# %%
import pandas as pd
import sqlite3
import numpy as np

pd.set_option('display.max_columns', None)

# %%
public = pd.read_csv('../data/buildings_dev_pha_clean_2.1.csv')

# %%
cols_to_front = ['objectid', 'corrected_address', 'corrected_unit', 'std_city', 'std_st', 'std_zip5']
remaining_cols = [col for col in public.columns if col not in cols_to_front]
public = public[cols_to_front + remaining_cols]

# %%
public = public[public.corrected_address.notna()]

# %%
public.std_zip5 = public.std_zip5.astype(str)
public.std_zip5 = public.std_zip5.replace('nan', '')
public.std_zip5 = public.std_zip5.apply(lambda x: x.split('.')[0])
public.std_zip5 = public.std_zip5.apply(lambda x: '00' + x if len(x) == 3 else x)
public.std_zip5 = public.std_zip5.apply(lambda x: '0' + x if len(x) == 4 else x)

# %%
public['corrected_address'] = public.corrected_address.fillna('')
public['corrected_address'] = public['corrected_address'].str.replace(r'\s+', ' ').str.strip()

public['corrected_unit'] = public.corrected_unit.fillna('')
public['corrected_unit'] = public.corrected_unit.str.strip()

public['std_city'] = public.std_city.fillna('')
public['std_city'] = public.std_city.str.strip()

public['std_st'] = public.std_st.fillna('')
public['std_st'] = public.std_st.str.strip()

# %%
full_fema_matches = pd.DataFrame()

# %%
for year in range(2012, 2022):
    conn = sqlite3.Connection('../data/fire_data.db')
    df = pd.read_sql("""
        select 
            INCIDENT_KEY,
            address,
            APT_NO,
            CITY,
            STATE,
            ZIP5,
            PROP_LOSS,
            CONT_LOSS,
            OTH_DEATH,
            OTH_INJ,
            INC_TYPE,
            HUM_FAC_1,
            HUM_FAC_2,
            HUM_FAC_3,
            HUM_FAC_4,
            HUM_FAC_5,
            HUM_FAC_6,
            HUM_FAC_7,
            BLDG_INVOL,
            DET_ALERT,
            FLAME_SPRD,
            AES_PRES,
            ST_DAM_HVY,
            ST_DAM_SIG,
            ST_DAM_XTR,
            ST_DAM_MIN 
        from buildings_fires_all 
        where INC_YEAR
        """ + f" = {year};", conn)

    df['EXP_NO'] = df.INCIDENT_KEY.apply(lambda x: x.split('_')[-1]).astype(int)

    df['address'] = df.address.fillna('')
    df['address'] = df['address'].str.replace(r'\s+', ' ', regex=True).str.strip()

    df['APT_NO'] = df.APT_NO.fillna('')
    df['APT_NO'] = df.APT_NO.str.strip()

    df['CITY'] = df.CITY.fillna('')
    df['CITY'] = df.CITY.str.strip()

    df['STATE'] = df.STATE.fillna('')
    df['STATE'] = df.STATE.str.strip()

    df.ZIP5 = df.ZIP5.astype(str)
    df.ZIP5 = df.ZIP5.replace('nan', '')
    df.ZIP5 = df.ZIP5.apply(lambda x: x.split('.')[0])
    df.ZIP5 = df.ZIP5.apply(lambda x: '00' + x if len(x) == 3 else x)
    df.ZIP5 = df.ZIP5.apply(lambda x: '0' + x if len(x) == 4 else x)

    df['HUM_FAC_1'] = df.HUM_FAC_1.apply(lambda x: 1 if x == '1' else 0)
    df['HUM_FAC_2'] = df.HUM_FAC_2.apply(lambda x: 1 if pd.notna(x) else 0)
    df['HUM_FAC_3'] = df.HUM_FAC_3.apply(lambda x: 1 if pd.notna(x) else 0)
    df['HUM_FAC_4'] = df.HUM_FAC_4.apply(lambda x: 1 if pd.notna(x) else 0)
    df['HUM_FAC_5'] = df.HUM_FAC_5.apply(lambda x: 1 if pd.notna(x) else 0)
    df['HUM_FAC_6'] = df.HUM_FAC_6.apply(lambda x: 1 if pd.notna(x) else 0)
    df['HUM_FAC_7'] = df.HUM_FAC_7.apply(lambda x: 1 if pd.notna(x) else 0)
    df['BLDG_INVOL'] = df.BLDG_INVOL.apply(lambda x: np.nan if pd.isna(x) or float(x) < 0 else x)
    df['BLDG_INVOL'] = df.BLDG_INVOL.astype(float)
    df['DET_ALERT'] = df.DET_ALERT.replace('U', np.nan)
    df['DET_ALERT'] = df.DET_ALERT.apply(lambda x: 1 if x == '1' else 0)
    df['FLAME_SPRD'] = df.FLAME_SPRD.apply(lambda x: 1 if x == 'Y' else 0)
    df['AES_PRES'] = df.AES_PRES.replace('U', np.nan)
    df['AES_PRES'] = df.AES_PRES.replace('N', 0)
    df['AES_PRES'] = df.AES_PRES.apply(lambda x: 1 if x == '1' else .5)
    df['ST_DAM_MIN'] = df.ST_DAM_MIN.apply(lambda x: np.nan if pd.isna(x) or float(x) < 0 else x)
    df['ST_DAM_XTR'] = df.ST_DAM_XTR.apply(lambda x: np.nan if pd.isna(x) or float(x) < 0 else x)
    df['ST_DAM_HVY'] = df.ST_DAM_HVY.apply(lambda x: np.nan if pd.isna(x) or float(x) < 0 else x)
    df['ST_DAM_SIG'] = df.ST_DAM_SIG.apply(lambda x: np.nan if pd.isna(x) or float(x) < 0 else x)

    col = 'INC_TYPE'
    dummies = pd.get_dummies(df[col], prefix=col)
    df = pd.concat([df.drop(col, axis=1), dummies], axis=1)

    inc_type_cols = [x for x in df.columns if 'INC_TYPE_' in x]
    df['building_fires'] = df[inc_type_cols].sum(axis=1)

    df = df.drop(['INC_TYPE_114', 'INC_TYPE_115', 'INC_TYPE_116'], axis=1)

    full_fema_matches = pd.concat([full_fema_matches, public.merge(df, how='inner', 
        left_on=['corrected_address', 'corrected_unit', 'std_city', 'std_st', 'std_zip5'],
        right_on=['address', 'APT_NO', 'CITY', 'STATE', 'ZIP5']
    )], axis=0)

    # Max for indicator variable columns
    aggregated = df \
        .drop(['INCIDENT_KEY'], axis=1) \
        .groupby(['address', 'APT_NO', 'CITY', 'STATE', 'ZIP5']).agg({
            'PROP_LOSS': 'sum',
            'CONT_LOSS': 'sum',
            'OTH_DEATH': 'sum',
            'OTH_INJ': 'sum',
            'HUM_FAC_1': 'max',
            'HUM_FAC_2': 'max',
            'HUM_FAC_3': 'max',
            'HUM_FAC_4': 'max',
            'HUM_FAC_5': 'max',
            'HUM_FAC_6': 'max',
            'HUM_FAC_7': 'max',
            'BLDG_INVOL': 'sum',
            'DET_ALERT': 'sum',
            'FLAME_SPRD': 'sum',
            'AES_PRES': 'sum',
            'ST_DAM_HVY': 'sum',
            'ST_DAM_SIG': 'sum',
            'ST_DAM_XTR': 'sum',
            'ST_DAM_MIN': 'sum',
            'EXP_NO': 'max',
            'INC_TYPE_111': 'sum',
            'INC_TYPE_113': 'sum',
            'INC_TYPE_118': 'sum',
            'building_fires': 'sum'
    }).reset_index()

    new_cols = aggregated.columns

    # Aggregated should have >1 building_fires for every row
    if aggregated.building_fires.min() < 1:
        raise Exception()

    public = public.merge(aggregated, how='left', 
        left_on=['corrected_address', 'corrected_unit', 'std_city', 'std_st', 'std_zip5'],
        right_on=['address', 'APT_NO', 'CITY', 'STATE', 'ZIP5']
    )

    # Randomize order
    public = public.sample(frac=1).reset_index(drop=True)

    # Drop duplicates
    duplicate_indices_to_zero_out = public[
        (public.duplicated(subset=['building_fires', 'corrected_address', 'corrected_unit', 'std_city', 'std_st', 'std_zip5'], keep='first')) &
        (public.building_fires > 0)
    ].index
    public.loc[duplicate_indices_to_zero_out, new_cols] = 0

    public[new_cols] = public[new_cols].fillna(0)
    public = public.drop(['address', 'APT_NO', 'CITY', 'STATE', 'ZIP5'], axis=1)
    public.columns = [x + f'_{year}' if x in new_cols else x for x in public.columns]

# %% [markdown]
# Check to make sure no public housing buildings have been duplicated.

# %%
public[(public.duplicated(keep=False, subset=[
    'corrected_address', 'corrected_unit', 'std_city', 'std_st', 'std_zip5',
    'building_fires_2012', 'building_fires_2013', 'building_fires_2014', 'building_fires_2015', 
    'building_fires_2016', 'building_fires_2017', 'building_fires_2018', 'building_fires_2019', 
    'building_fires_2020', 'building_fires_2021' 
]))]
# Out:
#         objectid  corrected_address corrected_unit      std_city std_st  \
# 7          86377   730 PALISADE AVE                   BRIDGEPORT     CT
# 14         36928    501 S AUSTIN ST                       RANGER     TX
# 17        135068  405 BAINBRIDGE CT                    LEXINGTON     KY
# 32        124413   3328 MCALPINE RD                   BELLINGHAM     WA
# 40        118525         109 1ST ST                       KERSEY     CO
# ...          ...                ...            ...           ...    ...
# 179017    138275    4890 RICHARD ST                 JACKSONVILLE     FL
# 179020     28131    3737 BURKETT ST                      HOUSTON     TX
# 179023    124186      600 S HOME ST                     CORRIGAN     TX
# 179035    136428    101 FRANKLIN ST                   HONEA PATH     SC
# 179040     27922      320 ANGELA ST                     KEY WEST     FL
#
#        std_zip5  total_dwelling_units  acc_units  total_occupied  \
# 7         06610                     6          6               6
# 14        76470                     2          2               2
# 17        40509                     8          8               8
# 32        98225                     2          2               2
# 40        80644                     4          4               4
# ...         ...                   ...        ...             ...
# 179017    32207                     2          2               2
# 179020    77004                     2          2               2
# 179023    75939                     2          2               2
# 179035    29654                     2          2               2
# 179040    33040                     8          8               8
#
#         regular_vacant  total_units  pct_occupied  number_reported  \
# 7                    0            6         100.0                6
# 14                   0            2         100.0                2
# 17                   0            8         100.0                8
# 32                   0            2         100.0                2
# 40                   0            4         100.0                4
# ...                ...          ...           ...              ...
# 179017               0            2         100.0                2
# 179020               0            2         100.0                2
# 179023               0            2         100.0                2
# 179035               0            2         100.0                2
# 179040               0            8         100.0                8
#
#         pct_reported  months_since_report  pct_movein  people_per_unit  \
# 7                NaN                  NaN         NaN              NaN
# 14               NaN                  NaN         NaN              NaN
# 17               NaN                  NaN         NaN              NaN
# 32               NaN                  NaN         NaN              NaN
# 40               NaN                  NaN         NaN              NaN
# ...              ...                  ...         ...              ...
# 179017           NaN                  NaN         NaN              NaN
# 179020           NaN                  NaN         NaN              NaN
# 179023           NaN                  NaN         NaN              NaN
# 179035           NaN                  NaN         NaN              NaN
# 179040           NaN                  NaN         NaN              NaN
#
#         people_total  rent_per_month  spending_per_month  \
# 7                NaN             NaN                 NaN
# 14               NaN             NaN                 NaN
# 17               NaN             NaN                 NaN
# 32               NaN             NaN                 NaN
# 40               NaN             NaN                 NaN
# ...              ...             ...                 ...
# 179017           NaN             NaN                 NaN
# 179020           NaN             NaN                 NaN
# 179023           NaN             NaN                 NaN
# 179035           NaN             NaN                 NaN
# 179040           NaN             NaN                 NaN
#
#         spending_per_month_prev_yr  hh_income  person_income  pct_lt5k  \
# 7                              NaN        NaN            NaN       NaN
# 14                             NaN        NaN            NaN       NaN
# 17                             NaN        NaN            NaN       NaN
# 32                             NaN        NaN            NaN       NaN
# 40                             NaN        NaN            NaN       NaN
# ...                            ...        ...            ...       ...
# 179017                         NaN        NaN            NaN       NaN
# 179020                         NaN        NaN            NaN       NaN
# 179023                         NaN        NaN            NaN       NaN
# 179035                         NaN        NaN            NaN       NaN
# 179040                         NaN        NaN            NaN       NaN
#
#         pct_5k_lt10k  pct_10k_lt15k  pct_15k_lt20k  pct_ge20k  pct_wage_major  \
# 7                NaN            NaN            NaN        NaN             NaN
# 14               NaN            NaN            NaN        NaN             NaN
# 17               NaN            NaN            NaN        NaN             NaN
# 32               NaN            NaN            NaN        NaN             NaN
# 40               NaN            NaN            NaN        NaN             NaN
# ...              ...            ...            ...        ...             ...
# 179017           NaN            NaN            NaN        NaN             NaN
# 179020           NaN            NaN            NaN        NaN             NaN
# 179023           NaN            NaN            NaN        NaN             NaN
# 179035           NaN            NaN            NaN        NaN             NaN
# 179040           NaN            NaN            NaN        NaN             NaN
#
#         pct_welfare_major  pct_other_major  pct_median  pct_lt50_median  \
# 7                     NaN              NaN         NaN              NaN
# 14                    NaN              NaN         NaN              NaN
# 17                    NaN              NaN         NaN              NaN
# 32                    NaN              NaN         NaN              NaN
# 40                    NaN              NaN         NaN              NaN
# ...                   ...              ...         ...              ...
# 179017                NaN              NaN         NaN              NaN
# 179020                NaN              NaN         NaN              NaN
# 179023                NaN              NaN         NaN              NaN
# 179035                NaN              NaN         NaN              NaN
# 179040                NaN              NaN         NaN              NaN
#
#         pct_lt30_median  pct_2adults  pct_1adult  pct_female_head  \
# 7                   NaN          NaN         NaN              NaN
# 14                  NaN          NaN         NaN              NaN
# 17                  NaN          NaN         NaN              NaN
# 32                  NaN          NaN         NaN              NaN
# 40                  NaN          NaN         NaN              NaN
# ...                 ...          ...         ...              ...
# 179017              NaN          NaN         NaN              NaN
# 179020              NaN          NaN         NaN              NaN
# 179023              NaN          NaN         NaN              NaN
# 179035              NaN          NaN         NaN              NaN
# 179040              NaN          NaN         NaN              NaN
#
#         pct_female_head_child  pct_disabled_lt62  pct_disabled_ge62  \
# 7                         NaN                NaN                NaN
# 14                        NaN                NaN                NaN
# 17                        NaN                NaN                NaN
# 32                        NaN                NaN                NaN
# 40                        NaN                NaN                NaN
# ...                       ...                ...                ...
# 179017                    NaN                NaN                NaN
# 179020                    NaN                NaN                NaN
# 179023                    NaN                NaN                NaN
# 179035                    NaN                NaN                NaN
# 179040                    NaN                NaN                NaN
#
#         pct_disabled_all  pct_lt24_head  pct_age25_50  pct_age51_61  \
# 7                    NaN            NaN           NaN           NaN
# 14                   NaN            NaN           NaN           NaN
# 17                   NaN            NaN           NaN           NaN
# 32                   NaN            NaN           NaN           NaN
# 40                   NaN            NaN           NaN           NaN
# ...                  ...            ...           ...           ...
# 179017               NaN            NaN           NaN           NaN
# 179020               NaN            NaN           NaN           NaN
# 179023               NaN            NaN           NaN           NaN
# 179035               NaN            NaN           NaN           NaN
# 179040               NaN            NaN           NaN           NaN
#
#         pct_age62plus  pct_age85plus  pct_minority  pct_black  \
# 7                 NaN            NaN           NaN        NaN
# 14                NaN            NaN           NaN        NaN
# 17                NaN            NaN           NaN        NaN
# 32                NaN            NaN           NaN        NaN
# 40                NaN            NaN           NaN        NaN
# ...               ...            ...           ...        ...
# 179017            NaN            NaN           NaN        NaN
# 179020            NaN            NaN           NaN        NaN
# 179023            NaN            NaN           NaN        NaN
# 179035            NaN            NaN           NaN        NaN
# 179040            NaN            NaN           NaN        NaN
#
#         pct_native_american  pct_asian  pct_hispanic  months_waiting  \
# 7                       NaN        NaN           NaN             NaN
# 14                      NaN        NaN           NaN             NaN
# 17                      NaN        NaN           NaN             NaN
# 32                      NaN        NaN           NaN             NaN
# 40                      NaN        NaN           NaN             NaN
# ...                     ...        ...           ...             ...
# 179017                  NaN        NaN           NaN             NaN
# 179020                  NaN        NaN           NaN             NaN
# 179023                  NaN        NaN           NaN             NaN
# 179035                  NaN        NaN           NaN             NaN
# 179040                  NaN        NaN           NaN             NaN
#
#         months_from_movein  pct_utility_allow  ave_util_allow  pct_bed1  \
# 7                      NaN                NaN             NaN       NaN
# 14                     NaN                NaN             NaN       NaN
# 17                     NaN                NaN             NaN       NaN
# 32                     NaN                NaN             NaN       NaN
# 40                     NaN                NaN             NaN       NaN
# ...                    ...                ...             ...       ...
# 179017                 NaN                NaN             NaN       NaN
# 179020                 NaN                NaN             NaN       NaN
# 179023                 NaN                NaN             NaN       NaN
# 179035                 NaN                NaN             NaN       NaN
# 179040                 NaN                NaN             NaN       NaN
#
#         pct_bed2  pct_bed3  pct_overhoused  tminority  tpoverty  tpct_ownsfd  \
# 7            NaN       NaN             NaN        NaN       NaN          NaN
# 14           NaN       NaN             NaN        NaN       NaN          NaN
# 17           NaN       NaN             NaN        NaN       NaN          NaN
# 32           NaN       NaN             NaN        NaN       NaN          NaN
# 40           NaN       NaN             NaN        NaN       NaN          NaN
# ...          ...       ...             ...        ...       ...          ...
# 179017       NaN       NaN             NaN        NaN       NaN          NaN
# 179020       NaN       NaN             NaN        NaN       NaN          NaN
# 179023       NaN       NaN             NaN        NaN       NaN          NaN
# 179035       NaN       NaN             NaN        NaN       NaN          NaN
# 179040       NaN       NaN             NaN        NaN       NaN          NaN
#
#         chldrn_mbr_cnt  eldly_prcnt  pct_disabled_lt62_all  pct_lt80_median  \
# 7                  NaN          NaN                    NaN              NaN
# 14                 NaN          NaN                    NaN              NaN
# 17                 NaN          NaN                    NaN              NaN
# 32                 NaN          NaN                    NaN              NaN
# 40                 NaN          NaN                    NaN              NaN
# ...                ...          ...                    ...              ...
# 179017             NaN          NaN                    NaN              NaN
# 179020             NaN          NaN                    NaN              NaN
# 179023             NaN          NaN                    NaN              NaN
# 179035             NaN          NaN                    NaN              NaN
# 179040             NaN          NaN                    NaN              NaN
#
#         median_inc_amnt  metro  micro  c1pprb  annl_expns_amnt  \
# 7                   NaN    1.0    0.0     2.0              NaN
# 14                  NaN    0.0    0.0     4.0              NaN
# 17                  NaN    1.0    0.0     1.0              NaN
# 32                  NaN    1.0    0.0     1.0              NaN
# 40                  NaN    1.0    0.0     1.0              NaN
# ...                 ...    ...    ...     ...              ...
# 179017              NaN    1.0    0.0     1.0              NaN
# 179020              NaN    1.0    0.0     2.0              NaN
# 179023              NaN    0.0    0.0     1.0              NaN
# 179035              NaN    1.0    0.0     1.0              NaN
# 179040              NaN    0.0    1.0     1.0              NaN
#
#         annl_expns_amnt_prev_yr  pha_total_units  \
# 7                           NaN             2224
# 14                          NaN               86
# 17                          NaN              914
# 32                          NaN               63
# 40                          NaN               20
# ...                         ...              ...
# 179017                      NaN             2314
# 179020                      NaN             2609
# 179023                      NaN              124
# 179035                      NaN             1322
# 179040                      NaN              588
#
#         dev_spending_per_month_prev_yr  dev_chldrn_mbr_cnt  \
# 7                                607.0                 2.0
# 14                               452.0                27.0
# 17                               318.0               317.0
# 32                               594.0                86.0
# 40                               265.0                 3.0
# ...                                ...                 ...
# 179017                           390.0               235.0
# 179020                           434.0               503.0
# 179023                           335.0                56.0
# 179035                           367.0                71.0
# 179040                            38.0               270.0
#
#         dev_annl_expns_amnt  dev_annl_expns_amnt_prev_yr  dev_eldly_prcnt  \
# 7                 3168020.0                    1908057.0        69.739998
# 14                 451594.0                     390880.0        27.360001
# 17                 658457.0                     664352.0         1.660000
# 32                 458365.0                     449362.0         5.820000
# 40                  59292.0                      57287.0        57.139999
# ...                     ...                          ...              ...
# 179017             932083.0                     888834.0         8.050000
# 179020            6871318.0                    2852115.0        10.040000
# 179023             562665.0                     479007.0        20.670000
# 179035            1681189.0                     864168.0        31.760000
# 179040             166694.0                     173953.0        19.930000
#
#         dev_pct_disabled_lt62_all  dev_pct_lt80_median  dev_median_inc_amnt  \
# 7                       26.639999           100.000000              11244.0
# 14                      12.260000            98.529999              13962.0
# 17                       7.560000            94.080002              20280.0
# 32                      12.170000            96.830002              19397.0
# 40                      17.860001           100.000000              15461.0
# ...                           ...                  ...                  ...
# 179017                  11.670000            99.470001              10548.0
# 179020                  16.219999            99.480003              10092.0
# 179023                  11.540000            88.790001              15684.0
# 179035                  20.610001            98.480003              11472.0
# 179040                   8.590000            91.320000              26402.0
#
#         dev_total_units  dev_total_dwelling_units  dev_acc_units  \
# 7                 272.0                     272.0          272.0
# 14                 86.0                      86.0           86.0
# 17                180.0                     180.0          180.0
# 32                 63.0                      63.0           63.0
# 40                 20.0                      20.0           20.0
# ...                 ...                       ...            ...
# 179017            196.0                     192.0          192.0
# 179020            595.0                     593.0          593.0
# 179023            124.0                     124.0          124.0
# 179035            205.0                     204.0          204.0
# 179040            390.0                     389.0          389.0
#
#         dev_total_occupied  dev_regular_vacant  dev_pha_total_units  \
# 7                    268.0                 4.0               2224.0
# 14                    68.0                 0.0                 86.0
# 17                   171.0                10.0                914.0
# 32                    63.0                 0.0                 63.0
# 40                    20.0                 0.0                 20.0
# ...                    ...                 ...                  ...
# 179017               190.0                 0.0               2314.0
# 179020               578.0                15.0               2609.0
# 179023               116.0                 0.0                124.0
# 179035               198.0                 6.0               1322.0
# 179040               380.0                 9.0                588.0
#
#         dev_pct_occupied  dev_number_reported  dev_pct_reported  \
# 7                  98.53                268.0            100.00
# 14                 79.07                 68.0            100.00
# 17                 95.01                169.0             98.82
# 32                100.00                 63.0            100.00
# 40                100.00                 20.0            100.00
# ...                  ...                  ...               ...
# 179017             98.96                190.0            100.00
# 179020             97.47                577.0             99.83
# 179023             93.55                116.0            100.00
# 179035             97.06                197.0             99.49
# 179040             97.69                380.0            100.00
#
#         dev_months_since_report  dev_pct_movein  dev_people_per_unit  \
# 7                           6.0            5.60                  1.1
# 14                          6.0           19.12                  1.6
# 17                         11.0            4.73                  3.2
# 32                          5.0            1.59                  3.0
# 40                          7.0           25.00                  1.4
# ...                         ...             ...                  ...
# 179017                      3.0            8.95                  2.6
# 179020                      6.0           16.98                  2.0
# 179023                      5.0           18.10                  1.8
# 179035                      6.0           15.74                  1.5
# 179040                      7.0            5.53                  2.1
#
#         dev_people_total  dev_rent_per_month  dev_spending_per_month  \
# 7                  304.0               357.0                   985.0
# 14                 106.0               344.0                   553.0
# 17                 542.0               331.0                   321.0
# 32                 189.0               564.0                   606.0
# 40                  28.0               398.0                   247.0
# ...                  ...                 ...                     ...
# 179017             497.0               332.0                   409.0
# 179020            1165.0               272.0                   991.0
# 179023             208.0               363.0                   404.0
# 179035             296.0               310.0                   708.0
# 179040             803.0               709.0                    37.0
#
#         dev_hh_income  dev_person_income  dev_pct_lt5k  dev_pct_5k_lt10k  \
# 7             15070.0            13285.0          1.13              4.53
# 14            16895.0            10838.0          1.47             19.12
# 17            24386.0             7604.0          6.51             14.79
# 32            25838.0             8613.0          1.61              8.06
# 40            18551.0            13250.0          5.26              5.26
# ...               ...                ...           ...               ...
# 179017        14146.0             5408.0         12.72             20.23
# 179020        11442.0             5667.0         21.80             12.07
# 179023        22444.0            12517.0          3.48             13.91
# 179035        14456.0             9621.0         12.24              9.69
# 179040        32512.0            15386.0          0.79             12.89
#
#         dev_pct_10k_lt15k  dev_pct_15k_lt20k  dev_pct_ge20k  \
# 7                   58.11              16.23          20.00
# 14                  33.82              19.12          26.47
# 17                  18.93               8.28          51.48
# 32                  20.97              19.35          50.00
# 40                  26.32              26.32          36.84
# ...                   ...                ...            ...
# 179017              28.90              14.45          23.70
# 179020              43.60               6.67          15.86
# 179023              26.09              15.65          40.87
# 179035              44.90              13.27          19.90
# 179040              20.26               9.47          56.58
#
#         dev_pct_wage_major  dev_pct_welfare_major  dev_pct_other_major  \
# 7                     3.36                   0.00                95.52
# 14                   36.76                   0.00                63.24
# 17                   65.68                   6.51                27.81
# 32                   58.73                   3.17                34.92
# 40                   10.00                   5.00                80.00
# ...                    ...                    ...                  ...
# 179017               32.11                   1.05                57.37
# 179020               27.21                   0.17                68.80
# 179023               42.24                   0.00                56.90
# 179035               18.27                   0.00                81.22
# 179040               56.84                   2.37                40.53
#
#         dev_pct_median  dev_pct_lt50_median  dev_pct_lt30_median  \
# 7                14.59                97.76                87.31
# 14               31.83                85.29                54.41
# 17               29.49                75.15                52.66
# 32               27.16                84.13                55.56
# 40               18.82                90.00                70.00
# ...                ...                  ...                  ...
# 179017           16.36                93.68                81.58
# 179020           13.22                98.27                87.35
# 179023           35.17                72.41                46.55
# 179035           20.49                90.86                68.02
# 179040           34.47                71.32                50.00
#
#         dev_pct_2adults  dev_pct_1adult  dev_pct_female_head  \
# 7                  0.00            0.75                56.34
# 14                 2.94           17.65                67.65
# 17                 6.51           78.11                91.72
# 32                14.29           47.62                82.54
# 40                 5.00            5.00                75.00
# ...                 ...             ...                  ...
# 179017             4.74           51.58                76.84
# 179020             0.52           41.59                76.60
# 179023             5.17           25.86                77.59
# 179035             1.52           18.78                73.10
# 179040             7.63           28.95                73.42
#
#         dev_pct_female_head_child  dev_pct_disabled_lt62  \
# 7                            0.37                  98.68
# 14                          11.76                  31.71
# 17                          78.11                  12.42
# 32                          50.79                  23.64
# 40                          10.00                  62.50
# ...                           ...                    ...
# 179017                      49.47                  26.49
# 179020                      39.86                  33.62
# 179023                      29.31                  30.26
# 179035                      19.80                  50.00
# 179040                      29.47                  18.91
#
#         dev_pct_disabled_ge62  dev_pct_disabled_all  dev_pct_lt24_head  \
# 7                       68.23                 72.04               0.75
# 14                      33.33                 21.70              11.76
# 17                      62.50                  8.67               2.37
# 32                      25.00                 13.23               0.00
# 40                      50.00                 46.43               0.00
# ...                       ...                   ...                ...
# 179017                  71.79                 17.30               2.11
# 179020                  87.61                 25.06               1.39
# 179023                  40.00                 19.23               6.03
# 179035                  35.63                 32.43               4.57
# 179040                  31.69                 14.57               1.05
#
#         dev_pct_age25_50  dev_pct_age51_61  dev_pct_age62plus  \
# 7                   8.58             19.40              71.27
# 14                 19.12             29.41              39.71
# 17                 84.02              9.47               4.14
# 32                 68.25             19.05              12.70
# 40                 30.00             10.00              60.00
# ...                  ...               ...                ...
# 179017             60.00             17.37              20.53
# 179020             54.77             24.44              19.41
# 179023             37.07             22.41              34.48
# 179035             20.30             30.96              44.16
# 179040             36.84             24.74              37.37
#
#         dev_pct_age85plus  dev_pct_minority  dev_pct_black  \
# 7                    9.33             90.67          41.42
# 14                   0.00             17.65           2.94
# 17                   0.00             78.11          73.96
# 32                   0.00             36.51           1.59
# 40                  15.00             20.00           0.00
# ...                   ...               ...            ...
# 179017               0.00             84.74          72.11
# 179020               1.73             97.92          89.77
# 179023               0.86             60.34          59.48
# 179035               1.02             57.87          54.82
# 179040               1.58             83.68          44.47
#
#         dev_pct_native_american  dev_pct_asian  dev_pct_hispanic  \
# 7                          0.00           0.00             49.25
# 14                         0.00           0.00             14.71
# 17                         0.59           0.00              3.55
# 32                         4.76           4.76             25.40
# 40                         0.00           0.00             20.00
# ...                         ...            ...               ...
# 179017                     0.00           0.53             12.11
# 179020                     0.35           0.00              7.80
# 179023                     0.00           0.00              0.86
# 179035                     0.00           0.00              3.05
# 179040                     0.53           0.79             37.89
#
#         dev_months_waiting  dev_months_from_movein  dev_pct_utility_allow  \
# 7                     13.0                   155.0                  97.39
# 14                     3.0                    51.0                  79.41
# 17                     0.0                   106.0                 100.00
# 32                     0.0                   119.0                  87.30
# 40                     2.0                    60.0                   0.00
# ...                    ...                     ...                    ...
# 179017                26.0                    86.0                  95.26
# 179020                52.0                    96.0                   6.93
# 179023                 3.0                    94.0                  99.14
# 179035                 7.0                    88.0                 100.00
# 179040                53.0                   178.0                  99.47
#
#         dev_ave_util_allow  dev_pct_bed1  dev_pct_bed2  dev_pct_bed3  \
# 7                     77.0        100.00          0.00          0.00
# 14                    62.0         39.71         45.59         14.71
# 17                   143.0          2.37         39.64         57.99
# 32                   180.0          0.00         15.87         84.13
# 40                     0.0         80.00         10.00         10.00
# ...                    ...           ...           ...           ...
# 179017               145.0         25.79         39.47         34.74
# 179020                78.0         41.94         41.25         16.81
# 179023                65.0         46.55         33.62         19.83
# 179035                36.0         48.73         28.93         22.34
# 179040               116.0         31.58         41.05         27.37
#
#         dev_pct_overhoused  dev_tminority  dev_tpoverty  dev_tpct_ownsfd  \
# 7                     0.00          70.48         22.36            40.72
# 14                   30.88          20.77         18.61            71.00
# 17                    7.69          28.58         18.49            42.06
# 32                   36.51          18.97         13.87            54.14
# 40                    0.00          26.44          7.14            81.62
# ...                    ...            ...           ...              ...
# 179017                7.37          39.18         14.10            53.93
# 179020                9.88          96.03         57.11            22.31
# 179023               17.24          46.06         27.36            64.66
# 179035               29.44          33.53         15.05            72.39
# 179040               21.58          37.26         11.97            41.41
#
#         pha_section8_units_cnt  pha_section8_occupied  pha_opfund_amnt  \
# 7                         3201                   2831         16386275
# 14                           0                      0           243305
# 17                        3427                   3178          3357530
# 32                           0                      0           202703
# 40                           0                      0            59292
# ...                        ...                    ...              ...
# 179017                    8374                   7774         11312543
# 179020                   18890                  16881         16948562
# 179023                       0                      0           261599
# 179035                    1675                   1544          6360454
# 179040                     259                    247           250480
#
#         pha_opfund_amnt_prev_yr  pha_capfund_amnt  pha_capfund_amnt_prev_yr  \
# 7                      15563049           8331371                         0
# 14                       223642            208289                    167238
# 17                      3222441                 0                         0
# 32                       244157            255662                    205205
# 40                        57287                 0                         0
# ...                         ...               ...                       ...
# 179017                 10717470                 0                         0
# 179020                 14614489           9634094                         0
# 179023                   233974            301066                    245033
# 179035                  5550955           4473617                         0
# 179040                   262528                 0                         0
#
#         pha_ross_amnt  pha_fss_amnt  pha_chldrn_mbr_cnt  pha_eldly_prcnt  \
# 7                   0             0              4159.0        12.260000
# 14                  0             0                27.0        27.360001
# 17                  0             0              3996.0        11.230000
# 32                  0             0                86.0         5.820000
# 40                  0             0                 3.0        57.139999
# ...               ...           ...                 ...              ...
# 179017              0             0             13731.0        10.220000
# 179020              0             0             21787.0        10.610000
# 179023              0             0                56.0        20.670000
# 179035              0             0              2157.0        18.520000
# 179040              0             0               416.0        32.830002
#
#         pha_pct_disabled_lt62_all  pha_pct_lt80_median  pha_median_inc_amnt  \
# 7                       12.200000            99.320000              11508.0
# 14                      12.260000            98.529999              13962.0
# 17                      12.650000            98.080002              12752.0
# 32                      12.170000            96.830002              19397.0
# 40                      17.860001           100.000000              15461.0
# ...                           ...                  ...                  ...
# 179017                  12.280000            93.730003              11019.0
# 179020                  15.370000            98.879997              10608.0
# 179023                  11.540000            88.790001              15684.0
# 179035                  14.380000            99.110001              11466.0
# 179040                   8.220000            95.320000              19437.0
#
#         pha_annl_expns_amnt  pha_annl_expns_amnt_prev_yr  construction_year  \
# 7                59782671.0                   38084913.0                NaN
# 14                 451594.0                     390880.0                NaN
# 17               23015085.0                   21910224.0                NaN
# 32                 458365.0                     449362.0             1941.0
# 40                  59292.0                      57287.0             1971.0
# ...                     ...                          ...                ...
# 179017           87885248.0                   81124367.0                NaN
# 179020          202713160.0                  163593235.0                NaN
# 179023             562665.0                     479007.0                NaN
# 179035           19914163.0                   14914871.0             1954.0
# 179040            3979004.0                    3645422.0             1952.0
#
#         dofa_actual_year  encoded_development_code  encoded_participant_code  \
# 7                 1963.0                       631                       303
# 14                1985.0                      5745                      2290
# 17                1986.0                      1977                       845
# 32                1983.0                      6306                      2627
# 40                1971.0                       606                       282
# ...                  ...                       ...                       ...
# 179017            1981.0                       834                       340
# 179020            1940.0                      5599                      2258
# 179023            1972.0                      5911                      2429
# 179035            1953.0                      5357                      2128
# 179040            1959.0                       922                       351
#
#         encoded_msa_nm  encoded_zip5  encoded_zip9  encoded_zip11  \
# 7                   39          3868          2555         115952
# 14                 306          4763          1680         139431
# 17                 161          2096           684          75745
# 32                  25          5765          7569         165690
# 40                 113          5106          7935         148042
# ...                ...           ...           ...            ...
# 179017             134          1442          6557          45680
# 179020             126          4819          7719         140334
# 179023             306          4716          1734         138186
# 179035             117          1167          1339          36483
# 179040             306          1534          6565          48507
#
#         msgusps_100% Overall probable correctness  \
# 7                                           False
# 14                                          False
# 17                                          False
# 32                                          False
# 40                                          False
# ...                                           ...
# 179017                                      False
# 179020                                      False
# 179023                                      False
# 179035                                      False
# 179040                                      False
#
#         msgusps_20% Overall probable correctness  \
# 7                                          False
# 14                                         False
# 17                                         False
# 32                                         False
# 40                                         False
# ...                                          ...
# 179017                                     False
# 179020                                     False
# 179023                                     False
# 179035                                     False
# 179040                                     False
#
#         msgusps_30% Overall probable correctness  \
# 7                                          False
# 14                                         False
# 17                                         False
# 32                                         False
# 40                                         False
# ...                                          ...
# 179017                                     False
# 179020                                     False
# 179023                                     False
# 179035                                     False
# 179040                                     False
#
#         msgusps_40% Overall probable correctness  \
# 7                                          False
# 14                                         False
# 17                                         False
# 32                                         False
# 40                                         False
# ...                                          ...
# 179017                                     False
# 179020                                     False
# 179023                                     False
# 179035                                     False
# 179040                                     False
#
#         msgusps_50% Overall probable correctness  \
# 7                                          False
# 14                                         False
# 17                                         False
# 32                                         False
# 40                                         False
# ...                                          ...
# 179017                                     False
# 179020                                     False
# 179023                                     False
# 179035                                     False
# 179040                                     False
#
#         msgusps_60% Overall probable correctness  \
# 7                                          False
# 14                                          True
# 17                                         False
# 32                                         False
# 40                                         False
# ...                                          ...
# 179017                                     False
# 179020                                     False
# 179023                                     False
# 179035                                     False
# 179040                                     False
#
#         msgusps_70% Overall probable correctness  \
# 7                                          False
# 14                                         False
# 17                                         False
# 32                                         False
# 40                                         False
# ...                                          ...
# 179017                                     False
# 179020                                     False
# 179023                                     False
# 179035                                     False
# 179040                                     False
#
#         msgusps_80% Overall probable correctness  \
# 7                                           True
# 14                                         False
# 17                                         False
# 32                                         False
# 40                                         False
# ...                                          ...
# 179017                                     False
# 179020                                      True
# 179023                                     False
# 179035                                     False
# 179040                                     False
#
#         msgusps_90% Overall probable correctness  \
# 7                                          False
# 14                                         False
# 17                                          True
# 32                                          True
# 40                                          True
# ...                                          ...
# 179017                                      True
# 179020                                     False
# 179023                                      True
# 179035                                      True
# 179040                                      True
#
#         msgusps_Apartment missing or not found  \
# 7                                        False
# 14                                       False
# 17                                       False
# 32                                       False
# 40                                       False
# ...                                        ...
# 179017                                   False
# 179020                                   False
# 179023                                   False
# 179035                                   False
# 179040                                   False
#
#         msgusps_House # not found on this street  \
# 7                                          False
# 14                                         False
# 17                                         False
# 32                                         False
# 40                                         False
# ...                                          ...
# 179017                                     False
# 179020                                     False
# 179023                                     False
# 179035                                     False
# 179040                                     False
#
#         msgusps_Insufficient or Blank address  msgusps_Multiple Match  \
# 7                                       False                   False
# 14                                      False                   False
# 17                                      False                   False
# 32                                      False                   False
# 40                                      False                   False
# ...                                       ...                     ...
# 179017                                  False                   False
# 179020                                  False                   False
# 179023                                  False                   False
# 179035                                  False                   False
# 179040                                  False                   False
#
#         msgusps_Street not found  \
# 7                          False
# 14                         False
# 17                         False
# 32                         False
# 40                         False
# ...                          ...
# 179017                     False
# 179020                     False
# 179023                     False
# 179035                     False
# 179040                     False
#
#         pha_ha_section_8_size_category_EXTRA LARGE (5,000+)  \
# 7                                                   False
# 14                                                  False
# 17                                                  False
# 32                                                  False
# 40                                                  False
# ...
#
#         OTH_INJ_2019  HUM_FAC_1_2019  HUM_FAC_2_2019  HUM_FAC_3_2019  \
# 7                0.0             0.0             0.0             0.0
# 14               0.0             0.0             0.0             0.0
# 17               0.0             0.0             0.0             0.0
# 32               0.0             0.0             0.0             0.0
# 40               0.0             0.0             0.0             0.0
# ...              ...             ...             ...             ...
# 179017           0.0             0.0             0.0             0.0
# 179020           0.0             0.0             0.0             0.0
# 179023           0.0             0.0             0.0             0.0
# 179035           0.0             0.0             0.0             0.0
# 179040           0.0             0.0             0.0             0.0
#
#         HUM_FAC_4_2019  HUM_FAC_5_2019  HUM_FAC_6_2019  HUM_FAC_7_2019  \
# 7                  0.0             0.0             0.0             0.0
# 14                 0.0             0.0             0.0             0.0
# 17                 0.0             0.0             0.0             0.0
# 32                 0.0             0.0             0.0             0.0
# 40                 0.0             0.0             0.0             0.0
# ...                ...             ...             ...             ...
# 179017             0.0             0.0             0.0             0.0
# 179020             0.0             0.0             0.0             0.0
# 179023             0.0             0.0             0.0             0.0
# 179035             0.0             0.0             0.0             0.0
# 179040             0.0             0.0             0.0             0.0
#
#         BLDG_INVOL_2019  DET_ALERT_2019  FLAME_SPRD_2019  AES_PRES_2019  \
# 7                   0.0             0.0              0.0            0.0
# 14                  0.0             0.0              0.0            0.0
# 17                  0.0             0.0              0.0            0.0
# 32                  0.0             0.0              0.0            0.0
# 40                  0.0             0.0              0.0            0.0
# ...                 ...             ...              ...            ...
# 179017              0.0             0.0              0.0            0.0
# 179020              0.0             0.0              0.0            0.0
# 179023              0.0             0.0              0.0            0.0
# 179035              0.0             0.0              0.0            0.0
# 179040              0.0             0.0              0.0            0.0
#
#         ST_DAM_HVY_2019  ST_DAM_SIG_2019  ST_DAM_XTR_2019  ST_DAM_MIN_2019  \
# 7                   0.0              0.0              0.0              0.0
# 14                  0.0              0.0              0.0              0.0
# 17                  0.0              0.0              0.0              0.0
# 32                  0.0              0.0              0.0              0.0
# 40                  0.0              0.0              0.0              0.0
# ...                 ...              ...              ...              ...
# 179017              0.0              0.0              0.0              0.0
# 179020              0.0              0.0              0.0              0.0
# 179023              0.0              0.0              0.0              0.0
# 179035              0.0              0.0              0.0              0.0
# 179040              0.0              0.0              0.0              0.0
#
#         EXP_NO_2019  INC_TYPE_111_2019  INC_TYPE_113_2019  INC_TYPE_118_2019  \
# 7               0.0                0.0                0.0                0.0
# 14              0.0                0.0                0.0                0.0
# 17              0.0                0.0                0.0                0.0
# 32              0.0                0.0                0.0                0.0
# 40              0.0                0.0                0.0                0.0
# ...             ...                ...                ...                ...
# 179017          0.0                0.0                0.0                0.0
# 179020          0.0                0.0                0.0                0.0
# 179023          0.0                0.0                0.0                0.0
# 179035          0.0                0.0                0.0                0.0
# 179040          0.0                0.0                0.0                0.0
#
#         building_fires_2019  PROP_LOSS_2020  CONT_LOSS_2020  OTH_DEATH_2020  \
# 7                       0.0             0.0             0.0             0.0
# 14                      0.0             0.0             0.0             0.0
# 17                      0.0             0.0             0.0             0.0
# 32                      0.0             0.0             0.0             0.0
# 40                      0.0             0.0             0.0             0.0
# ...                     ...             ...             ...             ...
# 179017                  0.0             0.0             0.0             0.0
# 179020                  0.0             0.0             0.0             0.0
# 179023                  0.0             0.0             0.0             0.0
# 179035                  0.0             0.0             0.0             0.0
# 179040                  0.0             0.0             0.0             0.0
#
#         OTH_INJ_2020  HUM_FAC_1_2020  HUM_FAC_2_2020  HUM_FAC_3_2020  \
# 7                0.0             0.0             0.0             0.0
# 14               0.0             0.0             0.0             0.0
# 17               0.0             0.0             0.0             0.0
# 32               0.0             0.0             0.0             0.0
# 40               0.0             0.0             0.0             0.0
# ...              ...             ...             ...             ...
# 179017           0.0             0.0             0.0             0.0
# 179020           0.0             0.0             0.0             0.0
# 179023           0.0             0.0             0.0             0.0
# 179035           0.0             0.0             0.0             0.0
# 179040           0.0             0.0             0.0             0.0
#
#         HUM_FAC_4_2020  HUM_FAC_5_2020  HUM_FAC_6_2020  HUM_FAC_7_2020  \
# 7                  0.0             0.0             0.0             0.0
# 14                 0.0             0.0             0.0             0.0
# 17                 0.0             0.0             0.0             0.0
# 32                 0.0             0.0             0.0             0.0
# 40                 0.0             0.0             0.0             0.0
# ...                ...             ...             ...             ...
# 179017             0.0             0.0             0.0             0.0
# 179020             0.0             0.0             0.0             0.0
# 179023             0.0             0.0             0.0             0.0
# 179035             0.0             0.0             0.0             0.0
# 179040             0.0             0.0             0.0             0.0
#
#         BLDG_INVOL_2020  DET_ALERT_2020  FLAME_SPRD_2020  AES_PRES_2020  \
# 7                   0.0             0.0              0.0            0.0
# 14                  0.0             0.0              0.0            0.0
# 17                  0.0             0.0              0.0            0.0
# 32                  0.0             0.0              0.0            0.0
# 40                  0.0             0.0              0.0            0.0
# ...                 ...             ...              ...            ...
# 179017              0.0             0.0              0.0            0.0
# 179020              0.0             0.0              0.0            0.0
# 179023              0.0             0.0              0.0            0.0
# 179035              0.0             0.0              0.0            0.0
# 179040              0.0             0.0              0.0            0.0
#
#         ST_DAM_HVY_2020  ST_DAM_SIG_2020  ST_DAM_XTR_2020  ST_DAM_MIN_2020  \
# 7                   0.0              0.0              0.0              0.0
# 14                  0.0              0.0              0.0              0.0
# 17                  0.0              0.0              0.0              0.0
# 32                  0.0              0.0              0.0              0.0
# 40                  0.0              0.0              0.0              0.0
# ...                 ...              ...              ...              ...
# 179017              0.0              0.0              0.0              0.0
# 179020              0.0              0.0              0.0              0.0
# 179023              0.0              0.0              0.0              0.0
# 179035              0.0              0.0              0.0              0.0
# 179040              0.0              0.0              0.0              0.0
#
#         EXP_NO_2020  INC_TYPE_111_2020  INC_TYPE_113_2020  INC_TYPE_118_2020  \
# 7               0.0                0.0                0.0                0.0
# 14              0.0                0.0                0.0                0.0
# 17              0.0                0.0                0.0                0.0
# 32              0.0                0.0                0.0                0.0
# 40              0.0                0.0                0.0                0.0
# ...             ...                ...                ...                ...
# 179017          0.0                0.0                0.0                0.0
# 179020          0.0                0.0                0.0                0.0
# 179023          0.0                0.0                0.0                0.0
# 179035          0.0                0.0                0.0                0.0
# 179040          0.0                0.0                0.0                0.0
#
#         building_fires_2020  PROP_LOSS_2021  CONT_LOSS_2021  OTH_DEATH_2021  \
# 7                       0.0             0.0             0.0             0.0
# 14                      0.0             0.0             0.0             0.0
# 17                      0.0             0.0             0.0             0.0
# 32                      0.0             0.0             0.0             0.0
# 40                      0.0             0.0             0.0             0.0
# ...                     ...             ...             ...             ...
# 179017                  0.0             0.0             0.0             0.0
# 179020                  0.0             0.0             0.0             0.0
# 179023                  0.0             0.0             0.0             0.0
# 179035                  0.0             0.0             0.0             0.0
# 179040                  0.0             0.0             0.0             0.0
#
#         OTH_INJ_2021  HUM_FAC_1_2021  HUM_FAC_2_2021  HUM_FAC_3_2021  \
# 7                0.0             0.0             0.0             0.0
# 14               0.0             0.0             0.0             0.0
# 17               0.0             0.0             0.0             0.0
# 32               0.0             0.0             0.0             0.0
# 40               0.0             0.0             0.0             0.0
# ...              ...             ...             ...             ...
# 179017           0.0             0.0             0.0             0.0
# 179020           0.0             0.0             0.0             0.0
# 179023           0.0             0.0             0.0             0.0
# 179035           0.0             0.0             0.0             0.0
# 179040           0.0             0.0             0.0             0.0
#
#         HUM_FAC_4_2021  HUM_FAC_5_2021  HUM_FAC_6_2021  HUM_FAC_7_2021  \
# 7                  0.0             0.0             0.0             0.0
# 14                 0.0             0.0             0.0             0.0
# 17                 0.0             0.0             0.0             0.0
# 32                 0.0             0.0             0.0             0.0
# 40                 0.0             0.0             0.0             0.0
# ...                ...             ...             ...             ...
# 179017             0.0             0.0             0.0             0.0
# 179020             0.0             0.0             0.0             0.0
# 179023             0.0             0.0             0.0             0.0
# 179035             0.0             0.0             0.0             0.0
# 179040             0.0             0.0             0.0             0.0
#
#         BLDG_INVOL_2021  DET_ALERT_2021  FLAME_SPRD_2021  AES_PRES_2021  \
# 7                   0.0             0.0              0.0            0.0
# 14                  0.0             0.0              0.0            0.0
# 17                  0.0             0.0              0.0            0.0
# 32                  0.0             0.0              0.0            0.0
# 40                  0.0             0.0              0.0            0.0
# ...                 ...             ...              ...            ...
# 179017              0.0             0.0              0.0            0.0
# 179020              0.0             0.0              0.0            0.0
# 179023              0.0             0.0              0.0            0.0
# 179035              0.0             0.0              0.0            0.0
# 179040              0.0             0.0              0.0            0.0
#
#         ST_DAM_HVY_2021  ST_DAM_SIG_2021  ST_DAM_XTR_2021  ST_DAM_MIN_2021  \
# 7                   0.0              0.0              0.0              0.0
# 14                  0.0              0.0              0.0              0.0
# 17                  0.0              0.0              0.0              0.0
# 32                  0.0              0.0              0.0              0.0
# 40                  0.0              0.0              0.0              0.0
# ...                 ...              ...              ...              ...
# 179017              0.0              0.0              0.0              0.0
# 179020              0.0              0.0              0.0              0.0
# 179023              0.0              0.0              0.0              0.0
# 179035              0.0              0.0              0.0              0.0
# 179040              0.0              0.0              0.0              0.0
#
#         EXP_NO_2021  INC_TYPE_111_2021  INC_TYPE_113_2021  INC_TYPE_118_2021  \
# 7               0.0                0.0                0.0                0.0
# 14              0.0                0.0                0.0                0.0
# 17              0.0                0.0                0.0                0.0
# 32              0.0                0.0                0.0                0.0
# 40              0.0                0.0                0.0                0.0
# ...             ...                ...                ...                ...
# 179017          0.0                0.0                0.0                0.0
# 179020          0.0                0.0                0.0                0.0
# 179023          0.0                0.0                0.0                0.0
# 179035          0.0                0.0                0.0                0.0
# 179040          0.0                0.0                0.0                0.0
#
#         building_fires_2021
# 7                       0.0
# 14                      0.0
# 17                      0.0
# 32                      0.0
# 40                      0.0
# ...                     ...
# 179017                  0.0
# 179020                  0.0
# 179023                  0.0
# 179035                  0.0
# 179040                  0.0
#
# [13181 rows x 550 columns]

# %%
print(public.objectid.nunique() / len(public))
if (public.objectid.nunique() / len(public)) != 1:
    raise Exception()

if public[(public.duplicated(keep=False, subset=[
    'corrected_address', 'corrected_unit', 'std_city', 'std_st', 'std_zip5',
    'building_fires_2012', 'building_fires_2013', 'building_fires_2014', 'building_fires_2015', 
    'building_fires_2016', 'building_fires_2017', 'building_fires_2018', 'building_fires_2019', 
    'building_fires_2020', 'building_fires_2021' 
])) & (public[[x for x in public.columns if 'building_fires' in x]].sum(axis=1) > 0)].shape[0] > 0:
    raise Exception()
# Out:
# 1.0

# %%
full_fema_matches \
    .loc[:, ['corrected_address', 'corrected_unit', 'std_city', 'std_st', 'std_zip5', 'INCIDENT_KEY']] \
    .to_csv('full_fema_matches.csv', index=False)

# %%
public.columns = [x.lower() for x in public.columns]

# %%
public.to_csv('../data/ph_fires_matched_2.1.csv', index=False)
