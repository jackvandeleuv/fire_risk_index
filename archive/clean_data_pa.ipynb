# %%
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
import numpy as np
import re
import seaborn as sns
import time
import requests
from sklearn.preprocessing import LabelEncoder

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('./pa_fires_in_ph.csv')

# %% [markdown]
# The majority of many columns have a -4 value, which indicates the information was hidden for privacy reasons, which occurs when the number of residents is fewer than 10.

# %%
df.replace(-4, np.nan, inplace=True)

# %%
pd.set_option('display.max_rows', 200)
(df.isna().sum() / len(df)).sort_values(ascending=False)
# Out:
# necta_nm                      1.000000
# dpv                           1.000000
# dpvact                        1.000000
# dpvnost                       1.000000
# place_inc2kx                  1.000000
# urb_out                       1.000000
# dpvrc                         1.000000
# zip_class                     0.998279
# c1psrc                        0.977631
# apt_no                        0.966220
# apt_type                      0.966129
# c1pdrc                        0.958794
# annl_expns_amnt_prev_yr       0.945209
# pct_asian                     0.945028
# pct_native_american           0.945028
# pct_black                     0.945028
# pct_minority                  0.945028
# pct_age85plus                 0.945028
# pct_age62plus                 0.945028
# pct_disabled_lt62             0.945028
# pct_age51_61                  0.945028
# pct_age25_50                  0.945028
# pct_lt24_head                 0.945028
# pct_disabled_all              0.945028
# pct_disabled_ge62             0.945028
# months_waiting                0.945028
# pct_hispanic                  0.945028
# tminority                     0.945028
# pct_utility_allow             0.945028
# ave_util_allow                0.945028
# pct_bed1                      0.945028
# pct_bed2                      0.945028
# pct_bed3                      0.945028
# pct_overhoused                0.945028
# pct_female_head               0.945028
# tpoverty                      0.945028
# tpct_ownsfd                   0.945028
# chldrn_mbr_cnt                0.945028
# eldly_prcnt                   0.945028
# pct_disabled_lt62_all         0.945028
# pct_lt80_median               0.945028
# median_inc_amnt               0.945028
# pct_female_head_child         0.945028
# months_from_movein            0.945028
# pct_1adult                    0.945028
# person_income                 0.945028
# pct_2adults                   0.945028
# annl_expns_amnt               0.945028
# pct_reported                  0.945028
# pct_movein                    0.945028
# people_per_unit               0.945028
# people_total                  0.945028
# rent_per_month                0.945028
# spending_per_month            0.945028
# spending_per_month_prev_yr    0.945028
# hh_income                     0.945028
# months_since_report           0.945028
# pct_lt5k                      0.945028
# pct_welfare_major             0.945028
# pct_lt30_median               0.945028
# pct_5k_lt10k                  0.945028
# pct_median                    0.945028
# pct_other_major               0.945028
# pct_lt50_median               0.945028
# pct_wage_major                0.945028
# pct_ge20k                     0.945028
# pct_15k_lt20k                 0.945028
# pct_10k_lt15k                 0.945028
# c1pgrc                        0.942221
# c1pzrc                        0.942130
# stm2kx                        0.901829
# exec_dir_fax                  0.506430
# building_name                 0.316428
# msa_nm                        0.200869
# c1parc                        0.099076
# construct_date                0.083590
# hlc                           0.079152
# c1pprb                        0.057779
# block2kx                      0.056602
# std_zip11                     0.054791
# dpbc                          0.054791
# dpbc_cksum                    0.054791
# std_addr                      0.054700
# std_zip9                      0.049538
# addr_type                     0.049538
# bg2kx                         0.047002
# blkgrp_level                  0.047002
# cbsa_nm                       0.014400
# national_bldg_id              0.005977
# dofa_actual_dt                0.001358
# place_cc2kx                   0.000815
# place_level                   0.000815
# ur                            0.000815
# place_nm2kx                   0.000815
# zcta2kx                       0.000815
# place2kx                      0.000815
# fcd_fips91                    0.000091
# ha_email_addr_text            0.000000
# ha_fax_num                    0.000000
# ha_phn_num                    0.000000
# all_fires                     0.000000
# last_updt_dttm                0.000000
# house_fires_20-21             0.000000
# dev_buil_nu_entrance          0.000000
# pha_total_units               0.000000
# cooking_fires_20-21           0.000000
# cooking_fires                 0.000000
# lat                           0.000000
# rad_type                      0.000000
# msgusps                       0.000000
# exec_dir_phone                0.000000
# house_fires                   0.000000
# rad_chap_indr                 0.000000
# tract_level                   0.000000
# exec_dir_email                0.000000
# lon                           0.000000
# rc2kx                         0.000000
# county_level                  0.000000
# msg2kx                        0.000000
# lvl2kx                        0.000000
# x                             0.000000
# cnty2kx                       0.000000
# std_zip5                      0.000000
# std_st                        0.000000
# objectid                      0.000000
# participant_code              0.000000
# formal_participant_name       0.000000
# development_code              0.000000
# project_name                  0.000000
# building_number               0.000000
# building_type_code            0.000000
# building_status_type_code     0.000000
# total_dwelling_units          0.000000
# acc_units                     0.000000
# total_occupied                0.000000
# regular_vacant                0.000000
# total_units                   0.000000
# pct_occupied                  0.000000
# number_reported               0.000000
# state2kx                      0.000000
# cnty_nm2kx                    0.000000
# y                             0.000000
# tract2kx                      0.000000
# curcnty_nm                    0.000000
# curcnty                       0.000000
# curcosub                      0.000000
# curcosub_nm                   0.000000
# msa                           0.000000
# cbsa                          0.000000
# necta                         0.000000
# metro                         0.000000
# micro                         0.000000
# std_city                      0.000000
# all_fires_20-21               0.000000
# dtype: float64

# %%
# Assuming your DataFrame is named 'df'
columns_to_drop = [
    'x', 'y', 'objectid', 'participant_code', 'std_addr', 'apt_no', 'rc2kx', 'stm2kx',
    'dev_buil_nu_entrance', 'ha_phn_num', 'ha_fax_num', 'ha_email_addr_text',
    'exec_dir_phone', 'exec_dir_fax', 'exec_dir_email',
    'lat', 'lon',
    'c1pgrc', 'c1pprb', 'c1pdrc', 'c1psrc', 'c1parc', 'c1pzrc',
    'project_name', 'building_name', 'building_number',
    'zcta2kx', 'dpbc', 'dpbc_cksum', 'std_zip11',
    'national_bldg_id', 'curcnty_nm', 'curcnty', 'curcosub', 'curcosub_nm',
    'place2kx', 'place_nm2kx',
    'msa', 'cbsa', 'necta', 'necta_nm', 'last_updt_dttm', 'development_code',
    'state2kx', 'cnty_nm2kx','cnty2kx','tract2kx','bg2kx','block2kx', 'cbsa_nm',
    'fcd_fips91','hlc', 'std_city', 'std_st',
    'county_level'	,'place_level',	'tract_level',	'blkgrp_level',
    'place_cc2kx', 'place_inc2kx'
]

df.drop(columns=columns_to_drop, inplace=True)

# %%
df['construction_year'] = pd.to_datetime(df['construct_date']).dt.year
df['dofa_actual_year'] = pd.to_datetime(df['dofa_actual_dt']).dt.year
df = df.drop(['construct_date', 'dofa_actual_dt'], axis=1)

# %%
df.sample()
# Out:
#                           formal_participant_name building_type_code  \
# 2365  Housing Authority of the City of Pittsburgh                 ES
#
#      building_status_type_code  total_dwelling_units  acc_units  \
# 2365                    INAPCP                    61         60
#
#       total_occupied  regular_vacant  total_units  pct_occupied  \
# 2365              59               1           61     96.720001
#
#       number_reported  pct_reported  months_since_report  pct_movein  \
# 2365               59         100.0                  7.0        5.08
#
#       people_per_unit  people_total  rent_per_month  spending_per_month  \
# 2365              1.0          59.0           355.0              2356.0
#
#       spending_per_month_prev_yr  hh_income  person_income  pct_lt5k  \
# 2365                      1983.0    15552.0        15552.0       0.0
#
#       pct_5k_lt10k  pct_10k_lt15k  pct_15k_lt20k  pct_ge20k  pct_wage_major  \
# 2365          1.69      54.240002      27.120001  16.950001            1.69
#
#       pct_welfare_major  pct_other_major  pct_median  pct_lt50_median  \
# 2365                0.0        98.309998        17.1        98.309998
#
#       pct_lt30_median  pct_2adults  pct_1adult  pct_female_head  \
# 2365        74.580002          0.0         0.0        81.360001
#
#       pct_female_head_child  pct_disabled_lt62  pct_disabled_ge62  \
# 2365                    0.0              100.0              39.66
#
#       pct_disabled_all  pct_lt24_head  pct_age25_50  pct_age51_61  \
# 2365             40.68            0.0          1.69           0.0
#
#       pct_age62plus  pct_age85plus  pct_minority  pct_black  \
# 2365      98.309998          20.34     89.830002  89.830002
#
#       pct_native_american  pct_asian  pct_hispanic  months_waiting  \
# 2365                  0.0        0.0           0.0             0.0
#
#       months_from_movein  pct_utility_allow  ave_util_allow  pct_bed1  \
# 2365                92.0              100.0            48.0     100.0
#
#       pct_bed2  pct_bed3  pct_overhoused  tminority  tpoverty  tpct_ownsfd  \
# 2365       0.0       0.0             0.0  71.279999      6.04    61.700001
#
#       chldrn_mbr_cnt  eldly_prcnt  pct_disabled_lt62_all  pct_lt80_median  \
# 2365             0.0    98.309998                   1.69            100.0
#
#       median_inc_amnt  dpvact  dpvnost              msa_nm  metro  micro  dpv  \
# 2365          14375.0     NaN      NaN  Pittsburgh, PA MSA    1.0    0.0  NaN
#
#       dpvrc  urb_out  std_zip5  std_zip9 zip_class addr_type apt_type  \
# 2365    NaN      NaN   15224.0    1055.0       NaN         H      NaN
#
#                                msgusps lvl2kx ur                      msg2kx  \
# 2365  90% Overall probable correctness      R  U  ** Street-Level Rooftop **
#
#      rad_chap_indr rad_type  annl_expns_amnt  annl_expns_amnt_prev_yr  \
# 2365             N                 1668034.0                1427787.0
#
#       pha_total_units  house_fires  cooking_fires  all_fires  \
# 2365             3154            0              0          0
#
#       house_fires_20-21  cooking_fires_20-21  all_fires_20-21  \
# 2365                  0                    0                0
#
#       construction_year  dofa_actual_year
# 2365             2004.0            2004.0

# %%
# Assuming your dataframe is named df
placeholder = "MISSING_VALUE"  # or any other string you'd like to use as placeholder

# List of columns to be one-hot encoded
columns_to_encode = [
     'msa_nm', 'building_type_code', 
    'building_status_type_code', 'formal_participant_name',
    'addr_type', 'apt_type', 'zip_class', 'lvl2kx', 'ur', 'msg2kx', 
    'rad_chap_indr', 'rad_type'
]

# Fill NaN values with placeholder
for column in columns_to_encode:
    df[column] = df[column].fillna(placeholder)

# One-hot encode the columns
for column in columns_to_encode:
    dummies = pd.get_dummies(df[column], prefix=column)
    df = pd.concat([df, dummies], axis=1)
    df.drop([column], axis=1, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

df.msgusps = LabelEncoder().fit_transform(df.msgusps)

# %%
df.sample()
# Out:
#       total_dwelling_units  acc_units  total_occupied  regular_vacant  \
# 8448                    20         20              16               0
#
#       total_units  pct_occupied  number_reported  pct_reported  \
# 8448           21     76.190002               16         100.0
#
#       months_since_report  pct_movein  people_per_unit  people_total  \
# 8448                 12.0         0.0              1.6          25.0
#
#       rent_per_month  spending_per_month  spending_per_month_prev_yr  \
# 8448           195.0              2392.0                      1983.0
#
#       hh_income  person_income  pct_lt5k  pct_5k_lt10k  pct_10k_lt15k  \
# 8448     8172.0         5230.0      10.0          40.0           30.0
#
#       pct_15k_lt20k  pct_ge20k  pct_wage_major  pct_welfare_major  \
# 8448           10.0       10.0           18.75                0.0
#
#       pct_other_major  pct_median  pct_lt50_median  pct_lt30_median  \
# 8448            43.75        9.63            93.75            93.75
#
#       pct_2adults  pct_1adult  pct_female_head  pct_female_head_child  \
# 8448          0.0       43.75            68.75                  43.75
#
#       pct_disabled_lt62  pct_disabled_ge62  pct_disabled_all  pct_lt24_head  \
# 8448              21.43               50.0              20.0           25.0
#
#       pct_age25_50  pct_age51_61  pct_age62plus  pct_age85plus  pct_minority  \
# 8448          37.5          25.0           12.5            0.0         100.0
#
#       pct_black  pct_native_american  pct_asian  pct_hispanic  months_waiting  \
# 8448      93.75                  0.0        0.0          6.25             0.0
#
#       months_from_movein  pct_utility_allow  ave_util_allow  pct_bed1  \
# 8448               141.0                0.0             0.0     56.25
#
#       pct_bed2  pct_bed3  pct_overhoused  tminority   tpoverty  tpct_ownsfd  \
# 8448     43.75       0.0             0.0  57.599998  28.200001        36.57
#
#       chldrn_mbr_cnt  eldly_prcnt  pct_disabled_lt62_all  pct_lt80_median  \
# 8448             9.0          8.0                   16.0            100.0
#
#       median_inc_amnt  dpvact  dpvnost  metro  micro  dpv  dpvrc  urb_out  \
# 8448           7006.0     NaN      NaN    1.0    0.0  NaN    NaN      NaN
#
#       std_zip5  std_zip9  msgusps  annl_expns_amnt  annl_expns_amnt_prev_yr  \
# 8448   15212.0    3945.0        7         459269.0                 404540.0
#
#       pha_total_units  house_fires  cooking_fires  all_fires  \
# 8448             3154            0              0          0
#
#       house_fires_20-21  cooking_fires_20-21  all_fires_20-21  \
# 8448                  0                    0                0
#
#       construction_year  dofa_actual_year  \
# 8448             1944.0            1944.0
#
#       msa_nm_Allentown-Bethlehem-Easton, PA MSA  msa_nm_Altoona, PA MSA  \
# 8448                                          0                       0
#
#       msa_nm_Erie, PA MSA  msa_nm_Harrisburg-Lebanon-Carlisle, PA MSA  \
# 8448                    0                                           0
#
#       msa_nm_Johnstown, PA MSA  msa_nm_Lancaster, PA MSA  \
# 8448                         0                         0
#
#       msa_nm_MISSING_VALUE  msa_nm_Philadelphia, PA-NJ PMSA  \
# 8448                     0                                0
#
#       msa_nm_Pittsburgh, PA MSA  msa_nm_Reading, PA MSA  \
# 8448                          1                       0
#
#       msa_nm_Scranton--Wilkes-Barre--Hazleton, PA MSA  msa_nm_Sharon, PA MSA  \
# 8448                                                0                      0
#
#       msa_nm_Williamsport, PA MSA  msa_nm_York, PA MSA  building_type_code_ES  \
# 8448                            0                    0                      0
#
#       building_type_code_RW  building_type_code_SD  building_type_code_SF  \
# 8448                      0                      0                      0
#
#       building_type_code_WU  building_status_type_code_DDAPRD  \
# 8448                      1                                 1
#
#       building_status_type_code_DDDRFT  building_status_type_code_DDPROP  \
# 8448                                 0                                 0
#
#       building_status_type_code_INAPCP  building_status_type_code_RMIPRP  \
# 8448                                 0                                 0
#
#       formal_participant_name_ALLEGHENY COUNTY HOUSING AUTHORITY  \
# 8448                                                  0
#
#       formal_participant_name_ALTOONA HOUSING AUTHORITY  \
# 8448                                                  0
#
#       formal_participant_name_Allentown Housing Authority  \
# 8448                                                  0
#
#       formal_participant_name_Bethlehem Housing Authority  \
# 8448                                                  0
#
#       formal_participant_name_Bradford County Housing Authority  \
# 8448                                                  0
#
#       formal_participant_name_Bucks County Housing Authority  \
# 8448                                                  0
#
#       formal_participant_name_CLEARFIELD COUNTY HOUSING AUTHORITY  \
# 8448                                                  0
#
#       formal_participant_name_CONNELLSVILLE HOUSING AUTHORITY  \
# 8448                                                  0
#
#       formal_participant_name_Carbon County Housing Authority  \
# 8448                                                  0
#
#       formal_participant_name_Chester Housing Authority  \
# 8448                                                  0
#
#       formal_participant_name_Columbia County Housing Authority  \
# 8448                                                  0
#
#       formal_participant_name_Easton Housing Authority  \
# 8448                                                 0
#
#       formal_participant_name_FAYETTE COUNTY HOUSING AUTHORITY  \
# 8448                                                  0
#
#       formal_participant_name_HOUSING AUTH CO OF LAWRENCE  \
# 8448                                                  0
#
#       formal_participant_name_HOUSING AUTHORITY OF INDIANA COUNTY  \
# 8448                                                  0
#
#       formal_participant_name_HOUSING AUTHORITY OF THE CITY OF DUBOIS  \
# 8448                                                  0
#
#       formal_participant_name_HOUSING AUTHORITY OF THE CITY OF ERIE  \
# 8448                                                  0
#
#       formal_participant_name_HOUSING AUTHORITY OF THE CITY OF FRANKLIN  \
# 8448                                                  0
#
#       formal_participant_name_HOUSING AUTHORITY OF THE CITY OF MCKEESPORT  \
# 8448                                                  0
#
#       formal_participant_name_HOUSING AUTHORITY OF THE CITY OF MEADVILLE  \
# 8448                                                  0
#
#       formal_participant_name_HOUSING AUTHORITY OF THE CITY OF OIL CITY  \
# 8448                                                  0
#
#       formal_participant_name_HOUSING AUTHORITY OF THE COUNTY OF BEAVER  \
# 8448                                                  0
#
#       formal_participant_name_HOUSING AUTHORITY OF THE COUNTY OF BEDFORD  \
# 8448                                                  0
#
#       formal_participant_name_HOUSING AUTHORITY OF THE COUNTY OF BLAIR  \
# 8448                                                  0
#
#       formal_participant_name_HOUSING AUTHORITY OF THE COUNTY OF ELK  \
# 8448                                                  0
#
#       formal_participant_name_HOUSING AUTHORITY OF THE COUNTY OF ERIE  \
# 8448                                                  0
#
#       formal_participant_name_HOUSING AUTHORITY OF THE COUNTY OF GREENE  \
# 8448                                                  0
#
#       formal_participant_name_HOUSING AUTHORITY OF THE COUNTY OF HUNTINGDON  \
# 8448                                                  0
#
#       formal_participant_name_HOUSING AUTHORITY OF THE COUNTY OF JEFFERSON  \
# 8448                                                  0
#
#       formal_participant_name_HOUSING AUTHORITY OF THE COUNTY OF MCKEAN  \
# 8448                                                  0
#
#       formal_participant_name_HOUSING AUTHORITY OF THE COUNTY OF WARREN  \
# 8448                                                  0
#
#       formal_participant_name_Harrisburg Housing Authority  \
# 8448                                                  0
#
#       formal_participant_name_Housing Auth of the County of Northumberland  \
# 8448                                                  0
#
#       formal_participant_name_Housing Authority County of Delaware  \
# 8448                                                  0
#
#       formal_participant_name_Housing Authority of the City of Pittsburgh  \
# 8448                                                  1
#
#       formal_participant_name_Housing Authority of the City of Pittston  \
# 8448                                                  0
#
#       formal_participant_name_Housing Authority of the City of Pottsville  \
# 8448                                                  0
#
#       formal_participant_name_Housing Authority of the City of York  \
# 8448                                                  0
#
#       formal_participant_name_Housing Authority of the County of Armstrong  \
# 8448                                                  0
#
#       formal_participant_name_Housing Authority of the County of Berks  \
# 8448                                                  0
#
#       formal_participant_name_Housing Authority of the County of Chester  \
# 8448                                                  0
#
#       formal_participant_name_Housing Authority of the County of Cumberland  \
# 8448                                                  0
#
#       formal_participant_name_Housing Authority of the County of Dauphin  \
# 8448                                                  0
#
#       formal_participant_name_Housing Authority of the County of Franklin  \
# 8448                                                  0
#
#       formal_participant_name_Housing Authority of the County of Lebanon  \
# 8448                                                  0
#
#       formal_participant_name_Housing Authority of the County of Luzerne  \
# 8448                                                  0
#
#       formal_participant_name_Housing Authority of the County of Lycoming  \
# 8448                                                  0
#
#       formal_participant_name_JOHNSTOWN HOUSING AUTHORITY  \
# 8448                                                  0
#
#       formal_participant_name_Lackawanna County Housing Authority  \
# 8448                                                  0
#
#       formal_participant_name_Lehigh County Housing Authority  \
# 8448                                                  0
#
#       formal_participant_name_MERCER COUNTY HOUSING AUTHORITY  \
# 8448                                                  0
#
#       formal_participant_name_Montgomery County Housing Authority  \
# 8448                                                  0
#
#       formal_participant_name_Northampton County Housing Authority  \
# 8448                                                  0
#
#       formal_participant_name_Philadelphia Housing Authority  \
# 8448                                                  0
#
#       formal_participant_name_Reading Housing Authority  \
# 8448                                                  0
#
#       formal_participant_name_SOMERSET COUNTY HOUSING AUTHORITY  \
# 8448                                                  0
#
#       formal_participant_name_Schuylkill County Housing Authority  \
# 8448                                                  0
#
#       formal_participant_name_Scranton Housing Authority  \
# 8448                                                  0
#
#       formal_participant_name_Shamokin Housing Authority  \
# 8448                                                  0
#
#       formal_participant_name_Snyder County Housing Authority  \
# 8448                                                  0
#
#       formal_participant_name_Sunbury Housing Authority  \
# 8448                                                  0
#
#       formal_participant_name_TITUSVILLE HOUSING AUTHORITY  \
# 8448                                                  0
#
#       formal_participant_name_The Housing Auth of the City of Carbondale  \
# 8448                                                  0
#
#       formal_participant_name_The Housing Auth of the City of Lancaster  \
# 8448                                                  0
#
#       formal_participant_name_The Housing Auth of the City of Nanticoke  \
# 8448                                                  0
#
#       formal_participant_name_The Housing Auth of the County of Mifflin  \
# 8448                                                  0
#
#       formal_participant_name_The Housing Authority of Clinton County  \
# 8448                                                  0
#
#       formal_participant_name_The Housing Authority of Monroe County  \
# 8448                                                  0
#
#       formal_participant_name_The Housing Authority of Montour County  \
# 8448                                                  0
#
#       formal_participant_name_The Housing Authority of the City of Hazleton  \
# 8448                                                  0
#
#       formal_participant_name_The Wyoming Co Housing & Redevelopment Auth  \
# 8448                                                  0
#
#       formal_participant_name_Tioga County Housing Authority  \
# 8448                                                  0
#
#       formal_participant_name_WASHINGTON COUNTY HOUSING AUTHORITY  \
# 8448                                                  0
#
#       formal_participant_name_WESTMORELAND COUNTY HSG AUTHORITY  \
# 8448                                                  0
#
#       formal_participant_name_Wilkes Barre Housing Authority  addr_type_H  \
# 8448                                                  0                 1
#
#       addr_type_MISSING_VALUE  addr_type_S  apt_type_Apt  \
# 8448                        0            0             0
#
#       apt_type_MISSING_VALUE  apt_type_Ste  apt_type_Unit  \
# 8448                       1             0              0
#
#       zip_class_MISSING_VALUE  zip_class_P  lvl2kx_4  lvl2kx_B  lvl2kx_R  \
# 8448                        1            0         0         0         1
#
#       lvl2kx_T  ur_MISSING_VALUE  ur_R  ur_U  \
# 8448         0                 0     0     1
#
#       msg2kx_**  Centroid Lat/Long   **  msg2kx_** Street-Level Rooftop **  \
# 8448                                  0                                  1
#
#       rad_chap_indr_N  rad_chap_indr_Y  rad_type_   rad_type_PBRA  \
# 8448                1                0           1              0
#
#       rad_type_PBV
# 8448             0

# %%
import pandas as pd
import numpy as np
from scipy import stats

# Sample dataframe
# df = pd.DataFrame({ ... })

# Compute the Spearman correlation
correlations = df.corrwith(df['house_fires'], method='spearman').drop('house_fires')

# Compute the significance
n = len(df)
# The t-statistic formula remains the same since the Spearman rank correlation is distributed in a manner similar to the Pearson correlation under the null hypothesis.
t_stats = correlations * np.sqrt((n-2) / (1-correlations**2))
p_values = 2*(1 - stats.t.cdf(np.abs(t_stats), df=n-2))  # two-tailed

# Create results dataframe
results_df = pd.DataFrame({
    'Correlation': correlations,
    'p-value': p_values
})

# Filter out columns with insignificant correlations (e.g., p-value > 0.05)
significant_results = results_df[results_df['p-value'] < 0.05]

significant_results.sort_values('Correlation')
# Out:
#                                                     Correlation       p-value
# people_per_unit                                       -0.214615  0.000000e+00
# chldrn_mbr_cnt                                        -0.212386  0.000000e+00
# pct_female_head_child                                 -0.211974  0.000000e+00
# pct_1adult                                            -0.208162  0.000000e+00
# pct_overhoused                                        -0.205147  0.000000e+00
# pct_age25_50                                          -0.200318  0.000000e+00
# pct_female_head                                       -0.191260  0.000000e+00
# pct_bed2                                              -0.184268  0.000000e+00
# pct_welfare_major                                     -0.169022  0.000000e+00
# pct_bed3                                              -0.160264  0.000000e+00
# addr_type_S                                           -0.153815  0.000000e+00
# pct_wage_major                                        -0.148670  0.000000e+00
# pct_minority                                          -0.131580  0.000000e+00
# spending_per_month                                    -0.126298  0.000000e+00
# tminority                                             -0.111665  0.000000e+00
# spending_per_month_prev_yr                            -0.107052  0.000000e+00
# months_from_movein                                    -0.104349  0.000000e+00
# pct_ge20k                                             -0.101008  0.000000e+00
# tpoverty                                              -0.096172  0.000000e+00
# pct_lt5k                                              -0.093465  0.000000e+00
# pct_2adults                                           -0.091603  0.000000e+00
# pct_black                                             -0.086700  0.000000e+00
# pct_occupied                                          -0.076708  6.661338e-16
# pct_lt24_head                                         -0.073945  7.327472e-15
# pct_reported                                          -0.068206  7.247536e-13
# months_since_report                                   -0.060367  2.173655e-10
# msgusps                                               -0.058846  6.083671e-10
# building_type_code_RW                                 -0.041270  1.437841e-05
# std_zip9                                              -0.040416  2.154917e-05
# msg2kx_**  Centroid Lat/Long   **                     -0.035227  2.135959e-04
# building_type_code_SD                                 -0.033552  4.215211e-04
# pct_hispanic                                          -0.032823  5.614603e-04
# addr_type_MISSING_VALUE                               -0.027857  3.417344e-03
# pha_total_units                                       -0.027223  4.226102e-03
# lvl2kx_T                                              -0.027098  4.403204e-03
# formal_participant_name_Housing Authority of th...    -0.026574  5.228956e-03
# lvl2kx_4                                              -0.025412  7.575932e-03
# formal_participant_name_HOUSING AUTHORITY OF TH...    -0.025201  8.091655e-03
# building_type_code_SF                                 -0.023914  1.197053e-02
# msa_nm_Erie, PA MSA                                   -0.023036  1.549236e-02
# apt_type_Apt                                          -0.021979  2.091165e-02
# pct_utility_allow                                     -0.021311  2.513358e-02
# formal_participant_name_Philadelphia Housing Au...    -0.019517  4.028846e-02
# formal_participant_name_FAYETTE COUNTY HOUSING ...    -0.019355  4.197437e-02
# ave_util_allow                                        -0.019349  4.203172e-02
# building_type_code_WU                                  0.018712  4.926953e-02
# dofa_actual_year                                       0.019977  3.580175e-02
# pct_lt30_median                                        0.019978  3.579168e-02
# formal_participant_name_Housing Authority Count...     0.020876  2.826110e-02
# formal_participant_name_The Wyoming Co Housing ...     0.022748  1.682801e-02
# apt_type_MISSING_VALUE                                 0.022847  1.635917e-02
# construction_year                                      0.022868  1.625924e-02
# formal_participant_name_Housing Authority of th...     0.022993  1.568283e-02
# formal_participant_name_HOUSING AUTHORITY OF TH...     0.024761  9.267114e-03
# formal_participant_name_Housing Authority of th...     0.027942  3.320485e-03
# median_inc_amnt                                        0.031222  1.033565e-03
# lvl2kx_R                                               0.035227  2.135959e-04
# msg2kx_** Street-Level Rooftop **                      0.035227  2.135959e-04
# formal_participant_name_Northampton County Hous...     0.053989  1.372953e-08
# pct_age51_61                                           0.070788  9.547918e-14
# msa_nm_Scranton--Wilkes-Barre--Hazleton, PA MSA        0.073017  1.576517e-14
# tpct_ownsfd                                            0.074043  6.661338e-15
# total_occupied                                         0.086686  0.000000e+00
# number_reported                                        0.086959  0.000000e+00
# formal_participant_name_Lehigh County Housing A...     0.087732  0.000000e+00
# regular_vacant                                         0.088335  0.000000e+00
# pct_age85plus                                          0.092017  0.000000e+00
# pct_15k_lt20k                                          0.097829  0.000000e+00
# total_units                                            0.101326  0.000000e+00
# total_dwelling_units                                   0.102071  0.000000e+00
# acc_units                                              0.102269  0.000000e+00
# pct_disabled_lt62_all                                  0.110385  0.000000e+00
# pct_movein                                             0.114476  0.000000e+00
# pct_asian                                              0.114686  0.000000e+00
# formal_participant_name_Housing Authority of th...     0.124250  0.000000e+00
# formal_participant_name_HOUSING AUTHORITY OF TH...     0.128291  0.000000e+00
# months_waiting                                         0.143853  0.000000e+00
# annl_expns_amnt_prev_yr                                0.147900  0.000000e+00
# pct_10k_lt15k                                          0.152917  0.000000e+00
# annl_expns_amnt                                        0.159775  0.000000e+00
# pct_age62plus                                          0.165699  0.000000e+00
# pct_native_american                                    0.170403  0.000000e+00
# pct_other_major                                        0.170921  0.000000e+00
# person_income                                          0.171481  0.000000e+00
# eldly_prcnt                                            0.174685  0.000000e+00
# people_total                                           0.178952  0.000000e+00
# cooking_fires_20-21                                    0.191014  0.000000e+00
# addr_type_H                                            0.196053  0.000000e+00
# building_type_code_ES                                  0.200850  0.000000e+00
# pct_disabled_all                                       0.201078  0.000000e+00
# pct_disabled_lt62                                      0.213956  0.000000e+00
# pct_bed1                                               0.216787  0.000000e+00
# cooking_fires                                          0.315494  0.000000e+00
# house_fires_20-21                                      0.325635  0.000000e+00
# all_fires_20-21                                        0.507979  0.000000e+00
# all_fires                                              0.507979  0.000000e+00

# %%
df.to_csv('pa_fires_in_ph_clean.csv', index=False)
