# %%
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
import numpy as np
import re
import seaborn as sns
import time
import requests
from sklearn.preprocessing import LabelEncoder
from scipy import stats

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('./fires_in_ph.csv')
# Out:
# C:\Users\jackv\AppData\Local\Temp\ipykernel_23696\2703195330.py:1: DtypeWarning: Columns (99,104,109) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./fires_in_ph.csv')

# %% [markdown]
# -4 indicates the value was anonymized because the property had 10 or fewer residents.

# %%
df = df.replace(-4, np.nan)

# %%
df = df[
    (df.std_st == 'PA') |
    (df.std_st == 'MA') |
    (df.std_st == 'NY') |
    (df.std_st == 'IL')
]

# %% [markdown]
# The majority of many columns have a -4 value, which indicates the information was hidden for privacy reasons, which occurs when the number of residents is fewer than 10.

# %%
pd.set_option('display.max_rows', 200)
(df.isna().sum() / len(df)).sort_values(ascending=False)
# Out:
# dpvact                        1.000000
# urb_out                       1.000000
# dpvrc                         1.000000
# dpv                           1.000000
# place_inc2kx                  1.000000
# dpvnost                       1.000000
# zip_class                     0.995566
# c1pdrc                        0.964201
# c1pgrc                        0.951979
# c1pzrc                        0.951943
# apt_type                      0.931033
# apt_no                        0.927969
# necta_nm                      0.899344
# c1psrc                        0.883950
# stm2kx                        0.879011
# annl_expns_amnt_prev_yr       0.865527
# pct_utility_allow             0.865455
# pct_disabled_ge62             0.865455
# pct_disabled_all              0.865455
# pct_lt24_head                 0.865455
# pct_age25_50                  0.865455
# pct_age51_61                  0.865455
# pct_age62plus                 0.865455
# pct_age85plus                 0.865455
# pct_minority                  0.865455
# pct_black                     0.865455
# pct_native_american           0.865455
# pct_asian                     0.865455
# pct_hispanic                  0.865455
# months_from_movein            0.865455
# tpct_ownsfd                   0.865455
# ave_util_allow                0.865455
# pct_bed1                      0.865455
# pct_bed2                      0.865455
# pct_bed3                      0.865455
# pct_overhoused                0.865455
# tminority                     0.865455
# tpoverty                      0.865455
# pct_female_head_child         0.865455
# chldrn_mbr_cnt                0.865455
# eldly_prcnt                   0.865455
# pct_disabled_lt62_all         0.865455
# pct_lt80_median               0.865455
# median_inc_amnt               0.865455
# pct_disabled_lt62             0.865455
# months_waiting                0.865455
# pct_female_head               0.865455
# pct_lt5k                      0.865455
# pct_reported                  0.865455
# months_since_report           0.865455
# pct_movein                    0.865455
# people_per_unit               0.865455
# people_total                  0.865455
# rent_per_month                0.865455
# spending_per_month            0.865455
# spending_per_month_prev_yr    0.865455
# hh_income                     0.865455
# annl_expns_amnt               0.865455
# person_income                 0.865455
# pct_median                    0.865455
# pct_other_major               0.865455
# pct_2adults                   0.865455
# pct_lt30_median               0.865455
# pct_lt50_median               0.865455
# pct_5k_lt10k                  0.865455
# pct_1adult                    0.865455
# pct_welfare_major             0.865455
# pct_wage_major                0.865455
# pct_ge20k                     0.865455
# pct_15k_lt20k                 0.865455
# pct_10k_lt15k                 0.865455
# exec_dir_fax                  0.398623
# building_name                 0.352657
# msa_nm                        0.284447
# construct_date                0.179141
# c1parc                        0.144711
# ha_fax_num                    0.092833
# cbsa_nm                       0.061035
# hlc                           0.052924
# c1pprb                        0.048021
# block2kx                      0.047408
# dpbc_cksum                    0.045173
# std_zip11                     0.045173
# dpbc                          0.045137
# std_addr                      0.045137
# addr_type                     0.040522
# std_zip9                      0.040522
# bg2kx                         0.039008
# blkgrp_level                  0.039008
# national_bldg_id              0.005011
# exec_dir_phone                0.001550
# exec_dir_email                0.001550
# curcosub_nm                   0.001009
# dofa_actual_dt                0.001009
# zcta2kx                       0.000541
# place_cc2kx                   0.000541
# place_nm2kx                   0.000541
# place_level                   0.000541
# place2kx                      0.000541
# ur                            0.000541
# ha_email_addr_text            0.000397
# fcd_fips91                    0.000036
# building_fires_11_19          0.000000
# pha_total_units               0.000000
# ha_phn_num                    0.000000
# dev_buil_nu_entrance          0.000000
# msgusps                       0.000000
# lat                           0.000000
# lon                           0.000000
# rc2kx                         0.000000
# lvl2kx                        0.000000
# msg2kx                        0.000000
# county_level                  0.000000
# tract_level                   0.000000
# last_updt_dttm                0.000000
# rad_type                      0.000000
# rad_chap_indr                 0.000000
# x                             0.000000
# state2kx                      0.000000
# std_zip5                      0.000000
# pct_occupied                  0.000000
# objectid                      0.000000
# participant_code              0.000000
# formal_participant_name       0.000000
# development_code              0.000000
# project_name                  0.000000
# building_number               0.000000
# building_type_code            0.000000
# building_status_type_code     0.000000
# total_dwelling_units          0.000000
# acc_units                     0.000000
# total_occupied                0.000000
# regular_vacant                0.000000
# total_units                   0.000000
# number_reported               0.000000
# std_st                        0.000000
# y                             0.000000
# cnty_nm2kx                    0.000000
# cnty2kx                       0.000000
# tract2kx                      0.000000
# curcnty_nm                    0.000000
# curcnty                       0.000000
# curcosub                      0.000000
# msa                           0.000000
# cbsa                          0.000000
# necta                         0.000000
# metro                         0.000000
# micro                         0.000000
# std_city                      0.000000
# building_fires_20_21          0.000000
# dtype: float64

# %%
columns_to_drop = [
    'x', 'y', 'objectid', 'participant_code', 'std_addr', 'apt_no', 'rc2kx', 'stm2kx',
    'dev_buil_nu_entrance', 'ha_phn_num', 'ha_fax_num', 'ha_email_addr_text',
    'exec_dir_phone', 'exec_dir_fax', 'exec_dir_email',
    'lat', 'lon', 'c1pgrc', 'c1pprb', 'c1pdrc', 'c1psrc', 'c1parc', 'c1pzrc',
    'project_name', 'building_name', 'building_number',
    'zcta2kx', 'dpbc', 'dpbc_cksum', 'std_zip11',
    'national_bldg_id', 'curcnty_nm', 'curcnty', 'curcosub', 'curcosub_nm',
    'place2kx', 'place_nm2kx', 'msa', 'cbsa', 'necta', 'necta_nm', 'last_updt_dttm', 
    'development_code',
    'state2kx', 'cnty_nm2kx','cnty2kx','tract2kx','bg2kx','block2kx',
    'fcd_fips91','hlc', 'std_city',
    'county_level'	,'place_level',	'tract_level',	'blkgrp_level',
    'place_cc2kx', 'place_inc2kx', 'formal_participant_name',
    'cbsa_nm', 'urb_out']

df.drop(columns=columns_to_drop, inplace=True)

# %%
df['construction_year'] = pd.to_datetime(df['construct_date']).dt.year
df['dofa_actual_year'] = pd.to_datetime(df['dofa_actual_dt']).dt.year
df = df.drop(['construct_date', 'dofa_actual_dt'], axis=1)

# %%
df.sample()
# Out:
#       building_type_code building_status_type_code  total_dwelling_units  \
# 15258                 SF                    INAPCP                     1
#
#        acc_units  total_occupied  regular_vacant  total_units  pct_occupied  \
# 15258          1               1               0            1         100.0
#
#        number_reported  pct_reported  months_since_report  pct_movein  \
# 15258                1           NaN                  NaN         NaN
#
#        people_per_unit  people_total  rent_per_month  spending_per_month  \
# 15258              NaN           NaN             NaN                 NaN
#
#        spending_per_month_prev_yr  hh_income  person_income  pct_lt5k  \
# 15258                         NaN        NaN            NaN       NaN
#
#        pct_5k_lt10k  pct_10k_lt15k  pct_15k_lt20k  pct_ge20k  pct_wage_major  \
# 15258           NaN            NaN            NaN        NaN             NaN
#
#        pct_welfare_major  pct_other_major  pct_median  pct_lt50_median  \
# 15258                NaN              NaN         NaN              NaN
#
#        pct_lt30_median  pct_2adults  pct_1adult  pct_female_head  \
# 15258              NaN          NaN         NaN              NaN
#
#        pct_female_head_child  pct_disabled_lt62  pct_disabled_ge62  \
# 15258                    NaN                NaN                NaN
#
#        pct_disabled_all  pct_lt24_head  pct_age25_50  pct_age51_61  \
# 15258               NaN            NaN           NaN           NaN
#
#        pct_age62plus  pct_age85plus  pct_minority  pct_black  \
# 15258            NaN            NaN           NaN        NaN
#
#        pct_native_american  pct_asian  pct_hispanic  months_waiting  \
# 15258                  NaN        NaN           NaN             NaN
#
#        months_from_movein  pct_utility_allow  ave_util_allow  pct_bed1  \
# 15258                 NaN                NaN             NaN       NaN
#
#        pct_bed2  pct_bed3  pct_overhoused  tminority  tpoverty  tpct_ownsfd  \
# 15258       NaN       NaN             NaN        NaN       NaN          NaN
#
#        chldrn_mbr_cnt  eldly_prcnt  pct_disabled_lt62_all  pct_lt80_median  \
# 15258             NaN          NaN                    NaN              NaN
#
#        median_inc_amnt  dpvact  dpvnost msa_nm  metro  micro  dpv  dpvrc  \
# 15258              NaN     NaN      NaN    NaN    1.0    0.0  NaN    NaN
#
#       std_st  std_zip5  std_zip9 zip_class addr_type apt_type  \
# 15258     IL   62053.0    1000.0       NaN         S      NaN
#
#                                 msgusps lvl2kx ur                      msg2kx  \
# 15258  90% Overall probable correctness      R  R  ** Street-Level Rooftop **
#
#       rad_chap_indr rad_type  annl_expns_amnt  annl_expns_amnt_prev_yr  \
# 15258             N                       NaN                      NaN
#
#        pha_total_units  building_fires_11_19  building_fires_20_21  \
# 15258               43                     0                     0
#
#        construction_year  dofa_actual_year
# 15258             1954.0            1954.0

# %%
# Assuming your dataframe is named df
placeholder = "MISSING_VALUE"  # or any other string you'd like to use as placeholder

# List of columns to be one-hot encoded
columns_to_encode = [
    'std_st', 'building_type_code', 
    'building_status_type_code', 
    'addr_type', 'apt_type', 'zip_class', 'lvl2kx', 'ur', 'msg2kx', 
    'rad_chap_indr', 'rad_type'
]

# Fill NaN values with placeholder
for column in columns_to_encode:
    df[column] = df[column].fillna(placeholder)

# One-hot encode the columns
for column in columns_to_encode:
    dummies = pd.get_dummies(df[column], prefix=column)
    df = pd.concat([df, dummies], axis=1)
    df.drop([column], axis=1, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

df.msgusps = LabelEncoder().fit_transform(df.msgusps)
df.msa_nm = LabelEncoder().fit_transform(df.msa_nm)

# %%
df.sample()
# Out:
#         total_dwelling_units  acc_units  total_occupied  regular_vacant  \
# 105350                     1          1               0               1
#
#         total_units  pct_occupied  number_reported  pct_reported  \
# 105350            1           0.0                0           NaN
#
#         months_since_report  pct_movein  people_per_unit  people_total  \
# 105350                  NaN         NaN              NaN           NaN
#
#         rent_per_month  spending_per_month  spending_per_month_prev_yr  \
# 105350             NaN                 NaN                         NaN
#
#         hh_income  person_income  pct_lt5k  pct_5k_lt10k  pct_10k_lt15k  \
# 105350        NaN            NaN       NaN           NaN            NaN
#
#         pct_15k_lt20k  pct_ge20k  pct_wage_major  pct_welfare_major  \
# 105350            NaN        NaN             NaN                NaN
#
#         pct_other_major  pct_median  pct_lt50_median  pct_lt30_median  \
# 105350              NaN         NaN              NaN              NaN
#
#         pct_2adults  pct_1adult  pct_female_head  pct_female_head_child  \
# 105350          NaN         NaN              NaN                    NaN
#
#         pct_disabled_lt62  pct_disabled_ge62  pct_disabled_all  pct_lt24_head  \
# 105350                NaN                NaN               NaN            NaN
#
#         pct_age25_50  pct_age51_61  pct_age62plus  pct_age85plus  \
# 105350           NaN           NaN            NaN            NaN
#
#         pct_minority  pct_black  pct_native_american  pct_asian  pct_hispanic  \
# 105350           NaN        NaN                  NaN        NaN           NaN
#
#         months_waiting  months_from_movein  pct_utility_allow  ave_util_allow  \
# 105350             NaN                 NaN                NaN             NaN
#
#         pct_bed1  pct_bed2  pct_bed3  pct_overhoused  tminority  tpoverty  \
# 105350       NaN       NaN       NaN             NaN        NaN       NaN
#
#         tpct_ownsfd  chldrn_mbr_cnt  eldly_prcnt  pct_disabled_lt62_all  \
# 105350          NaN             NaN          NaN                    NaN
#
#         pct_lt80_median  median_inc_amnt  dpvact  dpvnost  msa_nm  metro  \
# 105350              NaN              NaN     NaN      NaN      27    1.0
#
#         micro  dpv  dpvrc  std_zip5  std_zip9  msgusps  annl_expns_amnt  \
# 105350    0.0  NaN    NaN   19121.0    1422.0        7              NaN
#
#         annl_expns_amnt_prev_yr  pha_total_units  building_fires_11_19  \
# 105350                      NaN            12799                     0
#
#         building_fires_20_21  construction_year  dofa_actual_year  std_st_IL  \
# 105350                     0             1969.0            1969.0          0
#
#         std_st_MA  std_st_NY  std_st_PA  building_type_code_ES  \
# 105350          0          0          1                      0
#
#         building_type_code_RW  building_type_code_SD  building_type_code_SF  \
# 105350                      1                      0                      0
#
#         building_type_code_WU  building_type_code_sf  \
# 105350                      0                      0
#
#         building_status_type_code_DDAPRD  building_status_type_code_DDDRFT  \
# 105350                                 0                                 0
#
#         building_status_type_code_DDPROP  building_status_type_code_INAPCP  \
# 105350                                 0                                 1
#
#         building_status_type_code_RMI  building_status_type_code_RMIPRP  \
# 105350                              0                                 0
#
#         addr_type_F  addr_type_G  addr_type_H  addr_type_MISSING_VALUE  \
# 105350            0            0            0                        0
#
#         addr_type_R  addr_type_S  apt_type_#  apt_type_Apt  \
# 105350            0            1           0             0
#
#         apt_type_MISSING_VALUE  apt_type_Ste  apt_type_Unit  \
# 105350                       1             0              0
#
#         zip_class_MISSING_VALUE  zip_class_P  lvl2kx_4  lvl2kx_B  lvl2kx_R  \
# 105350                        1            0         0         0         1
#
#         lvl2kx_T  ur_MISSING_VALUE  ur_R  ur_U  \
# 105350         0                 0     0     1
#
#         msg2kx_**  Centroid Lat/Long   **  msg2kx_** Street-Level Rooftop **  \
# 105350                                  0                                  1
#
#         rad_chap_indr_N  rad_chap_indr_Y  rad_type_   rad_type_PBRA  \
# 105350                1                0           1              0
#
#         rad_type_PBV
# 105350             0

# %%
correlations = df.corrwith(df['building_fires_11_19'], method='spearman').drop('building_fires_11_19')

n = len(df)

t_stats = correlations * np.sqrt((n-2) / (1-correlations**2))
p_values = 2*(1 - stats.t.cdf(np.abs(t_stats), df=n-2))  # two-tailed

results_df = pd.DataFrame({
    'Correlation': correlations,
    'p-value': p_values
})

significant_results = results_df[results_df['p-value'] < 0.05]

significant_results.sort_values('Correlation')
# Out:
#                                    Correlation       p-value
# people_per_unit                      -0.316708  0.000000e+00
# months_from_movein                   -0.315583  0.000000e+00
# chldrn_mbr_cnt                       -0.312164  0.000000e+00
# pct_overhoused                       -0.309704  0.000000e+00
# pct_female_head                      -0.309231  0.000000e+00
# rent_per_month                       -0.299415  0.000000e+00
# pct_female_head_child                -0.290369  0.000000e+00
# pct_1adult                           -0.289612  0.000000e+00
# hh_income                            -0.287914  0.000000e+00
# pct_ge20k                            -0.285671  0.000000e+00
# pct_wage_major                       -0.279625  0.000000e+00
# pct_bed2                             -0.275558  0.000000e+00
# pct_median                           -0.268882  0.000000e+00
# pct_bed3                             -0.257352  0.000000e+00
# pct_minority                         -0.255385  0.000000e+00
# pct_welfare_major                    -0.241957  0.000000e+00
# tminority                            -0.230987  0.000000e+00
# pct_age25_50                         -0.224679  0.000000e+00
# median_inc_amnt                      -0.222915  0.000000e+00
# pct_2adults                          -0.186350  0.000000e+00
# spending_per_month                   -0.186014  0.000000e+00
# spending_per_month_prev_yr           -0.176379  0.000000e+00
# pct_hispanic                         -0.172126  0.000000e+00
# addr_type_S                          -0.139975  0.000000e+00
# pct_black                            -0.115931  0.000000e+00
# building_type_code_RW                -0.085693  0.000000e+00
# pct_lt24_head                        -0.077245  0.000000e+00
# pct_5k_lt10k                         -0.076617  0.000000e+00
# tpoverty                             -0.070969  0.000000e+00
# pct_lt5k                             -0.066876  0.000000e+00
# pct_asian                            -0.057794  0.000000e+00
# pct_occupied                         -0.057358  0.000000e+00
# msg2kx_**  Centroid Lat/Long   **    -0.055823  0.000000e+00
# building_type_code_SD                -0.051894  0.000000e+00
# months_since_report                  -0.047510  2.442491e-15
# lvl2kx_4                             -0.043477  4.352074e-13
# apt_type_Apt                         -0.041336  5.696776e-12
# ur_R                                 -0.036396  1.332796e-09
# building_type_code_SF                -0.034967  5.707802e-09
# addr_type_MISSING_VALUE              -0.033593  2.192002e-08
# lvl2kx_T                             -0.032933  4.107075e-08
# msa_nm                               -0.031997  9.811998e-08
# std_zip5                             -0.030258  4.647991e-07
# std_st_IL                            -0.022695  1.567737e-04
# std_st_NY                            -0.019800  9.744708e-04
# micro                                -0.016672  5.490313e-03
# construction_year                     0.012473  3.777016e-02
# building_status_type_code_RMI         0.017224  4.122472e-03
# std_zip9                              0.020848  5.159847e-04
# addr_type_F                           0.025660  1.918868e-05
# metro                                 0.030549  3.604135e-07
# pct_disabled_ge62                     0.032292  7.480158e-08
# annl_expns_amnt                       0.033463  2.483432e-08
# pct_native_american                   0.034466  9.377114e-09
# ur_U                                  0.036613  1.063712e-09
# apt_type_MISSING_VALUE                0.041837  3.155698e-12
# annl_expns_amnt_prev_yr               0.050151  0.000000e+00
# building_type_code_WU                 0.052360  0.000000e+00
# pct_age85plus                         0.053343  0.000000e+00
# std_st_MA                             0.054142  0.000000e+00
# lvl2kx_R                              0.055823  0.000000e+00
# msg2kx_** Street-Level Rooftop **     0.055823  0.000000e+00
# pct_disabled_lt62_all                 0.061705  0.000000e+00
# pct_15k_lt20k                         0.070800  0.000000e+00
# regular_vacant                        0.113434  0.000000e+00
# ave_util_allow                        0.113957  0.000000e+00
# pct_lt30_median                       0.117656  0.000000e+00
# total_occupied                        0.122948  0.000000e+00
# pct_utility_allow                     0.123104  0.000000e+00
# pct_lt80_median                       0.123786  0.000000e+00
# number_reported                       0.124485  0.000000e+00
# person_income                         0.127037  0.000000e+00
# acc_units                             0.130689  0.000000e+00
# total_dwelling_units                  0.130898  0.000000e+00
# total_units                           0.132652  0.000000e+00
# pct_lt50_median                       0.156119  0.000000e+00
# addr_type_H                           0.161071  0.000000e+00
# pct_age62plus                         0.175608  0.000000e+00
# building_type_code_ES                 0.203255  0.000000e+00
# tpct_ownsfd                           0.215646  0.000000e+00
# pct_disabled_all                      0.221594  0.000000e+00
# pct_disabled_lt62                     0.231425  0.000000e+00
# eldly_prcnt                           0.239300  0.000000e+00
# pct_reported                          0.256161  0.000000e+00
# pct_other_major                       0.264933  0.000000e+00
# pct_10k_lt15k                         0.277356  0.000000e+00
# pct_movein                            0.277860  0.000000e+00
# pct_bed1                              0.308222  0.000000e+00
# months_waiting                        0.312104  0.000000e+00
# building_fires_20_21                  0.326121  0.000000e+00

# %%
df.shape
# Out:
# (27738, 121)

# %%
df.to_csv('fires_in_ph_clean_4states.csv', index=False)
