# %%
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
import numpy as np
import re
import seaborn as sns
import time
import requests
from sklearn.preprocessing import LabelEncoder
from scipy import stats
from sklearn.preprocessing import LabelEncoder

pd.set_option('display.max_columns', None)

# %% [markdown]
# This notebook will clean up the combined public housing buildings/developments/agencies datafile so that it is ready to be merged with the FEMA NFIRS dataset in the subsequent dataset.

# %%
public = pd.read_csv('../data/buildings_dev_pha_2.1.csv')
# Out:
# C:\Users\jackv\AppData\Local\Temp\ipykernel_10716\407126396.py:1: DtypeWarning: Columns (104) have mixed types. Specify dtype option on import or set low_memory=False.
#   public = pd.read_csv('./buildings_dev_pha_2.0.csv')

# %%
public.sample()
# Out:
#                  x          y  objectid participant_code  \
# 126037 -111.010191  32.138674    126038            AZ004
#
#                          formal_participant_name development_code  \
# 126037  Housing and Community Development Tucson      AZ004000051
#
#                    project_name building_name building_number  \
# 126037  POSADAS SENTINEL, PH. I        LOGGER             590
#
#        building_type_code building_status_type_code  national_bldg_id  \
# 126037                 SF                    INAPCP      5.944200e+09
#
#                 construct_date          dofa_actual_dt  total_dwelling_units  \
# 126037  2000/10/20 00:00:00+00  2002/09/30 00:00:00+00                     1
#
#         acc_units  total_occupied  regular_vacant  total_units  pct_occupied  \
# 126037          1               1               0            1         100.0
#
#         number_reported  pct_reported  months_since_report  pct_movein  \
# 126037                1          -4.0                   -4        -4.0
#
#         people_per_unit  people_total  rent_per_month  spending_per_month  \
# 126037             -4.0            -4              -4                  -4
#
#         spending_per_month_prev_yr  hh_income  person_income  pct_lt5k  \
# 126037                          -4         -4             -4      -4.0
#
#         pct_5k_lt10k  pct_10k_lt15k  pct_15k_lt20k  pct_ge20k  pct_wage_major  \
# 126037          -4.0           -4.0           -4.0       -4.0            -4.0
#
#         pct_welfare_major  pct_other_major  pct_median  pct_lt50_median  \
# 126037               -4.0             -4.0        -4.0             -4.0
#
#         pct_lt30_median  pct_2adults  pct_1adult  pct_female_head  \
# 126037             -4.0         -4.0        -4.0             -4.0
#
#         pct_female_head_child  pct_disabled_lt62  pct_disabled_ge62  \
# 126037                   -4.0               -4.0               -4.0
#
#         pct_disabled_all  pct_lt24_head  pct_age25_50  pct_age51_61  \
# 126037              -4.0           -4.0          -4.0          -4.0
#
#         pct_age62plus  pct_age85plus  pct_minority  pct_black  \
# 126037           -4.0           -4.0          -4.0       -4.0
#
#         pct_native_american  pct_asian  pct_hispanic  months_waiting  \
# 126037                 -4.0       -4.0          -4.0              -4
#
#         months_from_movein  pct_utility_allow  ave_util_allow  pct_bed1  \
# 126037                  -4               -4.0              -4      -4.0
#
#         pct_bed2  pct_bed3  pct_overhoused  tminority  tpoverty  tpct_ownsfd  \
# 126037      -4.0      -4.0            -4.0       -4.0      -4.0         -4.0
#
#         chldrn_mbr_cnt  eldly_prcnt  pct_disabled_lt62_all  pct_lt80_median  \
# 126037              -4         -4.0                   -4.0             -4.0
#
#         median_inc_amnt  state2kx cnty_nm2kx  cnty2kx  tract2kx  bg2kx  \
# 126037               -4       4.0       Pima     19.0    2506.0    1.0
#
#         block2kx  dpvact  dpvnost curcnty_nm  curcnty  curcosub curcosub_nm  \
# 126037    1000.0     NaN      NaN       Pima     19.0   93570.0      Tucson
#
#         place2kx  place_nm2kx place_cc2kx  place_inc2kx     msa  \
# 126037   77000.0  Tucson city          C1           NaN  8520.0
#
#                 msa_nm     cbsa                                   cbsa_nm  \
# 126037  Tucson, AZ MSA  46060.0  Tucson, AZ Metropolitan Statistical Area
#
#           necta necta_nm  metro  micro fcd_fips91    hlc  dpv  dpvrc  \
# 126037  99999.0      NaN    1.0    0.0       0403  492.0  NaN    NaN
#
#                 std_addr urb_out std_city std_st  std_zip5  std_zip9  \
# 126037  6224 S LOGGER DR     NaN   TUCSON     AZ   85746.0    3404.0
#
#        zip_class  zcta2kx  dpbc  dpbc_cksum     std_zip11 addr_type apt_type  \
# 126037       NaN  85746.0  24.0         3.0  8.574634e+10         S      NaN
#
#        c1pgrc  c1pprb c1pdrc c1psrc c1parc c1pzrc  \
# 126037    NaN     1.0    NaN    NaN      A    NaN
#
#                                  msgusps        lat         lon rc2kx stm2kx  \
# 126037  90% Overall probable correctness  32.138674 -111.010191     S    NaN
#
#        lvl2kx ur                      msg2kx  county_level  place_level  \
# 126037      R  U  ** Street-Level Rooftop **        4019.0     477000.0
#
#          tract_level  blkgrp_level rad_chap_indr rad_type  \
# 126037  4.019003e+09  4.019003e+10             N
#
#                 last_updt_dttm  annl_expns_amnt  annl_expns_amnt_prev_yr  \
# 126037  2023/03/06 08:50:52+00               -4                     -4.0
#
#         pha_total_units dev_buil_nu_entrance  ha_phn_num    ha_fax_num  \
# 126037             1505      AZ0040000515901  5207914171  5.207915e+09
#
#               ha_email_addr_text  exec_dir_phone  exec_dir_fax  \
# 126037  liz.morales@tucsonaz.gov    5.208375e+09           NaN
#
#                   exec_dir_email dev_development_code  \
# 126037  liz.morales@tucsonaz.gov          AZ004000051
#
#         dev_spending_per_month_prev_yr  dev_chldrn_mbr_cnt  \
# 126037                           448.0               264.0
#
#         dev_annl_expns_amnt  dev_annl_expns_amnt_prev_yr  dev_eldly_prcnt  \
# 126037             794050.0                     742107.0             2.58
#
#         dev_pct_disabled_lt62_all  dev_pct_lt80_median  dev_median_inc_amnt  \
# 126037                       8.93                92.75              14126.0
#
#        dev_scattered_site_ind dev_pd_status_type_code  dev_total_units  \
# 126037                      N                       M            201.0
#
#         dev_total_dwelling_units  dev_acc_units  dev_total_occupied  \
# 126037                     200.0          140.0               139.0
#
#         dev_regular_vacant  dev_pha_total_units  dev_pct_occupied  \
# 126037                 1.0               1505.0         99.279999
#
#         dev_number_reported  dev_pct_reported  dev_months_since_report  \
# 126037                138.0             99.29                      5.0
#
#         dev_pct_movein  dev_people_per_unit  dev_people_total  \
# 126037             5.8                  3.7             504.0
#
#         dev_rent_per_month  dev_spending_per_month  dev_hh_income  \
# 126037               497.0                   476.0        20595.0
#
#         dev_person_income  dev_pct_lt5k  dev_pct_5k_lt10k  dev_pct_10k_lt15k  \
# 126037             5639.0         17.89             15.45              13.82
#
#         dev_pct_15k_lt20k  dev_pct_ge20k  dev_pct_wage_major  \
# 126037               7.32          45.53               53.62
#
#         dev_pct_welfare_major  dev_pct_other_major  dev_pct_median  \
# 126037                   3.62                31.16           30.04
#
#         dev_pct_lt50_median  dev_pct_lt30_median  dev_pct_2adults  \
# 126037                78.99                 58.7            13.77
#
#         dev_pct_1adult  dev_pct_female_head  dev_pct_female_head_child  \
# 126037           66.67                88.41                      70.29
#
#         dev_pct_disabled_lt62  dev_pct_disabled_ge62  dev_pct_disabled_all  \
# 126037                  17.32                  72.73                 10.71
#
#         dev_pct_lt24_head  dev_pct_age25_50  dev_pct_age51_61  \
# 126037                0.0             74.64             17.39
#
#         dev_pct_age62plus  dev_pct_age85plus  dev_pct_minority  dev_pct_black  \
# 126037               7.97                0.0             86.23          10.14
#
#         dev_pct_native_american  dev_pct_asian  dev_pct_hispanic  \
# 126037                     0.72           1.45             73.91
#
#         dev_months_waiting  dev_months_from_movein  dev_pct_utility_allow  \
# 126037                83.0                   116.0                  99.28
#
#         dev_ave_util_allow  dev_pct_bed1  dev_pct_bed2  dev_pct_bed3  \
# 126037               381.0           0.0         15.94         84.06
#
#         dev_pct_overhoused  dev_tminority  dev_tpoverty  dev_tpct_ownsfd  \
# 126037               15.94          72.65         27.08            54.46
#
#        pha_participant_code pha_phas_designation  \
# 126037                AZ004   Standard Performer
#
#        pha_ha_low_rent_size_category  pha_section8_units_cnt  \
# 126037           LARGE (1,000-4,999)                    4857
#
#        pha_ha_section_8_size_category pha_ha_combined_size_category  \
# 126037            LARGE (1,000-4,999)          EXTRA LARGE (5,000+)
#
#        pha_ha_fye pha_ha_program_type  pha_section8_occupied  pha_opfund_amnt  \
# 126037       6/30            Combined                   4197          6425754
#
#         pha_opfund_amnt_prev_yr  pha_capfund_amnt  pha_capfund_amnt_prev_yr  \
# 126037                  5294427           3121477                   2546086
#
#         pha_ross_amnt  pha_fss_amnt  pha_chldrn_mbr_cnt  pha_eldly_prcnt  \
# 126037              0             0                5475            13.93
#
#         pha_pct_disabled_lt62_all  pha_pct_lt80_median  pha_median_inc_amnt  \
# 126037                      15.04            96.190002                10340
#
#         pha_annl_expns_amnt  pha_annl_expns_amnt_prev_yr corrected_address  \
# 126037             47749298                   45938090.0  6224 S LOGGER DR
#
#        corrected_unit
# 126037            NaN

# %% [markdown]
# -4 indicates the value was anonymized because the property had 10 or fewer residents.

# %%
public = public.replace(-4, np.nan)

# %%
pd.set_option('display.max_rows', 300)
display((public.isna().sum() / len(public)).sort_values(ascending=False))
pd.set_option('display.max_rows', 10)
# Out:
# dpvrc                             1.000000
# dpv                               1.000000
# place_inc2kx                      1.000000
# dpvnost                           1.000000
# dpvact                            1.000000
# urb_out                           0.999406
# zip_class                         0.993871
# necta_nm                          0.967178
# annl_expns_amnt_prev_yr           0.951648
# pct_disabled_lt62                 0.951528
# pct_age62plus                     0.951528
# pct_age51_61                      0.951528
# pct_age25_50                      0.951528
# pct_lt24_head                     0.951528
# pct_disabled_all                  0.951528
# pct_disabled_ge62                 0.951528
# pct_15k_lt20k                     0.951528
# pct_minority                      0.951528
# pct_female_head_child             0.951528
# pct_female_head                   0.951528
# pct_1adult                        0.951528
# pct_2adults                       0.951528
# pct_lt30_median                   0.951528
# pct_age85plus                     0.951528
# months_waiting                    0.951528
# pct_black                         0.951528
# pct_native_american               0.951528
# pct_asian                         0.951528
# pct_hispanic                      0.951528
# pct_median                        0.951528
# months_from_movein                0.951528
# pct_utility_allow                 0.951528
# ave_util_allow                    0.951528
# pct_bed1                          0.951528
# pct_bed2                          0.951528
# pct_bed3                          0.951528
# pct_overhoused                    0.951528
# tminority                         0.951528
# pct_lt50_median                   0.951528
# tpoverty                          0.951528
# pct_other_major                   0.951528
# people_total                      0.951528
# annl_expns_amnt                   0.951528
# median_inc_amnt                   0.951528
# pct_lt80_median                   0.951528
# pct_disabled_lt62_all             0.951528
# eldly_prcnt                       0.951528
# chldrn_mbr_cnt                    0.951528
# pct_reported                      0.951528
# months_since_report               0.951528
# pct_movein                        0.951528
# pct_welfare_major                 0.951528
# people_per_unit                   0.951528
# rent_per_month                    0.951528
# spending_per_month                0.951528
# spending_per_month_prev_yr        0.951528
# hh_income                         0.951528
# person_income                     0.951528
# pct_lt5k                          0.951528
# pct_5k_lt10k                      0.951528
# pct_10k_lt15k                     0.951528
# tpct_ownsfd                       0.951528
# pct_ge20k                         0.951528
# pct_wage_major                    0.951528
# c1pdrc                            0.946687
# c1pgrc                            0.929166
# c1pzrc                            0.928921
# corrected_unit                    0.914146
# apt_type                          0.882867
# c1psrc                            0.833489
# stm2kx                            0.816593
# building_name                     0.473085
# msa_nm                            0.462954
# exec_dir_fax                      0.315064
# construct_date                    0.209256
# c1parc                            0.206405
# cbsa_nm                           0.140115
# block2kx                          0.089856
# hlc                               0.072616
# c1pprb                            0.070834
# dpbc_cksum                        0.067170
# std_zip11                         0.067170
# std_addr                          0.066926
# corrected_address                 0.066926
# dpbc                              0.065174
# std_zip9                          0.062094
# addr_type                         0.061985
# blkgrp_level                      0.058186
# bg2kx                             0.058186
# dev_annl_expns_amnt_prev_yr       0.024541
# dev_spending_per_month_prev_yr    0.024468
# dev_pct_female_head_child         0.021826
# dev_pct_female_head               0.021826
# dev_pct_median                    0.021826
# dev_pct_1adult                    0.021826
# dev_pct_2adults                   0.021826
# dev_pct_disabled_ge62             0.021826
# dev_pct_lt30_median               0.021826
# dev_pct_disabled_all              0.021826
# dev_pct_lt50_median               0.021826
# dev_pct_lt24_head                 0.021826
# dev_pct_disabled_lt62             0.021826
# dev_pct_lt80_median               0.021826
# dev_pct_other_major               0.021826
# dev_people_total                  0.021826
# dev_pct_15k_lt20k                 0.021826
# dev_pct_10k_lt15k                 0.021826
# dev_pct_5k_lt10k                  0.021826
# dev_pct_lt5k                      0.021826
# dev_person_income                 0.021826
# dev_hh_income                     0.021826
# dev_spending_per_month            0.021826
# dev_rent_per_month                0.021826
# dev_people_per_unit               0.021826
# dev_pct_wage_major                0.021826
# dev_pct_movein                    0.021826
# dev_months_since_report           0.021826
# dev_pct_reported                  0.021826
# dev_median_inc_amnt               0.021826
# dev_pct_welfare_major             0.021826
# dev_pct_disabled_lt62_all         0.021826
# dev_eldly_prcnt                   0.021826
# dev_annl_expns_amnt               0.021826
# dev_chldrn_mbr_cnt                0.021826
# dev_pct_age25_50                  0.021826
# dev_pct_age51_61                  0.021826
# dev_months_from_movein            0.021826
# dev_tpct_ownsfd                   0.021826
# dev_pct_age62plus                 0.021826
# dev_tminority                     0.021826
# dev_pct_overhoused                0.021826
# dev_pct_bed3                      0.021826
# dev_pct_bed2                      0.021826
# dev_pct_bed1                      0.021826
# dev_ave_util_allow                0.021826
# dev_pct_utility_allow             0.021826
# dev_tpoverty                      0.021826
# dev_months_waiting                0.021826
# dev_pct_native_american           0.021826
# dev_pct_age85plus                 0.021826
# dev_pct_hispanic                  0.021826
# dev_pct_minority                  0.021826
# dev_pct_black                     0.021826
# dev_pct_ge20k                     0.021826
# dev_pct_asian                     0.021826
# pha_phas_designation              0.021383
# ha_fax_num                        0.021039
# ha_email_addr_text                0.017672
# place_level                       0.007848
# place2kx                          0.007848
# place_cc2kx                       0.007848
# place_nm2kx                       0.007848
# ur                                0.007828
# zcta2kx                           0.007828
# national_bldg_id                  0.004289
# pha_annl_expns_amnt_prev_yr       0.003888
# exec_dir_phone                    0.003513
# exec_dir_email                    0.003513
# dev_pha_total_units               0.003372
# dev_number_reported               0.003372
# dev_pct_occupied                  0.003372
# dev_regular_vacant                0.003372
# dev_total_units                   0.003372
# dev_acc_units                     0.003372
# dev_total_dwelling_units          0.003372
# dev_pd_status_type_code           0.003372
# dev_development_code              0.003372
# dev_scattered_site_ind            0.003372
# dev_total_occupied                0.003372
# pha_pct_disabled_lt62_all         0.002851
# pha_annl_expns_amnt               0.002851
# pha_median_inc_amnt               0.002851
# pha_pct_lt80_median               0.002851
# pha_chldrn_mbr_cnt                0.002851
# pha_eldly_prcnt                   0.002851
# cnty_nm2kx                        0.002486
# curcnty_nm                        0.002486
# dofa_actual_dt                    0.002225
# curcosub_nm                       0.000730
# fcd_fips91                        0.000375
# x                                 0.000240
# metro                             0.000240
# county_level                      0.000240
# curcnty                           0.000240
# curcosub                          0.000240
# msa                               0.000240
# cbsa                              0.000240
# necta                             0.000240
# micro                             0.000240
# lat                               0.000240
# lon                               0.000240
# y                                 0.000240
# tract2kx                          0.000240
# tract_level                       0.000240
# cnty2kx                           0.000240
# rc2kx                             0.000219
# std_zip5                          0.000219
# lvl2kx                            0.000219
# state2kx                          0.000021
# building_number                   0.000016
# std_city                          0.000010
# std_st                            0.000010
# pha_ha_fye                        0.000000
# total_units                       0.000000
# pha_ha_program_type               0.000000
# regular_vacant                    0.000000
# total_occupied                    0.000000
# pha_section8_occupied             0.000000
# total_dwelling_units              0.000000
# pha_opfund_amnt                   0.000000
# pha_opfund_amnt_prev_yr           0.000000
# pha_capfund_amnt                  0.000000
# pha_capfund_amnt_prev_yr          0.000000
# pha_ha_section_8_size_category    0.000000
# pha_ross_amnt                     0.000000
# pha_fss_amnt                      0.000000
# acc_units                         0.000000
# pha_ha_combined_size_category     0.000000
# pct_occupied                      0.000000
# pha_section8_units_cnt            0.000000
# msg2kx                            0.000000
# dev_buil_nu_entrance              0.000000
# pha_total_units                   0.000000
# objectid                          0.000000
# participant_code                  0.000000
# last_updt_dttm                    0.000000
# rad_type                          0.000000
# rad_chap_indr                     0.000000
# msgusps                           0.000000
# pha_ha_low_rent_size_category     0.000000
# formal_participant_name           0.000000
# development_code                  0.000000
# project_name                      0.000000
# building_type_code                0.000000
# building_status_type_code         0.000000
# ha_phn_num                        0.000000
# pha_participant_code              0.000000
# number_reported                   0.000000
# dtype: float64

# %%
pd.set_option('display.max_rows', 300)
display(public.dtypes)
pd.set_option('display.max_rows', 10)
# Out:
# x                                 float64
# y                                 float64
# objectid                            int64
# participant_code                   object
# formal_participant_name            object
# development_code                   object
# project_name                       object
# building_name                      object
# building_number                    object
# building_type_code                 object
# building_status_type_code          object
# national_bldg_id                  float64
# construct_date                     object
# dofa_actual_dt                     object
# total_dwelling_units                int64
# acc_units                           int64
# total_occupied                      int64
# regular_vacant                      int64
# total_units                         int64
# pct_occupied                      float64
# number_reported                     int64
# pct_reported                      float64
# months_since_report               float64
# pct_movein                        float64
# people_per_unit                   float64
# people_total                      float64
# rent_per_month                    float64
# spending_per_month                float64
# spending_per_month_prev_yr        float64
# hh_income                         float64
# person_income                     float64
# pct_lt5k                          float64
# pct_5k_lt10k                      float64
# pct_10k_lt15k                     float64
# pct_15k_lt20k                     float64
# pct_ge20k                         float64
# pct_wage_major                    float64
# pct_welfare_major                 float64
# pct_other_major                   float64
# pct_median                        float64
# pct_lt50_median                   float64
# pct_lt30_median                   float64
# pct_2adults                       float64
# pct_1adult                        float64
# pct_female_head                   float64
# pct_female_head_child             float64
# pct_disabled_lt62                 float64
# pct_disabled_ge62                 float64
# pct_disabled_all                  float64
# pct_lt24_head                     float64
# pct_age25_50                      float64
# pct_age51_61                      float64
# pct_age62plus                     float64
# pct_age85plus                     float64
# pct_minority                      float64
# pct_black                         float64
# pct_native_american               float64
# pct_asian                         float64
# pct_hispanic                      float64
# months_waiting                    float64
# months_from_movein                float64
# pct_utility_allow                 float64
# ave_util_allow                    float64
# pct_bed1                          float64
# pct_bed2                          float64
# pct_bed3                          float64
# pct_overhoused                    float64
# tminority                         float64
# tpoverty                          float64
# tpct_ownsfd                       float64
# chldrn_mbr_cnt                    float64
# eldly_prcnt                       float64
# pct_disabled_lt62_all             float64
# pct_lt80_median                   float64
# median_inc_amnt                   float64
# state2kx                          float64
# cnty_nm2kx                         object
# cnty2kx                           float64
# tract2kx                          float64
# bg2kx                             float64
# block2kx                          float64
# dpvact                            float64
# dpvnost                           float64
# curcnty_nm                         object
# curcnty                           float64
# curcosub                          float64
# curcosub_nm                        object
# place2kx                          float64
# place_nm2kx                        object
# place_cc2kx                        object
# place_inc2kx                      float64
# msa                               float64
# msa_nm                             object
# cbsa                              float64
# cbsa_nm                            object
# necta                             float64
# necta_nm                           object
# metro                             float64
# micro                             float64
# fcd_fips91                         object
# hlc                               float64
# dpv                               float64
# dpvrc                             float64
# std_addr                           object
# urb_out                            object
# std_city                           object
# std_st                             object
# std_zip5                          float64
# std_zip9                          float64
# zip_class                          object
# zcta2kx                           float64
# dpbc                              float64
# dpbc_cksum                        float64
# std_zip11                         float64
# addr_type                          object
# apt_type                           object
# c1pgrc                             object
# c1pprb                            float64
# c1pdrc                             object
# c1psrc                             object
# c1parc                             object
# c1pzrc                             object
# msgusps                            object
# lat                               float64
# lon                               float64
# rc2kx                              object
# stm2kx                             object
# lvl2kx                             object
# ur                                 object
# msg2kx                             object
# county_level                      float64
# place_level                       float64
# tract_level                       float64
# blkgrp_level                      float64
# rad_chap_indr                      object
# rad_type                           object
# last_updt_dttm                     object
# annl_expns_amnt                   float64
# annl_expns_amnt_prev_yr           float64
# pha_total_units                     int64
# dev_buil_nu_entrance               object
# ha_phn_num                          int64
# ha_fax_num                        float64
# ha_email_addr_text                 object
# exec_dir_phone                    float64
# exec_dir_fax                      float64
# exec_dir_email                     object
# dev_development_code               object
# dev_spending_per_month_prev_yr    float64
# dev_chldrn_mbr_cnt                float64
# dev_annl_expns_amnt               float64
# dev_annl_expns_amnt_prev_yr       float64
# dev_eldly_prcnt                   float64
# dev_pct_disabled_lt62_all         float64
# dev_pct_lt80_median               float64
# dev_median_inc_amnt               float64
# dev_scattered_site_ind             object
# dev_pd_status_type_code            object
# dev_total_units                   float64
# dev_total_dwelling_units          float64
# dev_acc_units                     float64
# dev_total_occupied                float64
# dev_regular_vacant                float64
# dev_pha_total_units               float64
# dev_pct_occupied                  float64
# dev_number_reported               float64
# dev_pct_reported                  float64
# dev_months_since_report           float64
# dev_pct_movein                    float64
# dev_people_per_unit               float64
# dev_people_total                  float64
# dev_rent_per_month                float64
# dev_spending_per_month            float64
# dev_hh_income                     float64
# dev_person_income                 float64
# dev_pct_lt5k                      float64
# dev_pct_5k_lt10k                  float64
# dev_pct_10k_lt15k                 float64
# dev_pct_15k_lt20k                 float64
# dev_pct_ge20k                     float64
# dev_pct_wage_major                float64
# dev_pct_welfare_major             float64
# dev_pct_other_major               float64
# dev_pct_median                    float64
# dev_pct_lt50_median               float64
# dev_pct_lt30_median               float64
# dev_pct_2adults                   float64
# dev_pct_1adult                    float64
# dev_pct_female_head               float64
# dev_pct_female_head_child         float64
# dev_pct_disabled_lt62             float64
# dev_pct_disabled_ge62             float64
# dev_pct_disabled_all              float64
# dev_pct_lt24_head                 float64
# dev_pct_age25_50                  float64
# dev_pct_age51_61                  float64
# dev_pct_age62plus                 float64
# dev_pct_age85plus                 float64
# dev_pct_minority                  float64
# dev_pct_black                     float64
# dev_pct_native_american           float64
# dev_pct_asian                     float64
# dev_pct_hispanic                  float64
# dev_months_waiting                float64
# dev_months_from_movein            float64
# dev_pct_utility_allow             float64
# dev_ave_util_allow                float64
# dev_pct_bed1                      float64
# dev_pct_bed2                      float64
# dev_pct_bed3                      float64
# dev_pct_overhoused                float64
# dev_tminority                     float64
# dev_tpoverty                      float64
# dev_tpct_ownsfd                   float64
# pha_participant_code               object
# pha_phas_designation               object
# pha_ha_low_rent_size_category      object
# pha_section8_units_cnt              int64
# pha_ha_section_8_size_category     object
# pha_ha_combined_size_category      object
# pha_ha_fye                         object
# pha_ha_program_type                object
# pha_section8_occupied               int64
# pha_opfund_amnt                     int64
# pha_opfund_amnt_prev_yr             int64
# pha_capfund_amnt                    int64
# pha_capfund_amnt_prev_yr            int64
# pha_ross_amnt                       int64
# pha_fss_amnt                        int64
# pha_chldrn_mbr_cnt                float64
# pha_eldly_prcnt                   float64
# pha_pct_disabled_lt62_all         float64
# pha_pct_lt80_median               float64
# pha_median_inc_amnt               float64
# pha_annl_expns_amnt               float64
# pha_annl_expns_amnt_prev_yr       float64
# corrected_address                  object
# corrected_unit                     object
# dtype: object

# %%
columns_to_drop = [
    'x', 
    'y', 
    'formal_participant_name', 
    'project_name',
    'building_name',
    'building_number',
    'national_bldg_id',
    'state2kx', 
    'cnty_nm2kx',
    'cnty2kx',
    'tract2kx',
    'bg2kx',
    'block2kx',
    'dpvact',
    'dpvnost', 
    'curcnty_nm', 
    'curcnty', 
    'curcosub', 
    'curcosub_nm',
    'place2kx', 
    'place_nm2kx', 
    'place_cc2kx', 
    'place_inc2kx', 
    'msa', 
    'cbsa', 
    'cbsa_nm', 
    'necta', 
    'necta_nm', 
    'zcta2kx',
    'dpbc',
    'dpbc_cksum',
    'c1pgrc',  
    'c1pdrc',
    'c1psrc',
    'c1parc',
    'c1pzrc',
    'lat',
    'lon',
    'rc2kx',
    'stm2kx',
    'fcd_fips91',
    'hlc',
    'dpv', 
    'dpvrc', 
    'std_addr',
    'urb_out', 
    'msg2kx',
    'county_level',
    'place_level',	
    'tract_level',	
    'blkgrp_level',
    'county_level',
    'place_level',
    'tract_level',
    'blkgrp_level',
    'dev_buil_nu_entrance',
    'ha_phn_num',
    'ha_fax_num',
    'ha_email_addr_text',
    'exec_dir_phone' ,
    'exec_dir_fax',
    'exec_dir_email',
    'dev_development_code',
    'pha_participant_code'
]

public = public.drop(columns=columns_to_drop)

# %%
public['construction_year'] = pd.to_datetime(public['construct_date']).dt.year
public['dofa_actual_year'] = pd.to_datetime(public['dofa_actual_dt']).dt.year
public = public.drop(['construct_date', 'dofa_actual_dt'], axis=1)

# %%
public.building_type_code = public.building_type_code.str.upper()

# %%
public.sample()
# Out:
#        objectid participant_code development_code building_type_code  \
# 69679     69680            PA002      PA002000902                 RW
#
#       building_status_type_code  total_dwelling_units  acc_units  \
# 69679                    INAPCP                     1          1
#
#        total_occupied  regular_vacant  total_units  pct_occupied  \
# 69679               1               0            1         100.0
#
#        number_reported  pct_reported  months_since_report  pct_movein  \
# 69679                1           NaN                  NaN         NaN
#
#        people_per_unit  people_total  rent_per_month  spending_per_month  \
# 69679              NaN           NaN             NaN                 NaN
#
#        spending_per_month_prev_yr  hh_income  person_income  pct_lt5k  \
# 69679                         NaN        NaN            NaN       NaN
#
#        pct_5k_lt10k  pct_10k_lt15k  pct_15k_lt20k  pct_ge20k  pct_wage_major  \
# 69679           NaN            NaN            NaN        NaN             NaN
#
#        pct_welfare_major  pct_other_major  pct_median  pct_lt50_median  \
# 69679                NaN              NaN         NaN              NaN
#
#        pct_lt30_median  pct_2adults  pct_1adult  pct_female_head  \
# 69679              NaN          NaN         NaN              NaN
#
#        pct_female_head_child  pct_disabled_lt62  pct_disabled_ge62  \
# 69679                    NaN                NaN                NaN
#
#        pct_disabled_all  pct_lt24_head  pct_age25_50  pct_age51_61  \
# 69679               NaN            NaN           NaN           NaN
#
#        pct_age62plus  pct_age85plus  pct_minority  pct_black  \
# 69679            NaN            NaN           NaN        NaN
#
#        pct_native_american  pct_asian  pct_hispanic  months_waiting  \
# 69679                  NaN        NaN           NaN             NaN
#
#        months_from_movein  pct_utility_allow  ave_util_allow  pct_bed1  \
# 69679                 NaN                NaN             NaN       NaN
#
#        pct_bed2  pct_bed3  pct_overhoused  tminority  tpoverty  tpct_ownsfd  \
# 69679       NaN       NaN             NaN        NaN       NaN          NaN
#
#        chldrn_mbr_cnt  eldly_prcnt  pct_disabled_lt62_all  pct_lt80_median  \
# 69679             NaN          NaN                    NaN              NaN
#
#        median_inc_amnt                    msa_nm  metro  micro      std_city  \
# 69679              NaN  Philadelphia, PA-NJ PMSA    1.0    0.0  PHILADELPHIA
#
#       std_st  std_zip5  std_zip9 zip_class     std_zip11 addr_type apt_type  \
# 69679     PA   19104.0    1801.0       NaN  1.910418e+10         S      NaN
#
#        c1pprb                           msgusps lvl2kx ur rad_chap_indr  \
# 69679     1.0  90% Overall probable correctness      R  U             N
#
#       rad_type          last_updt_dttm  annl_expns_amnt  \
# 69679           2023/03/06 08:50:52+00              NaN
#
#        annl_expns_amnt_prev_yr  pha_total_units  \
# 69679                      NaN            12799
#
#        dev_spending_per_month_prev_yr  dev_chldrn_mbr_cnt  \
# 69679                          1297.0               342.0
#
#        dev_annl_expns_amnt  dev_annl_expns_amnt_prev_yr  dev_eldly_prcnt  \
# 69679            5706978.0                    5305612.0            12.09
#
#        dev_pct_disabled_lt62_all  dev_pct_lt80_median  dev_median_inc_amnt  \
# 69679                      14.67            97.309998              12361.0
#
#       dev_scattered_site_ind dev_pd_status_type_code  dev_total_units  \
# 69679                      Y                       M            376.0
#
#        dev_total_dwelling_units  dev_acc_units  dev_total_occupied  \
# 69679                     373.0          373.0               338.0
#
#        dev_regular_vacant  dev_pha_total_units  dev_pct_occupied  \
# 69679                22.0              12790.0         90.620003
#
#        dev_number_reported  dev_pct_reported  dev_months_since_report  \
# 69679                335.0             99.11                     12.0
#
#        dev_pct_movein  dev_people_per_unit  dev_people_total  \
# 69679            3.88                  2.7             893.0
#
#        dev_rent_per_month  dev_spending_per_month  dev_hh_income  \
# 69679               501.0                  1407.0        18915.0
#
#        dev_person_income  dev_pct_lt5k  dev_pct_5k_lt10k  dev_pct_10k_lt15k  \
# 69679             7096.0          8.17             24.18              20.59
#
#        dev_pct_15k_lt20k  dev_pct_ge20k  dev_pct_wage_major  \
# 69679              10.13          36.93               29.25
#
#        dev_pct_welfare_major  dev_pct_other_major  dev_pct_median  \
# 69679                   6.27                55.82           20.04
#
#        dev_pct_lt50_median  dev_pct_lt30_median  dev_pct_2adults  \
# 69679                88.66                74.63             2.39
#
#        dev_pct_1adult  dev_pct_female_head  dev_pct_female_head_child  \
# 69679           44.78                90.75                      45.07
#
#        dev_pct_disabled_lt62  dev_pct_disabled_ge62  dev_pct_disabled_all  \
# 69679                  29.36                   53.0                 20.94
#
#        dev_pct_lt24_head  dev_pct_age25_50  dev_pct_age51_61  \
# 69679               2.69             47.76              19.7
#
#        dev_pct_age62plus  dev_pct_age85plus  dev_pct_minority  dev_pct_black  \
# 69679              29.85               2.99             97.01          95.22
#
#        dev_pct_native_american  dev_pct_asian  dev_pct_hispanic  \
# 69679                      0.0            0.0              1.79
#
#        dev_months_waiting  dev_months_from_movein  dev_pct_utility_allow  \
# 69679                 0.0                   193.0                  83.58
#
#        dev_ave_util_allow  dev_pct_bed1  dev_pct_bed2  dev_pct_bed3  \
# 69679               187.0          3.88         22.09         74.03
#
#        dev_pct_overhoused  dev_tminority  dev_tpoverty  dev_tpct_ownsfd  \
# 69679               46.57          92.59         43.45             5.36
#
#       pha_phas_designation pha_ha_low_rent_size_category  \
# 69679             Advisory          EXTRA LARGE (5,000+)
#
#        pha_section8_units_cnt pha_ha_section_8_size_category  \
# 69679                   23003           EXTRA LARGE (5,000+)
#
#       pha_ha_combined_size_category pha_ha_fye pha_ha_program_type  \
# 69679          EXTRA LARGE (5,000+)       3/31            Combined
#
#        pha_section8_occupied  pha_opfund_amnt  pha_opfund_amnt_prev_yr  \
# 69679                  19008        158748192                129464275
#
#        pha_capfund_amnt  pha_capfund_amnt_prev_yr  pha_ross_amnt  \
# 69679          54175579                  53271528              0
#
#        pha_fss_amnt  pha_chldrn_mbr_cnt  pha_eldly_prcnt  \
# 69679             0             26294.0            14.39
#
#        pha_pct_disabled_lt62_all  pha_pct_lt80_median  pha_median_inc_amnt  \
# 69679                      15.25            98.349998              11713.0
#
#        pha_annl_expns_amnt  pha_annl_expns_amnt_prev_yr corrected_address  \
# 69679          379445090.0                  337899750.0     609 N 39TH ST
#
#       corrected_unit  construction_year  dofa_actual_year
# 69679            NaN             1974.0            1974.0

# %%
pd.set_option('display.max_rows', 30)
display(public.select_dtypes(include='object') \
    .nunique().sort_values(ascending=False))
pd.set_option('display.max_rows', 10)
# Out:
# corrected_address                 156377
# development_code                    6493
# std_city                            3444
# participant_code                    2754
# corrected_unit                      1763
# msa_nm                               306
# std_st                                54
# msgusps                               14
# pha_ha_section_8_size_category         6
# building_type_code                     6
# addr_type                              6
# building_status_type_code              6
# pha_ha_combined_size_category          6
# pha_phas_designation                   6
# pha_ha_low_rent_size_category          6
# apt_type                               5
# lvl2kx                                 5
# rad_type                               4
# pha_ha_fye                             4
# pha_ha_program_type                    2
# rad_chap_indr                          2
# dev_scattered_site_ind                 2
# ur                                     2
# zip_class                              2
# dev_pd_status_type_code                1
# last_updt_dttm                         1
# dtype: int64

# %%
print([x for x in public.columns if 'zip' in x.lower()])
# Out:
# ['std_zip5', 'std_zip9', 'zip_class', 'std_zip11']

# %%
public['std_zip5'] = public.std_zip5.astype(str)
public['std_zip9'] = public.std_zip9.astype(str)
public['std_zip11'] = public.std_zip11.astype(str)

# %%
public['encoded_development_code'] = LabelEncoder().fit_transform(public.development_code)
public['encoded_participant_code'] = LabelEncoder().fit_transform(public.participant_code)
public['encoded_msa_nm'] = LabelEncoder().fit_transform(public.msa_nm)
public['encoded_zip5'] = LabelEncoder().fit_transform(public.std_zip5)
public['encoded_zip9'] = LabelEncoder().fit_transform(public.std_zip9)
public['encoded_zip11'] = LabelEncoder().fit_transform(public.std_zip11)

public = public.drop([
    'development_code',
    'participant_code',
    'msa_nm',
    'std_zip9',
    'std_zip11'
], axis=1)

# %%
placeholder = "MISSING_VALUE" 

# List of columns to be one-hot encoded
columns_to_encode = [
    'msgusps',
    'pha_ha_section_8_size_category',
    'building_type_code',
    'addr_type',
    'building_status_type_code',
    'pha_ha_combined_size_category',
    'pha_phas_designation',
    'pha_ha_low_rent_size_category',
    'apt_type',
    'lvl2kx',
    'rad_type',
    'pha_ha_fye',
    'pha_ha_program_type',
    'rad_chap_indr',
    'dev_scattered_site_ind',
    'ur',
    'zip_class',
    'dev_pd_status_type_code',
    'last_updt_dttm'
]

# Fill NaN values with placeholder
for column in columns_to_encode:
    public[column] = public[column].fillna(placeholder)

# One-hot encode the columns
for column in columns_to_encode:
    dummies = pd.get_dummies(public[column], prefix=column)
    public = pd.concat([public, dummies], axis=1)
    public.drop([column], axis=1, inplace=True)

# %%
# Encode address info, but don't drop so we can match later
public['encoded_city'] = LabelEncoder().fit_transform(public.std_city)

public['std_st'] = public['std_st'].fillna(placeholder)
dummies = pd.get_dummies(public['std_st'], prefix='std_st')
public = pd.concat([public, dummies], axis=1)

public['encoded_zip5'] = LabelEncoder().fit_transform(public.std_zip5)

# %%
public.shape
# Out:
# (191885, 310)

# %%
pd.set_option('display.max_rows', 350)
display(public.dtypes.sort_values(ascending=False))
pd.set_option('display.max_rows', 10)
# Out:
# std_st                                                   object
# corrected_unit                                           object
# corrected_address                                        object
# std_zip5                                                 object
# std_city                                                 object
# dev_pct_5k_lt10k                                        float64
# dev_people_total                                        float64
# dev_rent_per_month                                      float64
# dev_spending_per_month                                  float64
# dev_hh_income                                           float64
# dev_person_income                                       float64
# dev_pct_lt5k                                            float64
# dev_median_inc_amnt                                     float64
# dev_pct_10k_lt15k                                       float64
# dev_pct_movein                                          float64
# dev_pct_15k_lt20k                                       float64
# dev_pct_ge20k                                           float64
# dev_pct_wage_major                                      float64
# dev_pct_welfare_major                                   float64
# dev_pct_other_major                                     float64
# dev_people_per_unit                                     float64
# dev_number_reported                                     float64
# dev_months_since_report                                 float64
# dev_pct_reported                                        float64
# dev_pct_lt50_median                                     float64
# dev_pct_occupied                                        float64
# dev_pha_total_units                                     float64
# dev_regular_vacant                                      float64
# dev_total_occupied                                      float64
# dev_acc_units                                           float64
# dev_total_dwelling_units                                float64
# dev_total_units                                         float64
# pha_annl_expns_amnt                                     float64
# dev_pct_lt80_median                                     float64
# dev_pct_disabled_lt62_all                               float64
# dev_eldly_prcnt                                         float64
# dev_pct_median                                          float64
# dev_pct_2adults                                         float64
# dev_pct_lt30_median                                     float64
# dev_tminority                                           float64
# dev_pct_utility_allow                                   float64
# dev_ave_util_allow                                      float64
# dev_pct_bed1                                            float64
# dev_pct_bed2                                            float64
# dev_pct_bed3                                            float64
# dev_pct_overhoused                                      float64
# dev_tpoverty                                            float64
# dev_months_waiting                                      float64
# dev_tpct_ownsfd                                         float64
# pha_median_inc_amnt                                     float64
# pha_pct_lt80_median                                     float64
# pha_pct_disabled_lt62_all                               float64
# pha_eldly_prcnt                                         float64
# pha_chldrn_mbr_cnt                                      float64
# dev_months_from_movein                                  float64
# dev_pct_hispanic                                        float64
# dev_annl_expns_amnt                                     float64
# dev_pct_lt24_head                                       float64
# dev_pct_1adult                                          float64
# dev_pct_female_head                                     float64
# dev_pct_female_head_child                               float64
# dev_pct_disabled_lt62                                   float64
# dev_pct_disabled_ge62                                   float64
# dev_pct_disabled_all                                    float64
# dev_pct_age25_50                                        float64
# dev_pct_asian                                           float64
# dev_pct_age51_61                                        float64
# dev_pct_age62plus                                       float64
# dev_pct_age85plus                                       float64
# dev_pct_minority                                        float64
# dev_pct_black                                           float64
# dev_pct_native_american                                 float64
# dev_annl_expns_amnt_prev_yr                             float64
# pha_annl_expns_amnt_prev_yr                             float64
# dev_chldrn_mbr_cnt                                      float64
# pct_10k_lt15k                                           float64
# pct_disabled_ge62                                       float64
# pct_disabled_lt62                                       float64
# pct_female_head_child                                   float64
# pct_female_head                                         float64
# pct_1adult                                              float64
# pct_2adults                                             float64
# pct_lt30_median                                         float64
# pct_lt50_median                                         float64
# pct_median                                              float64
# pct_other_major                                         float64
# pct_welfare_major                                       float64
# pct_wage_major                                          float64
# pct_ge20k                                               float64
# pct_15k_lt20k                                           float64
# pct_5k_lt10k                                            float64
# dev_spending_per_month_prev_yr                          float64
# pct_lt5k                                                float64
# person_income                                           float64
# hh_income                                               float64
# spending_per_month_prev_yr                              float64
# spending_per_month                                      float64
# rent_per_month                                          float64
# people_total                                            float64
# people_per_unit                                         float64
# pct_movein                                              float64
# months_since_report                                     float64
# pct_reported                                            float64
# pct_occupied                                            float64
# construction_year                                       float64
# dofa_actual_year                                        float64
# pct_disabled_all                                        float64
# pct_lt24_head                                           float64
# pct_age25_50                                            float64
# pct_age51_61                                            float64
# annl_expns_amnt_prev_yr                                 float64
# annl_expns_amnt                                         float64
# c1pprb                                                  float64
# micro                                                   float64
# metro                                                   float64
# median_inc_amnt                                         float64
# pct_lt80_median                                         float64
# pct_disabled_lt62_all                                   float64
# eldly_prcnt                                             float64
# chldrn_mbr_cnt                                          float64
# tpct_ownsfd                                             float64
# tpoverty                                                float64
# tminority                                               float64
# pct_overhoused                                          float64
# pct_bed3                                                float64
# pct_bed2                                                float64
# pct_age62plus                                           float64
# pct_age85plus                                           float64
# pct_minority                                            float64
# pct_black                                               float64
# pct_native_american                                     float64
# pct_asian                                               float64
# pct_hispanic                                            float64
# months_waiting                                          float64
# months_from_movein                                      float64
# pct_utility_allow                                       float64
# ave_util_allow                                          float64
# pct_bed1                                                float64
# pha_ross_amnt                                             int64
# total_dwelling_units                                      int64
# pha_fss_amnt                                              int64
# objectid                                                  int64
# pha_capfund_amnt_prev_yr                                  int64
# pha_capfund_amnt                                          int64
# pha_opfund_amnt_prev_yr                                   int64
# pha_opfund_amnt                                           int64
# pha_section8_occupied                                     int64
# pha_section8_units_cnt                                    int64
# pha_total_units                                           int64
# number_reported                                           int64
# total_units                                               int64
# regular_vacant                                            int64
# total_occupied                                            int64
# acc_units                                                 int64
# encoded_zip9                                              int32
# encoded_city                                              int32
# encoded_zip11                                             int32
# encoded_participant_code                                  int32
# encoded_zip5                                              int32
# encoded_msa_nm                                            int32
# encoded_development_code                                  int32
# std_st_ID                                                 uint8
# std_st_IA                                                 uint8
# std_st_HI                                                 uint8
# std_st_GU                                                 uint8
# std_st_GA                                                 uint8
# std_st_FL                                                 uint8
# std_st_IL                                                 uint8
# std_st_DC                                                 uint8
# std_st_CT                                                 uint8
# std_st_CO                                                 uint8
# std_st_CA                                                 uint8
# std_st_AZ                                                 uint8
# std_st_AR                                                 uint8
# std_st_AL                                                 uint8
# std_st_AK                                                 uint8
# std_st_DE                                                 uint8
# last_updt_dttm_2023/03/06 08:50:52+00                     uint8
# dev_pd_status_type_code_MISSING_VALUE                     uint8
# dev_pd_status_type_code_M                                 uint8
# pha_ha_fye_6/30                                           uint8
# pha_ha_fye_9/30                                           uint8
# pha_ha_program_type_Combined                              uint8
# pha_ha_program_type_Low-Rent                              uint8
# rad_chap_indr_N                                           uint8
# rad_chap_indr_Y                                           uint8
# dev_scattered_site_ind_MISSING_VALUE                      uint8
# dev_scattered_site_ind_N                                  uint8
# dev_scattered_site_ind_Y                                  uint8
# ur_MISSING_VALUE                                          uint8
# ur_R                                                      uint8
# ur_U                                                      uint8
# zip_class_MISSING_VALUE                                   uint8
# zip_class_P                                               uint8
# zip_class_U                                               uint8
# std_st_IN                                                 uint8
# std_st_KS                                                 uint8
# std_st_KY                                                 uint8
# std_st_OH                                                 uint8
# std_st_OR                                                 uint8
# std_st_PA                                                 uint8
# std_st_PR                                                 uint8
# std_st_RI                                                 uint8
# std_st_SC                                                 uint8
# std_st_SD                                                 uint8
# std_st_TN                                                 uint8
# std_st_TX                                                 uint8
# std_st_UT                                                 uint8
# std_st_VA                                                 uint8
# std_st_VI                                                 uint8
# std_st_VT                                                 uint8
# std_st_WA                                                 uint8
# std_st_WI                                                 uint8
# std_st_WV                                                 uint8
# std_st_OK                                                 uint8
# std_st_NY                                                 uint8
# std_st_LA                                                 uint8
# std_st_NV                                                 uint8
# std_st_MA                                                 uint8
# std_st_MD                                                 uint8
# std_st_ME                                                 uint8
# std_st_MI                                                 uint8
# std_st_MISSING_VALUE                                      uint8
# std_st_MN                                                 uint8
# std_st_MO                                                 uint8
# std_st_MS                                                 uint8
# std_st_MT                                                 uint8
# std_st_NC                                                 uint8
# std_st_ND                                                 uint8
# std_st_NE                                                 uint8
# std_st_NH                                                 uint8
# std_st_NJ                                                 uint8
# std_st_NM                                                 uint8
# pha_ha_fye_3/31                                           uint8
# pha_ha_fye_12/31                                          uint8
# rad_type_PBV/PBRA                                         uint8
# pha_ha_section_8_size_category_MEDIUM LOW (100-299)       uint8
# pha_ha_section_8_size_category_VERY SMALL (0-49)          uint8
# building_type_code_ES                                     uint8
# building_type_code_NDS                                    uint8
# building_type_code_RW                                     uint8
# building_type_code_SD                                     uint8
# building_type_code_SF                                     uint8
# building_type_code_WU                                     uint8
# addr_type_F                                               uint8
# addr_type_G                                               uint8
# addr_type_H                                               uint8
# addr_type_MISSING_VALUE                                   uint8
# addr_type_P                                               uint8
# addr_type_R                                               uint8
# addr_type_S                                               uint8
# building_status_type_code_DDAPRD                          uint8
# pha_ha_section_8_size_category_SMALL (50-99)              uint8
# pha_ha_section_8_size_category_MEDIUM HIGH (300-999)      uint8
# building_status_type_code_DDPROP                          uint8
# pha_ha_section_8_size_category_LARGE (1,000-4,999)        uint8
# msgusps_100% Overall probable correctness                 uint8
# msgusps_20% Overall probable correctness                  uint8
# msgusps_30% Overall probable correctness                  uint8
# msgusps_40% Overall probable correctness                  uint8
# msgusps_50% Overall probable correctness                  uint8
# msgusps_60% Overall probable correctness                  uint8
# msgusps_70% Overall probable correctness                  uint8
# msgusps_80% Overall probable correctness                  uint8
# msgusps_90% Overall probable correctness                  uint8
# msgusps_Apartment missing or not found                    uint8
# msgusps_House # not found on this street                  uint8
# msgusps_Insufficient or Blank address                     uint8
# msgusps_Multiple Match                                    uint8
# msgusps_Street not found                                  uint8
# pha_ha_section_8_size_category_EXTRA LARGE (5,000+)       uint8
# building_status_type_code_DDDRFT                          uint8
# building_status_type_code_INAPCP                          uint8
# rad_type_PBV                                              uint8
# pha_ha_low_rent_size_category_MEDIUM LOW (100-299)        uint8
# pha_ha_low_rent_size_category_VERY SMALL (0-49)           uint8
# apt_type_#                                                uint8
# apt_type_Apt                                              uint8
# apt_type_Lot                                              uint8
# apt_type_MISSING_VALUE                                    uint8
# apt_type_Ste                                              uint8
# apt_type_Unit                                             uint8
# lvl2kx_4                                                  uint8
# lvl2kx_5                                                  uint8
# lvl2kx_B                                                  uint8
# lvl2kx_MISSING_VALUE                                      uint8
# lvl2kx_R                                                  uint8
# lvl2kx_T                                                  uint8
# rad_type_                                                 uint8
# rad_type_PBRA                                             uint8
# pha_ha_low_rent_size_category_SMALL (50-99)               uint8
# pha_ha_low_rent_size_category_MEDIUM HIGH (300-999)       uint8
# building_status_type_code_RMI                             uint8
# pha_ha_low_rent_size_category_LARGE (1,000-4,999)         uint8
# building_status_type_code_RMIPRP                          uint8
# pha_ha_combined_size_category_EXTRA LARGE (5,000+)        uint8
# pha_ha_combined_size_category_LARGE (1,000-4,999)         uint8
# pha_ha_combined_size_category_MEDIUM HIGH (300-999)       uint8
# pha_ha_combined_size_category_MEDIUM LOW (100-299)        uint8
# pha_ha_combined_size_category_SMALL (50-99)               uint8
# pha_ha_combined_size_category_VERY SMALL (0-49)           uint8
# pha_phas_designation_Advisory                             uint8
# pha_phas_designation_High Performer                       uint8
# pha_phas_designation_MISSING_VALUE                        uint8
# pha_phas_designation_Standard Performer                   uint8
# pha_phas_designation_Substandard Financial                uint8
# pha_phas_designation_Substandard Physical                 uint8
# pha_phas_designation_Troubled Performer                   uint8
# pha_ha_low_rent_size_category_EXTRA LARGE (5,000+)        uint8
# std_st_WY                                                 uint8
# dtype: object

# %% [markdown]
# Export the cleaned file for future analysis.

# %%
public.to_csv('..data/buildings_dev_pha_clean_2.1.csv', index=False)
