# %%
import pandas as pd
import sqlite3
import numpy as np

pd.set_option('display.max_columns', None)

# %%
public = pd.read_csv('./buildings_dev_pha_clean_2.1.csv')

# %%
cols_to_front = ['objectid', 'corrected_address', 'corrected_unit', 'std_city', 'std_st', 'std_zip5']
remaining_cols = [col for col in public.columns if col not in cols_to_front]
public = public[cols_to_front + remaining_cols]

# %%
public = public[public.corrected_address.notna()]

# %%
public.std_zip5 = public.std_zip5.astype(str)
public.std_zip5 = public.std_zip5.replace('nan', '')
public.std_zip5 = public.std_zip5.apply(lambda x: x.split('.')[0])
public.std_zip5 = public.std_zip5.apply(lambda x: '00' + x if len(x) == 3 else x)
public.std_zip5 = public.std_zip5.apply(lambda x: '0' + x if len(x) == 4 else x)

# %%
public['corrected_address'] = public.corrected_address.fillna('')
public['corrected_address'] = public['corrected_address'].str.replace(r'\s+', ' ').str.strip()

public['corrected_unit'] = public.corrected_unit.fillna('')
public['corrected_unit'] = public.corrected_unit.str.strip()

public['std_city'] = public.std_city.fillna('')
public['std_city'] = public.std_city.str.strip()

public['std_st'] = public.std_st.fillna('')
public['std_st'] = public.std_st.str.strip()
# Out:
# C:\Users\jackv\AppData\Local\Temp\ipykernel_5648\3736073915.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   public['corrected_address'] = public['corrected_address'].str.replace(r'\s+', ' ').str.strip()

# %%
full_fema_matches = pd.DataFrame()

# %%
for year in range(2012, 2022):
    conn = sqlite3.Connection('./data/nfirs/fire_data.db')
    df = pd.read_sql("""
        select 
            INCIDENT_KEY,
            address,
            APT_NO,
            CITY,
            STATE,
            ZIP5,
            PROP_LOSS,
            CONT_LOSS,
            OTH_DEATH,
            OTH_INJ,
            INC_TYPE,
            HUM_FAC_1,
            HUM_FAC_2,
            HUM_FAC_3,
            HUM_FAC_4,
            HUM_FAC_5,
            HUM_FAC_6,
            HUM_FAC_7,
            BLDG_INVOL,
            DET_ALERT,
            FLAME_SPRD,
            AES_PRES,
            ST_DAM_HVY,
            ST_DAM_SIG,
            ST_DAM_XTR,
            ST_DAM_MIN 
        from buildings_fires_all 
        where INC_YEAR
        """ + f" = {year};", conn)

    df['EXP_NO'] = df.INCIDENT_KEY.apply(lambda x: x.split('_')[-1]).astype(int)

    df['address'] = df.address.fillna('')
    df['address'] = df['address'].str.replace(r'\s+', ' ', regex=True).str.strip()

    df['APT_NO'] = df.APT_NO.fillna('')
    df['APT_NO'] = df.APT_NO.str.strip()

    df['CITY'] = df.CITY.fillna('')
    df['CITY'] = df.CITY.str.strip()

    df['STATE'] = df.STATE.fillna('')
    df['STATE'] = df.STATE.str.strip()

    df.ZIP5 = df.ZIP5.astype(str)
    df.ZIP5 = df.ZIP5.replace('nan', '')
    df.ZIP5 = df.ZIP5.apply(lambda x: x.split('.')[0])
    df.ZIP5 = df.ZIP5.apply(lambda x: '00' + x if len(x) == 3 else x)
    df.ZIP5 = df.ZIP5.apply(lambda x: '0' + x if len(x) == 4 else x)

    df['HUM_FAC_1'] = df.HUM_FAC_1.apply(lambda x: 1 if x == '1' else 0)
    df['HUM_FAC_2'] = df.HUM_FAC_2.apply(lambda x: 1 if pd.notna(x) else 0)
    df['HUM_FAC_3'] = df.HUM_FAC_3.apply(lambda x: 1 if pd.notna(x) else 0)
    df['HUM_FAC_4'] = df.HUM_FAC_4.apply(lambda x: 1 if pd.notna(x) else 0)
    df['HUM_FAC_5'] = df.HUM_FAC_5.apply(lambda x: 1 if pd.notna(x) else 0)
    df['HUM_FAC_6'] = df.HUM_FAC_6.apply(lambda x: 1 if pd.notna(x) else 0)
    df['HUM_FAC_7'] = df.HUM_FAC_7.apply(lambda x: 1 if pd.notna(x) else 0)
    df['BLDG_INVOL'] = df.BLDG_INVOL.apply(lambda x: np.nan if pd.isna(x) or float(x) < 0 else x)
    df['BLDG_INVOL'] = df.BLDG_INVOL.astype(float)
    df['DET_ALERT'] = df.DET_ALERT.replace('U', np.nan)
    df['DET_ALERT'] = df.DET_ALERT.apply(lambda x: 1 if x == '1' else 0)
    df['FLAME_SPRD'] = df.FLAME_SPRD.apply(lambda x: 1 if x == 'Y' else 0)
    df['AES_PRES'] = df.AES_PRES.replace('U', np.nan)
    df['AES_PRES'] = df.AES_PRES.replace('N', 0)
    df['AES_PRES'] = df.AES_PRES.apply(lambda x: 1 if x == '1' else .5)
    df['ST_DAM_MIN'] = df.ST_DAM_MIN.apply(lambda x: np.nan if pd.isna(x) or float(x) < 0 else x)
    df['ST_DAM_XTR'] = df.ST_DAM_XTR.apply(lambda x: np.nan if pd.isna(x) or float(x) < 0 else x)
    df['ST_DAM_HVY'] = df.ST_DAM_HVY.apply(lambda x: np.nan if pd.isna(x) or float(x) < 0 else x)
    df['ST_DAM_SIG'] = df.ST_DAM_SIG.apply(lambda x: np.nan if pd.isna(x) or float(x) < 0 else x)

    col = 'INC_TYPE'
    dummies = pd.get_dummies(df[col], prefix=col)
    df = pd.concat([df.drop(col, axis=1), dummies], axis=1)

    inc_type_cols = [x for x in df.columns if 'INC_TYPE_' in x]
    df['building_fires'] = df[inc_type_cols].sum(axis=1)

    df = df.drop(['INC_TYPE_114', 'INC_TYPE_115', 'INC_TYPE_116'], axis=1)

    full_fema_matches = pd.concat([full_fema_matches, public.merge(df, how='inner', 
        left_on=['corrected_address', 'corrected_unit', 'std_city', 'std_st', 'std_zip5'],
        right_on=['address', 'APT_NO', 'CITY', 'STATE', 'ZIP5']
    )], axis=0)

    # Max for indicator variable columns
    aggregated = df \
        .drop(['INCIDENT_KEY'], axis=1) \
        .groupby(['address', 'APT_NO', 'CITY', 'STATE', 'ZIP5']).agg({
            'PROP_LOSS': 'sum',
            'CONT_LOSS': 'sum',
            'OTH_DEATH': 'sum',
            'OTH_INJ': 'sum',
            'HUM_FAC_1': 'max',
            'HUM_FAC_2': 'max',
            'HUM_FAC_3': 'max',
            'HUM_FAC_4': 'max',
            'HUM_FAC_5': 'max',
            'HUM_FAC_6': 'max',
            'HUM_FAC_7': 'max',
            'BLDG_INVOL': 'sum',
            'DET_ALERT': 'sum',
            'FLAME_SPRD': 'sum',
            'AES_PRES': 'sum',
            'ST_DAM_HVY': 'sum',
            'ST_DAM_SIG': 'sum',
            'ST_DAM_XTR': 'sum',
            'ST_DAM_MIN': 'sum',
            'EXP_NO': 'max',
            'INC_TYPE_111': 'sum',
            'INC_TYPE_113': 'sum',
            'INC_TYPE_118': 'sum',
            'building_fires': 'sum'
    }).reset_index()

    new_cols = aggregated.columns

    # Aggregated should have >1 building_fires for every row
    if aggregated.building_fires.min() < 1:
        raise Exception()

    public = public.merge(aggregated, how='left', 
        left_on=['corrected_address', 'corrected_unit', 'std_city', 'std_st', 'std_zip5'],
        right_on=['address', 'APT_NO', 'CITY', 'STATE', 'ZIP5']
    )

    # Randomize order
    public = public.sample(frac=1).reset_index(drop=True)

    # Drop duplicates
    duplicate_indices_to_zero_out = public[
        (public.duplicated(subset=['building_fires', 'corrected_address', 'corrected_unit', 'std_city', 'std_st', 'std_zip5'], keep='first')) &
        (public.building_fires > 0)
    ].index
    public.loc[duplicate_indices_to_zero_out, new_cols] = 0

    public[new_cols] = public[new_cols].fillna(0)
    public = public.drop(['address', 'APT_NO', 'CITY', 'STATE', 'ZIP5'], axis=1)
    public.columns = [x + f'_{year}' if x in new_cols else x for x in public.columns]

# %% [markdown]
# Check to make sure no public housing buildings have been duplicated.

# %%
public[(public.duplicated(keep=False, subset=[
    'corrected_address', 'corrected_unit', 'std_city', 'std_st', 'std_zip5',
    'building_fires_2012', 'building_fires_2013', 'building_fires_2014', 'building_fires_2015', 
    'building_fires_2016', 'building_fires_2017', 'building_fires_2018', 'building_fires_2019', 
    'building_fires_2020', 'building_fires_2021' 
]))]
# Out:
#         objectid    corrected_address corrected_unit       std_city std_st  \
# 56         97716        785 MLK JR DR                        DAWSON     GA
# 67         89551  8313 FAIR OAKS BLVD                    CARMICHAEL     CA
# 86        132093            3771 CAME             DR      LEXINGTON     KY
# 87         99579        600 S HOME ST                      CORRIGAN     TX
# 105        88201       309 W RIVER ST                 WEEPING WATER     NE
# ...          ...                  ...            ...            ...    ...
# 179019    166554       414 TRIBBLE ST                        SENECA     SC
# 179023    186022    2851 SW DAKOTA ST                       SEATTLE     WA
# 179026      3710  300 B T WOODARD CIR                     GRAMBLING     LA
# 179030    126946      2600 THURMAN DR                     GREENWOOD     MS
# 179036    110178         807 S FRY ST                      VALDOSTA     GA
#
#        std_zip5  total_dwelling_units  acc_units  total_occupied  \
# 56        39842                     4          4               4
# 67        95608                     4          4               3
# 86        40517                     2          2               2
# 87        75939                     2          2               2
# 105       68463                     4          4               4
# ...         ...                   ...        ...             ...
# 179019    29678                     4          4               4
# 179023    98126                     4          4               4
# 179026    71245                     1          1               1
# 179030    38930                     2          2               2
# 179036    31601                     6          6               6
#
#         regular_vacant  total_units  pct_occupied  number_reported  \
# 56                   0            4         100.0                4
# 67                   0            4          75.0                3
# 86                   0            2         100.0                2
# 87                   0            2         100.0                2
# 105                  0            4         100.0                4
# ...                ...          ...           ...              ...
# 179019               0            4         100.0                4
# 179023               0            4         100.0                4
# 179026               0            1         100.0                1
# 179030               0            2         100.0                2
# 179036               0            6         100.0                6
#
#         pct_reported  months_since_report  pct_movein  people_per_unit  \
# 56               NaN                  NaN         NaN              NaN
# 67               NaN                  NaN         NaN              NaN
# 86               NaN                  NaN         NaN              NaN
# 87               NaN                  NaN         NaN              NaN
# 105              NaN                  NaN         NaN              NaN
# ...              ...                  ...         ...              ...
# 179019           NaN                  NaN         NaN              NaN
# 179023           NaN                  NaN         NaN              NaN
# 179026           NaN                  NaN         NaN              NaN
# 179030           NaN                  NaN         NaN              NaN
# 179036           NaN                  NaN         NaN              NaN
#
#         people_total  rent_per_month  spending_per_month  \
# 56               NaN             NaN                 NaN
# 67               NaN             NaN                 NaN
# 86               NaN             NaN                 NaN
# 87               NaN             NaN                 NaN
# 105              NaN             NaN                 NaN
# ...              ...             ...                 ...
# 179019           NaN             NaN                 NaN
# 179023           NaN             NaN                 NaN
# 179026           NaN             NaN                 NaN
# 179030           NaN             NaN                 NaN
# 179036           NaN             NaN                 NaN
#
#         spending_per_month_prev_yr  hh_income  person_income  pct_lt5k  \
# 56                             NaN        NaN            NaN       NaN
# 67                             NaN        NaN            NaN       NaN
# 86                             NaN        NaN            NaN       NaN
# 87                             NaN        NaN            NaN       NaN
# 105                            NaN        NaN            NaN       NaN
# ...                            ...        ...            ...       ...
# 179019                         NaN        NaN            NaN       NaN
# 179023                         NaN        NaN            NaN       NaN
# 179026                         NaN        NaN            NaN       NaN
# 179030                         NaN        NaN            NaN       NaN
# 179036                         NaN        NaN            NaN       NaN
#
#         pct_5k_lt10k  pct_10k_lt15k  pct_15k_lt20k  pct_ge20k  pct_wage_major  \
# 56               NaN            NaN            NaN        NaN             NaN
# 67               NaN            NaN            NaN        NaN             NaN
# 86               NaN            NaN            NaN        NaN             NaN
# 87               NaN            NaN            NaN        NaN             NaN
# 105              NaN            NaN            NaN        NaN             NaN
# ...              ...            ...            ...        ...             ...
# 179019           NaN            NaN            NaN        NaN             NaN
# 179023           NaN            NaN            NaN        NaN             NaN
# 179026           NaN            NaN            NaN        NaN             NaN
# 179030           NaN            NaN            NaN        NaN             NaN
# 179036           NaN            NaN            NaN        NaN             NaN
#
#         pct_welfare_major  pct_other_major  pct_median  pct_lt50_median  \
# 56                    NaN              NaN         NaN              NaN
# 67                    NaN              NaN         NaN              NaN
# 86                    NaN              NaN         NaN              NaN
# 87                    NaN              NaN         NaN              NaN
# 105                   NaN              NaN         NaN              NaN
# ...                   ...              ...         ...              ...
# 179019                NaN              NaN         NaN              NaN
# 179023                NaN              NaN         NaN              NaN
# 179026                NaN              NaN         NaN              NaN
# 179030                NaN              NaN         NaN              NaN
# 179036                NaN              NaN         NaN              NaN
#
#         pct_lt30_median  pct_2adults  pct_1adult  pct_female_head  \
# 56                  NaN          NaN         NaN              NaN
# 67                  NaN          NaN         NaN              NaN
# 86                  NaN          NaN         NaN              NaN
# 87                  NaN          NaN         NaN              NaN
# 105                 NaN          NaN         NaN              NaN
# ...                 ...          ...         ...              ...
# 179019              NaN          NaN         NaN              NaN
# 179023              NaN          NaN         NaN              NaN
# 179026              NaN          NaN         NaN              NaN
# 179030              NaN          NaN         NaN              NaN
# 179036              NaN          NaN         NaN              NaN
#
#         pct_female_head_child  pct_disabled_lt62  pct_disabled_ge62  \
# 56                        NaN                NaN                NaN
# 67                        NaN                NaN                NaN
# 86                        NaN                NaN                NaN
# 87                        NaN                NaN                NaN
# 105                       NaN                NaN                NaN
# ...                       ...                ...                ...
# 179019                    NaN                NaN                NaN
# 179023                    NaN                NaN                NaN
# 179026                    NaN                NaN                NaN
# 179030                    NaN                NaN                NaN
# 179036                    NaN                NaN                NaN
#
#         pct_disabled_all  pct_lt24_head  pct_age25_50  pct_age51_61  \
# 56                   NaN            NaN           NaN           NaN
# 67                   NaN            NaN           NaN           NaN
# 86                   NaN            NaN           NaN           NaN
# 87                   NaN            NaN           NaN           NaN
# 105                  NaN            NaN           NaN           NaN
# ...                  ...            ...           ...           ...
# 179019               NaN            NaN           NaN           NaN
# 179023               NaN            NaN           NaN           NaN
# 179026               NaN            NaN           NaN           NaN
# 179030               NaN            NaN           NaN           NaN
# 179036               NaN            NaN           NaN           NaN
#
#         pct_age62plus  pct_age85plus  pct_minority  pct_black  \
# 56                NaN            NaN           NaN        NaN
# 67                NaN            NaN           NaN        NaN
# 86                NaN            NaN           NaN        NaN
# 87                NaN            NaN           NaN        NaN
# 105               NaN            NaN           NaN        NaN
# ...               ...            ...           ...        ...
# 179019            NaN            NaN           NaN        NaN
# 179023            NaN            NaN           NaN        NaN
# 179026            NaN            NaN           NaN        NaN
# 179030            NaN            NaN           NaN        NaN
# 179036            NaN            NaN           NaN        NaN
#
#         pct_native_american  pct_asian  pct_hispanic  months_waiting  \
# 56                      NaN        NaN           NaN             NaN
# 67                      NaN        NaN           NaN             NaN
# 86                      NaN        NaN           NaN             NaN
# 87                      NaN        NaN           NaN             NaN
# 105                     NaN        NaN           NaN             NaN
# ...                     ...        ...           ...             ...
# 179019                  NaN        NaN           NaN             NaN
# 179023                  NaN        NaN           NaN             NaN
# 179026                  NaN        NaN           NaN             NaN
# 179030                  NaN        NaN           NaN             NaN
# 179036                  NaN        NaN           NaN             NaN
#
#         months_from_movein  pct_utility_allow  ave_util_allow  pct_bed1  \
# 56                     NaN                NaN             NaN       NaN
# 67                     NaN                NaN             NaN       NaN
# 86                     NaN                NaN             NaN       NaN
# 87                     NaN                NaN             NaN       NaN
# 105                    NaN                NaN             NaN       NaN
# ...                    ...                ...             ...       ...
# 179019                 NaN                NaN             NaN       NaN
# 179023                 NaN                NaN             NaN       NaN
# 179026                 NaN                NaN             NaN       NaN
# 179030                 NaN                NaN             NaN       NaN
# 179036                 NaN                NaN             NaN       NaN
#
#         pct_bed2  pct_bed3  pct_overhoused  tminority  tpoverty  tpct_ownsfd  \
# 56           NaN       NaN             NaN        NaN       NaN          NaN
# 67           NaN       NaN             NaN        NaN       NaN          NaN
# 86           NaN       NaN             NaN        NaN       NaN          NaN
# 87           NaN       NaN             NaN        NaN       NaN          NaN
# 105          NaN       NaN             NaN        NaN       NaN          NaN
# ...          ...       ...             ...        ...       ...          ...
# 179019       NaN       NaN             NaN        NaN       NaN          NaN
# 179023       NaN       NaN             NaN        NaN       NaN          NaN
# 179026       NaN       NaN             NaN        NaN       NaN          NaN
# 179030       NaN       NaN             NaN        NaN       NaN          NaN
# 179036       NaN       NaN             NaN        NaN       NaN          NaN
#
#         chldrn_mbr_cnt  eldly_prcnt  pct_disabled_lt62_all  pct_lt80_median  \
# 56                 NaN          NaN                    NaN              NaN
# 67                 NaN          NaN                    NaN              NaN
# 86                 NaN          NaN                    NaN              NaN
# 87                 NaN          NaN                    NaN              NaN
# 105                NaN          NaN                    NaN              NaN
# ...                ...          ...                    ...              ...
# 179019             NaN          NaN                    NaN              NaN
# 179023             NaN          NaN                    NaN              NaN
# 179026             NaN          NaN                    NaN              NaN
# 179030             NaN          NaN                    NaN              NaN
# 179036             NaN          NaN                    NaN              NaN
#
#         median_inc_amnt  metro  micro  c1pprb  annl_expns_amnt  \
# 56                  NaN    1.0    0.0     3.0              NaN
# 67                  NaN    1.0    0.0     1.0              NaN
# 86                  NaN    1.0    0.0     1.0              NaN
# 87                  NaN    0.0    0.0     2.0              NaN
# 105                 NaN    1.0    0.0     1.0              NaN
# ...                 ...    ...    ...     ...              ...
# 179019              NaN    0.0    1.0     3.0              NaN
# 179023              NaN    1.0    0.0     1.0              NaN
# 179026              NaN    0.0    1.0     3.0              NaN
# 179030              NaN    0.0    1.0     3.0              NaN
# 179036              NaN    1.0    0.0     1.0              NaN
#
#         annl_expns_amnt_prev_yr  pha_total_units  \
# 56                          NaN              116
# 67                          NaN              856
# 86                          NaN              914
# 87                          NaN              124
# 105                         NaN               19
# ...                         ...              ...
# 179019                      NaN             1322
# 179023                      NaN             5229
# 179026                      NaN               95
# 179030                      NaN              408
# 179036                      NaN              531
#
#         dev_spending_per_month_prev_yr  dev_chldrn_mbr_cnt  \
# 56                               362.0               125.0
# 67                               691.0               324.0
# 86                               318.0               335.0
# 87                               335.0                61.0
# 105                              134.0                 2.0
# ...                                ...                 ...
# 179019                           367.0               173.0
# 179023                           577.0                65.0
# 179026                           257.0                53.0
# 179030                           636.0               321.0
# 179036                           580.0               303.0
#
#         dev_annl_expns_amnt  dev_annl_expns_amnt_prev_yr  dev_eldly_prcnt  \
# 56                 541066.0                     491472.0             5.00
# 67                2416494.0                    2263325.0             7.11
# 86                1159196.0                     664352.0             1.42
# 87                 502629.0                     479007.0            20.91
# 105                 31821.0                      28903.0            55.00
# ...                     ...                          ...              ...
# 179019            1676625.0                     930303.0            13.24
# 179023             745870.0                     477541.0             8.82
# 179026             285302.0                     259127.0             7.53
# 179030            1351692.0                    1289586.0             3.66
# 179036            1220459.0                    1148916.0             2.45
#
#         dev_pct_disabled_lt62_all  dev_pct_lt80_median  dev_median_inc_amnt  \
# 56                           9.62            94.949997              10018.0
# 67                           9.90            98.900002              12923.0
# 86                           7.64            94.250000              18084.0
# 87                          10.00            87.290001              14776.0
# 105                         15.00            94.440002              12960.0
# ...                           ...                  ...                  ...
# 179019                      14.84            98.169998               9907.0
# 179023                       9.41           100.000000              11841.0
# 179026                      15.75           100.000000               9564.0
# 179030                       7.13           100.000000               9954.0
# 179036                       4.50           100.000000               9274.0
#
#         dev_total_units  dev_total_dwelling_units  dev_acc_units  \
# 56                116.0                     116.0          116.0
# 67                293.0                     293.0          293.0
# 86                180.0                     180.0          180.0
# 87                124.0                     124.0          124.0
# 105                20.0                      19.0           19.0
# ...                 ...                       ...            ...
# 179019            225.0                     224.0          224.0
# 179023             73.0                      73.0           73.0
# 179026             97.0                      95.0           95.0
# 179030            199.0                     199.0          199.0
# 179036            170.0                     169.0          169.0
#
#         dev_total_occupied  dev_regular_vacant  dev_pha_total_units  \
# 56                   113.0                 3.0                116.0
# 67                   275.0                 3.0                920.0
# 86                   173.0                 6.0                914.0
# 87                   118.0                 0.0                124.0
# 105                   18.0                 1.0                 19.0
# ...                    ...                 ...                  ...
# 179019               219.0                 5.0               1322.0
# 179023                72.0                 1.0               5410.0
# 179026                81.0                 8.0                 95.0
# 179030               166.0                29.0                408.0
# 179036               163.0                 6.0                530.0
#
#         dev_pct_occupied  dev_number_reported  dev_pct_reported  \
# 56             97.410004                 99.0             87.61
# 67             93.849998                272.0             98.91
# 86             96.120003                174.0            100.00
# 87             95.160004                118.0            100.00
# 105            94.739998                 18.0            100.00
# ...                  ...                  ...               ...
# 179019         97.769997                219.0            100.00
# 179023         98.629997                 72.0            100.00
# 179026         85.260002                 80.0             98.77
# 179030         83.419998                166.0            100.00
# 179036         96.449997                163.0            100.00
#
#         dev_months_since_report  dev_pct_movein  dev_people_per_unit  \
# 56                          6.0           13.13                  2.6
# 67                          7.0            1.10                  2.6
# 86                          8.0            6.90                  3.2
# 87                          5.0           18.64                  1.9
# 105                         8.0           16.67                  1.1
# ...                         ...             ...                  ...
# 179019                      3.0           21.92                  2.0
# 179023                     12.0            2.78                  2.4
# 179026                      5.0           20.00                  1.8
# 179030                      5.0            9.64                  3.3
# 179036                      6.0           26.99                  3.0
#
#         dev_people_total  dev_rent_per_month  dev_spending_per_month  \
# 56                 260.0               288.0                   399.0
# 67                 717.0               418.0                   732.0
# 86                 563.0               274.0                   558.0
# 87                 220.0               344.0                   355.0
# 105                 20.0               316.0                   147.0
# ...                  ...                 ...                     ...
# 179019             438.0               263.0                   638.0
# 179023             170.0               504.0                   863.0
# 179026             146.0               258.0                   294.0
# 179030             547.0               277.0                   679.0
# 179036             489.0               229.0                   624.0
#
#         dev_hh_income  dev_person_income  dev_pct_lt5k  dev_pct_5k_lt10k  \
# 56            14862.0             5659.0          9.09             39.39
# 67            17733.0             6727.0          5.34             14.12
# 86            20853.0             6445.0         12.64             15.52
# 87            20859.0            11188.0          5.17             25.86
# 105           17137.0            15423.0          5.88             29.41
# ...               ...                ...           ...               ...
# 179019        12198.0             6099.0         20.85             28.44
# 179023        20000.0             8471.0          7.46             25.37
# 179026        11146.0             6107.0          7.59             51.90
# 179030        11827.0             3589.0         22.88             22.88
# 179036        11008.0             3669.0          1.23             64.42
#
#         dev_pct_10k_lt15k  dev_pct_15k_lt20k  dev_pct_ge20k  \
# 56                  25.25               3.03          23.23
# 67                  34.73              12.60          33.21
# 86                  16.09              12.07          43.68
# 87                  18.97              13.79          36.21
# 105                 29.41               0.00          35.29
# ...                   ...                ...            ...
# 179019              21.80              12.32          16.59
# 179023              22.39               5.97          38.81
# 179026              18.99              12.66           8.86
# 179030              19.61              12.42          22.22
# 179036              15.95               8.59           9.82
#
#         dev_pct_wage_major  dev_pct_welfare_major  dev_pct_other_major  \
# 56                   37.37                   0.00                62.63
# 67                   25.74                  16.91                53.31
# 86                   62.07                   9.77                28.16
# 87                   41.53                   0.00                56.78
# 105                  11.11                   0.00                83.33
# ...                    ...                    ...                  ...
# 179019               24.66                   0.46                71.23
# 179023               44.44                   8.33                40.28
# 179026               40.00                   0.00                58.75
# 179030               30.12                   0.60                61.45
# 179036               34.97                   1.23                63.80
#
#         dev_pct_median  dev_pct_lt50_median  dev_pct_lt30_median  \
# 56               26.99                84.85                70.71
# 67               19.65                92.28                74.63
# 86               25.66                80.46                59.20
# 87               35.49                70.34                44.92
# 105              19.58                83.33                66.67
# ...                ...                  ...                  ...
# 179019           18.74                94.52                70.32
# 179023           17.66                88.89                73.61
# 179026           19.19                95.00                72.50
# 179030           33.79                89.16                65.66
# 179036           19.15                93.87                80.98
#
#         dev_pct_2adults  dev_pct_1adult  dev_pct_female_head  \
# 56                 2.02           60.61                95.96
# 67                 6.25           52.21                84.93
# 86                 6.32           78.74                91.95
# 87                 5.93           25.42                75.42
# 105                0.00           11.11                72.22
# ...                 ...             ...                  ...
# 179019             1.37           40.18                80.82
# 179023             5.56           52.78                88.89
# 179026             1.25           36.25                78.75
# 179030             2.41           71.08                96.39
# 179036             2.45           71.78                95.71
#
#         dev_pct_female_head_child  dev_pct_disabled_lt62  \
# 56                          62.63                  20.69
# 67                          54.04                  24.00
# 86                          79.31                  13.77
# 87                          28.81                  28.00
# 105                         11.11                  42.86
# ...                           ...                    ...
# 179019                      37.44                  37.04
# 179023                      51.39                  22.03
# 179026                      36.25                  26.09
# 179030                      72.29                  17.01
# 179036                      73.62                  13.25
#
#         dev_pct_disabled_ge62  dev_pct_disabled_all  dev_pct_lt24_head  \
# 56                      41.67                 11.92               5.05
# 67                      76.60                 15.20               1.10
# 86                      71.43                  8.53               4.60
# 87                      37.21                 17.27               6.78
# 105                     18.18                 25.00               0.00
# ...                       ...                   ...                ...
# 179019                  49.12                 21.46               9.59
# 179023                  30.77                 11.76               0.00
# 179026                 100.00                 23.29              23.75
# 179030                  84.21                 10.24               3.61
# 179036                   8.33                  4.70              11.66
#
#         dev_pct_age25_50  dev_pct_age51_61  dev_pct_age62plus  \
# 56                 66.67             16.16              12.12
# 67                 59.93             22.06              16.91
# 86                 82.18              9.77               3.45
# 87                 36.44             20.34              36.44
# 105                33.33              5.56              61.11
# ...                  ...               ...                ...
# 179019             41.55             22.83              26.03
# 179023             59.72             22.22              18.06
# 179026             48.75             13.75              13.75
# 179030             73.49             11.45              11.45
# 179036             68.10             12.88               7.36
#
#         dev_pct_age85plus  dev_pct_minority  dev_pct_black  \
# 56                   1.01             97.98          97.98
# 67                   0.74             73.90          51.47
# 86                   0.00             79.31          75.29
# 87                   1.69             63.56          62.71
# 105                  5.56              0.00           0.00
# ...                   ...               ...            ...
# 179019               1.83             31.96          30.59
# 179023               0.00             81.94          56.94
# 179026               0.00            100.00          97.50
# 179030               0.60             98.19          98.19
# 179036               0.61             98.77          98.77
#
#         dev_pct_native_american  dev_pct_asian  dev_pct_hispanic  \
# 56                         0.00           0.00              0.00
# 67                         0.74           8.09             13.60
# 86                         0.57           0.00              3.45
# 87                         0.00           0.00              0.85
# 105                        0.00           0.00              0.00
# ...                         ...            ...               ...
# 179019                     0.00           0.00              1.37
# 179023                     0.00          13.89             11.11
# 179026                     0.00           0.00              2.50
# 179030                     0.00           0.00              0.00
# 179036                     0.00           0.00              0.00
#
#         dev_months_waiting  dev_months_from_movein  dev_pct_utility_allow  \
# 56                    17.0                    99.0                 100.00
# 67                   118.0                   157.0                  98.53
# 86                     0.0                   110.0                  78.74
# 87                     3.0                    87.0                  98.31
# 105                    2.0                    75.0                   0.00
# ...                    ...                     ...                    ...
# 179019                10.0                    75.0                 100.00
# 179023                 0.0                   190.0                 100.00
# 179026                 5.0                    62.0                  98.75
# 179030                14.0                   111.0                  98.80
# 179036                 6.0                    49.0                 100.00
#
#         dev_ave_util_allow  dev_pct_bed1  dev_pct_bed2  dev_pct_bed3  \
# 56                   146.0         21.21         41.41         37.37
# 67                    96.0         16.18         31.25         52.57
# 86                   141.0          3.45         37.93         58.62
# 87                    64.0         48.31         33.05         18.64
# 105                    0.0         94.44          5.56          0.00
# ...                    ...           ...           ...           ...
# 179019                38.0         31.96         33.33         34.70
# 179023                99.0          5.56         86.11          8.33
# 179026               102.0         26.25         45.00         28.75
# 179030               168.0          0.00         28.92         71.08
# 179036               125.0         17.18         33.74         49.08
#
#         dev_pct_overhoused  dev_tminority  dev_tpoverty  dev_tpct_ownsfd  \
# 56                   11.11          77.77         38.69            73.02
# 67                   19.85          33.37         16.06            53.35
# 86                    6.90          28.56         18.27            41.71
# 87                   11.86          46.06         27.36            64.66
# 105                   0.00           3.38          5.84            90.07
# ...                    ...            ...           ...              ...
# 179019               27.40          32.10         23.66            55.58
# 179023               18.06          29.41         10.00            57.15
# 179026               32.50          94.56         36.61            53.42
# 179030               22.89          75.93         51.90            54.92
# 179036               11.04          90.44         42.14            69.71
#
#         pha_section8_units_cnt  pha_section8_occupied  pha_opfund_amnt  \
# 56                           0                      0           553116
# 67                       13394                  11597          2595760
# 86                        3427                   3178          3357530
# 87                           0                      0           261599
# 105                          0                      0            23646
# ...                        ...                    ...              ...
# 179019                    1675                   1544          6360454
# 179023                   12373                  10625         45433857
# 179026                     154                     76           315304
# 179030                     265                    190          2027292
# 179036                       0                      0          2722843
#
#         pha_opfund_amnt_prev_yr  pha_capfund_amnt  pha_capfund_amnt_prev_yr  \
# 56                       491455            314276                         0
# 67                      2978874           2663251                   2186206
# 86                      3222441                 0                         0
# 87                       233974            301066                    245033
# 105                       28903             33239                         0
# ...                         ...               ...                       ...
# 179019                  5550955           4473617                         0
# 179023                 35912474                 0                         0
# 179026                   259139            265551                         0
# 179030                  1765428           1251932                   1012141
# 179036                  2277945           1605853                   1273250
#
#         pha_ross_amnt  pha_fss_amnt  pha_chldrn_mbr_cnt  pha_eldly_prcnt  \
# 56                  0             0               135.0         5.240000
# 67                  0             0              8803.0        19.190001
# 86                  0             0              3996.0        11.230000
# 87                  0             0                56.0        20.670000
# 105                 0             0                 3.0        40.910000
# ...               ...           ...                 ...              ...
# 179019              0             0              2157.0        18.520000
# 179023              0             0              8792.0        24.620001
# 179026              0             0               161.0         7.260000
# 179030              0             0               915.0         5.840000
# 179036              0             0               768.0         7.280000
#
#         pha_pct_disabled_lt62_all  pha_pct_lt80_median  pha_median_inc_amnt  \
# 56                       8.740000            98.209999              11844.0
# 67                      18.000000            96.500000              12723.0
# 86                      12.650000            98.080002              12752.0
# 87                      11.540000            88.790001              15684.0
# 105                     31.820000           100.000000              10452.0
# ...                           ...                  ...                  ...
# 179019                  14.380000            99.110001              11466.0
# 179023                  16.790001            99.029999              11280.0
# 179026                  12.850000            98.779999              11700.0
# 179030                   8.550000            98.900002              10812.0
# 179036                   6.330000            98.820000              10332.0
#
#         pha_annl_expns_amnt  pha_annl_expns_amnt_prev_yr  construction_year  \
# 56                 867392.0                     491472.0             1952.0
# 67              153373794.0                  141513319.0             1986.0
# 86               23015085.0                   21910224.0                NaN
# 87                 562665.0                     479007.0                NaN
# 105                 56885.0                      28903.0             1970.0
# ...                     ...                          ...                ...
# 179019           19914163.0                   14914871.0             1954.0
# 179023          170426828.0                  143452007.0             1985.0
# 179026             913082.0                     569809.0             1984.0
# 179030            4101451.0                    3675720.0             1981.0
# 179036            4328609.0                    3551195.0             1953.0
#
#         dofa_actual_year  encoded_development_code  encoded_participant_code  \
# 56                1952.0                      1144                       430
# 67                1986.0                       452                       232
# 86                1994.0                      1977                       845
# 87                1972.0                      5911                      2429
# 105               1970.0                      3508                      1674
# ...                  ...                       ...                       ...
# 179019            1971.0                      5352                      2128
# 179023            1985.0                      6211                      2609
# 179026            1984.0                      2250                      1009
# 179030            1981.0                      3155                      1497
# 179036            1953.0                      1179                       450
#
#         encoded_msa_nm  encoded_zip5  encoded_zip9  encoded_zip11  \
# 56                 306          2035            47          73502
# 67                 237          5561          1026         161918
# 86                 161          2100           808          75757
# 87                 306          4716          1734         138186
# 105                206          4044          3404         119345
# ...                ...           ...           ...            ...
# 179019             306          1173          3984          36520
# 179023             251          5752          1640         165240
# 179026             306          4286          8182         127045
# 179030             306          1978          2965          71327
# 179036             306          1382          6481          43481
#
#         msgusps_100% Overall probable correctness  \
# 56                                              0
# 67                                              0
# 86                                              0
# 87                                              0
# 105                                             0
# ...                                           ...
# 179019                                          0
# 179023                                          0
# 179026                                          0
# 179030                                          0
# 179036                                          0
#
#         msgusps_20% Overall probable correctness  \
# 56                                             0
# 67                                             0
# 86                                             0
# 87                                             0
# 105                                            0
# ...                                          ...
# 179019                                         0
# 179023                                         0
# 179026                                         0
# 179030                                         0
# 179036                                         0
#
#         msgusps_30% Overall probable correctness  \
# 56                                             0
# 67                                             0
# 86                                             0
# 87                                             0
# 105                                            0
# ...                                          ...
# 179019                                         0
# 179023                                         0
# 179026                                         0
# 179030                                         0
# 179036                                         0
#
#         msgusps_40% Overall probable correctness  \
# 56                                             0
# 67                                             0
# 86                                             0
# 87                                             0
# 105                                            0
# ...                                          ...
# 179019                                         0
# 179023                                         0
# 179026                                         0
# 179030                                         0
# 179036                                         0
#
#         msgusps_50% Overall probable correctness  \
# 56                                             0
# 67                                             0
# 86                                             0
# 87                                             0
# 105                                            0
# ...                                          ...
# 179019                                         0
# 179023                                         0
# 179026                                         0
# 179030                                         0
# 179036                                         0
#
#         msgusps_60% Overall probable correctness  \
# 56                                             0
# 67                                             0
# 86                                             0
# 87                                             0
# 105                                            0
# ...                                          ...
# 179019                                         0
# 179023                                         0
# 179026                                         0
# 179030                                         0
# 179036                                         0
#
#         msgusps_70% Overall probable correctness  \
# 56                                             1
# 67                                             0
# 86                                             0
# 87                                             0
# 105                                            0
# ...                                          ...
# 179019                                         1
# 179023                                         0
# 179026                                         1
# 179030                                         1
# 179036                                         0
#
#         msgusps_80% Overall probable correctness  \
# 56                                             0
# 67                                             0
# 86                                             0
# 87                                             1
# 105                                            0
# ...                                          ...
# 179019                                         0
# 179023                                         0
# 179026                                         0
# 179030                                         0
# 179036                                         0
#
#         msgusps_90% Overall probable correctness  \
# 56                                             0
# 67                                             1
# 86                                             1
# 87                                             0
# 105                                            1
# ...                                          ...
# 179019                                         0
# 179023                                         1
# 179026                                         0
# 179030                                         0
# 179036                                         1
#
#         msgusps_Apartment missing or not found  \
# 56                                           0
# 67                                           0
# 86                                           0
# 87                                           0
# 105                                          0
# ...                                        ...
# 179019                                       0
# 179023                                       0
# 179026                                       0
# 179030                                       0
# 179036                                       0
#
#         msgusps_House # not found on this street  \
# 56                                             0
# 67                                             0
# 86                                             0
# 87                                             0
# 105                                            0
# ...                                          ...
# 179019                                         0
# 179023                                         0
# 179026                                         0
# 179030                                         0
# 179036                                         0
#
#         msgusps_Insufficient or Blank address  msgusps_Multiple Match  \
# 56                                          0                       0
# 67                                          0                       0
# 86                                          0                       0
# 87                                          0                       0
# 105                                         0                       0
# ...                                       ...                     ...
# 179019                                      0                       0
# 179023                                      0                       0
# 179026                                      0                       0
# 179030                                      0                       0
# 179036                                      0                       0
#
#         msgusps_Street not found  \
# 56                             0
# 67                             0
# 86                             0
# 87                             0
# 105                            0
# ...                          ...
# 179019                         0
# 179023                         0
# 179026                         0
# 179030                         0
# 179036                         0
#
#         pha_ha_section_8_size_category_EXTRA LARGE (5,000+)  \
# 56                                                      0
# 67                                                      1
# 86                                                      0
# 87                                                      0
# 105                                                     0
# ...
#
#         OTH_INJ_2019  HUM_FAC_1_2019  HUM_FAC_2_2019  HUM_FAC_3_2019  \
# 56               0.0             0.0             0.0             0.0
# 67               0.0             0.0             0.0             0.0
# 86               0.0             0.0             0.0             0.0
# 87               0.0             0.0             0.0             0.0
# 105              0.0             0.0             0.0             0.0
# ...              ...             ...             ...             ...
# 179019           0.0             0.0             0.0             0.0
# 179023           0.0             0.0             0.0             0.0
# 179026           0.0             0.0             0.0             0.0
# 179030           0.0             0.0             0.0             0.0
# 179036           0.0             0.0             0.0             0.0
#
#         HUM_FAC_4_2019  HUM_FAC_5_2019  HUM_FAC_6_2019  HUM_FAC_7_2019  \
# 56                 0.0             0.0             0.0             0.0
# 67                 0.0             0.0             0.0             0.0
# 86                 0.0             0.0             0.0             0.0
# 87                 0.0             0.0             0.0             0.0
# 105                0.0             0.0             0.0             0.0
# ...                ...             ...             ...             ...
# 179019             0.0             0.0             0.0             0.0
# 179023             0.0             0.0             0.0             0.0
# 179026             0.0             0.0             0.0             0.0
# 179030             0.0             0.0             0.0             0.0
# 179036             0.0             0.0             0.0             0.0
#
#         BLDG_INVOL_2019  DET_ALERT_2019  FLAME_SPRD_2019  AES_PRES_2019  \
# 56                  0.0             0.0              0.0            0.0
# 67                  0.0             0.0              0.0            0.0
# 86                  0.0             0.0              0.0            0.0
# 87                  0.0             0.0              0.0            0.0
# 105                 0.0             0.0              0.0            0.0
# ...                 ...             ...              ...            ...
# 179019              0.0             0.0              0.0            0.0
# 179023              0.0             0.0              0.0            0.0
# 179026              0.0             0.0              0.0            0.0
# 179030              0.0             0.0              0.0            0.0
# 179036              0.0             0.0              0.0            0.0
#
#         ST_DAM_HVY_2019  ST_DAM_SIG_2019  ST_DAM_XTR_2019  ST_DAM_MIN_2019  \
# 56                  0.0              0.0              0.0              0.0
# 67                  0.0              0.0              0.0              0.0
# 86                  0.0              0.0              0.0              0.0
# 87                  0.0              0.0              0.0              0.0
# 105                 0.0              0.0              0.0              0.0
# ...                 ...              ...              ...              ...
# 179019              0.0              0.0              0.0              0.0
# 179023              0.0              0.0              0.0              0.0
# 179026              0.0              0.0              0.0              0.0
# 179030              0.0              0.0              0.0              0.0
# 179036              0.0              0.0              0.0              0.0
#
#         EXP_NO_2019  INC_TYPE_111_2019  INC_TYPE_113_2019  INC_TYPE_118_2019  \
# 56              0.0                0.0                0.0                0.0
# 67              0.0                0.0                0.0                0.0
# 86              0.0                0.0                0.0                0.0
# 87              0.0                0.0                0.0                0.0
# 105             0.0                0.0                0.0                0.0
# ...             ...                ...                ...                ...
# 179019          0.0                0.0                0.0                0.0
# 179023          0.0                0.0                0.0                0.0
# 179026          0.0                0.0                0.0                0.0
# 179030          0.0                0.0                0.0                0.0
# 179036          0.0                0.0                0.0                0.0
#
#         building_fires_2019  PROP_LOSS_2020  CONT_LOSS_2020  OTH_DEATH_2020  \
# 56                      0.0             0.0             0.0             0.0
# 67                      0.0             0.0             0.0             0.0
# 86                      0.0             0.0             0.0             0.0
# 87                      0.0             0.0             0.0             0.0
# 105                     0.0             0.0             0.0             0.0
# ...                     ...             ...             ...             ...
# 179019                  0.0             0.0             0.0             0.0
# 179023                  0.0             0.0             0.0             0.0
# 179026                  0.0             0.0             0.0             0.0
# 179030                  0.0             0.0             0.0             0.0
# 179036                  0.0             0.0             0.0             0.0
#
#         OTH_INJ_2020  HUM_FAC_1_2020  HUM_FAC_2_2020  HUM_FAC_3_2020  \
# 56               0.0             0.0             0.0             0.0
# 67               0.0             0.0             0.0             0.0
# 86               0.0             0.0             0.0             0.0
# 87               0.0             0.0             0.0             0.0
# 105              0.0             0.0             0.0             0.0
# ...              ...             ...             ...             ...
# 179019           0.0             0.0             0.0             0.0
# 179023           0.0             0.0             0.0             0.0
# 179026           0.0             0.0             0.0             0.0
# 179030           0.0             0.0             0.0             0.0
# 179036           0.0             0.0             0.0             0.0
#
#         HUM_FAC_4_2020  HUM_FAC_5_2020  HUM_FAC_6_2020  HUM_FAC_7_2020  \
# 56                 0.0             0.0             0.0             0.0
# 67                 0.0             0.0             0.0             0.0
# 86                 0.0             0.0             0.0             0.0
# 87                 0.0             0.0             0.0             0.0
# 105                0.0             0.0             0.0             0.0
# ...                ...             ...             ...             ...
# 179019             0.0             0.0             0.0             0.0
# 179023             0.0             0.0             0.0             0.0
# 179026             0.0             0.0             0.0             0.0
# 179030             0.0             0.0             0.0             0.0
# 179036             0.0             0.0             0.0             0.0
#
#         BLDG_INVOL_2020  DET_ALERT_2020  FLAME_SPRD_2020  AES_PRES_2020  \
# 56                  0.0             0.0              0.0            0.0
# 67                  0.0             0.0              0.0            0.0
# 86                  0.0             0.0              0.0            0.0
# 87                  0.0             0.0              0.0            0.0
# 105                 0.0             0.0              0.0            0.0
# ...                 ...             ...              ...            ...
# 179019              0.0             0.0              0.0            0.0
# 179023              0.0             0.0              0.0            0.0
# 179026              0.0             0.0              0.0            0.0
# 179030              0.0             0.0              0.0            0.0
# 179036              0.0             0.0              0.0            0.0
#
#         ST_DAM_HVY_2020  ST_DAM_SIG_2020  ST_DAM_XTR_2020  ST_DAM_MIN_2020  \
# 56                  0.0              0.0              0.0              0.0
# 67                  0.0              0.0              0.0              0.0
# 86                  0.0              0.0              0.0              0.0
# 87                  0.0              0.0              0.0              0.0
# 105                 0.0              0.0              0.0              0.0
# ...                 ...              ...              ...              ...
# 179019              0.0              0.0              0.0              0.0
# 179023              0.0              0.0              0.0              0.0
# 179026              0.0              0.0              0.0              0.0
# 179030              0.0              0.0              0.0              0.0
# 179036              0.0              0.0              0.0              0.0
#
#         EXP_NO_2020  INC_TYPE_111_2020  INC_TYPE_113_2020  INC_TYPE_118_2020  \
# 56              0.0                0.0                0.0                0.0
# 67              0.0                0.0                0.0                0.0
# 86              0.0                0.0                0.0                0.0
# 87              0.0                0.0                0.0                0.0
# 105             0.0                0.0                0.0                0.0
# ...             ...                ...                ...                ...
# 179019          0.0                0.0                0.0                0.0
# 179023          0.0                0.0                0.0                0.0
# 179026          0.0                0.0                0.0                0.0
# 179030          0.0                0.0                0.0                0.0
# 179036          0.0                0.0                0.0                0.0
#
#         building_fires_2020  PROP_LOSS_2021  CONT_LOSS_2021  OTH_DEATH_2021  \
# 56                      0.0             0.0             0.0             0.0
# 67                      0.0             0.0             0.0             0.0
# 86                      0.0             0.0             0.0             0.0
# 87                      0.0             0.0             0.0             0.0
# 105                     0.0             0.0             0.0             0.0
# ...                     ...             ...             ...             ...
# 179019                  0.0             0.0             0.0             0.0
# 179023                  0.0             0.0             0.0             0.0
# 179026                  0.0             0.0             0.0             0.0
# 179030                  0.0             0.0             0.0             0.0
# 179036                  0.0             0.0             0.0             0.0
#
#         OTH_INJ_2021  HUM_FAC_1_2021  HUM_FAC_2_2021  HUM_FAC_3_2021  \
# 56               0.0             0.0             0.0             0.0
# 67               0.0             0.0             0.0             0.0
# 86               0.0             0.0             0.0             0.0
# 87               0.0             0.0             0.0             0.0
# 105              0.0             0.0             0.0             0.0
# ...              ...             ...             ...             ...
# 179019           0.0             0.0             0.0             0.0
# 179023           0.0             0.0             0.0             0.0
# 179026           0.0             0.0             0.0             0.0
# 179030           0.0             0.0             0.0             0.0
# 179036           0.0             0.0             0.0             0.0
#
#         HUM_FAC_4_2021  HUM_FAC_5_2021  HUM_FAC_6_2021  HUM_FAC_7_2021  \
# 56                 0.0             0.0             0.0             0.0
# 67                 0.0             0.0             0.0             0.0
# 86                 0.0             0.0             0.0             0.0
# 87                 0.0             0.0             0.0             0.0
# 105                0.0             0.0             0.0             0.0
# ...                ...             ...             ...             ...
# 179019             0.0             0.0             0.0             0.0
# 179023             0.0             0.0             0.0             0.0
# 179026             0.0             0.0             0.0             0.0
# 179030             0.0             0.0             0.0             0.0
# 179036             0.0             0.0             0.0             0.0
#
#         BLDG_INVOL_2021  DET_ALERT_2021  FLAME_SPRD_2021  AES_PRES_2021  \
# 56                  0.0             0.0              0.0            0.0
# 67                  0.0             0.0              0.0            0.0
# 86                  0.0             0.0              0.0            0.0
# 87                  0.0             0.0              0.0            0.0
# 105                 0.0             0.0              0.0            0.0
# ...                 ...             ...              ...            ...
# 179019              0.0             0.0              0.0            0.0
# 179023              0.0             0.0              0.0            0.0
# 179026              0.0             0.0              0.0            0.0
# 179030              0.0             0.0              0.0            0.0
# 179036              0.0             0.0              0.0            0.0
#
#         ST_DAM_HVY_2021  ST_DAM_SIG_2021  ST_DAM_XTR_2021  ST_DAM_MIN_2021  \
# 56                  0.0              0.0              0.0              0.0
# 67                  0.0              0.0              0.0              0.0
# 86                  0.0              0.0              0.0              0.0
# 87                  0.0              0.0              0.0              0.0
# 105                 0.0              0.0              0.0              0.0
# ...                 ...              ...              ...              ...
# 179019              0.0              0.0              0.0              0.0
# 179023              0.0              0.0              0.0              0.0
# 179026              0.0              0.0              0.0              0.0
# 179030              0.0              0.0              0.0              0.0
# 179036              0.0              0.0              0.0              0.0
#
#         EXP_NO_2021  INC_TYPE_111_2021  INC_TYPE_113_2021  INC_TYPE_118_2021  \
# 56              0.0                0.0                0.0                0.0
# 67              0.0                0.0                0.0                0.0
# 86              0.0                0.0                0.0                0.0
# 87              0.0                0.0                0.0                0.0
# 105             0.0                0.0                0.0                0.0
# ...             ...                ...                ...                ...
# 179019          0.0                0.0                0.0                0.0
# 179023          0.0                0.0                0.0                0.0
# 179026          0.0                0.0                0.0                0.0
# 179030          0.0                0.0                0.0                0.0
# 179036          0.0                0.0                0.0                0.0
#
#         building_fires_2021
# 56                      0.0
# 67                      0.0
# 86                      0.0
# 87                      0.0
# 105                     0.0
# ...                     ...
# 179019                  0.0
# 179023                  0.0
# 179026                  0.0
# 179030                  0.0
# 179036                  0.0
#
# [13185 rows x 550 columns]

# %%
print(public.objectid.nunique() / len(public))
if (public.objectid.nunique() / len(public)) != 1:
    raise Exception()

if public[(public.duplicated(keep=False, subset=[
    'corrected_address', 'corrected_unit', 'std_city', 'std_st', 'std_zip5',
    'building_fires_2012', 'building_fires_2013', 'building_fires_2014', 'building_fires_2015', 
    'building_fires_2016', 'building_fires_2017', 'building_fires_2018', 'building_fires_2019', 
    'building_fires_2020', 'building_fires_2021' 
])) & (public[[x for x in public.columns if 'building_fires' in x]].sum(axis=1) > 0)].shape[0] > 0:
    raise Exception()
# Out:
# 1.0

# %%
full_fema_matches \
    .loc[:, ['corrected_address', 'corrected_unit', 'std_city', 'std_st', 'std_zip5', 'INCIDENT_KEY']] \
    .to_csv('full_fema_matches.csv', index=False)

# %%
public.columns = [x.lower() for x in public.columns]

# %%
public.to_csv('ph_fires_matched_2.1.csv', index=False)
